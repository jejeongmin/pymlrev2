# %%
import codecs
from konlpy.tag import Twitter

twitter = Twitter()
line = '나는 국민대학교의 축제에 놀러 가고 싶습니다.'
malist = twitter.pos(line)
malist
# Out:
# [('나', 'Noun'),
#  ('는', 'Josa'),
#  ('국민', 'Noun'),
#  ('대학교', 'Noun'),
#  ('의', 'Josa'),
#  ('축제', 'Noun'),
#  ('에', 'Josa'),
#  ('놀', 'Verb'),
#  ('러', 'Eomi'),
#  ('가고', 'Verb'),
#  ('싶', 'Verb'),
#  ('습니다', 'Eomi'),
#  ('.', 'Punctuation')]

# %%
from konlpy.tag import Komoran
tagger = Komoran()

line = '나는 국민대학교의 축제에 놀러 가고 싶습니다.'
malist = tagger.pos(line)
malist
# Out:
# [('나', 'NP'),
#  ('는', 'JX'),
#  ('국민대학교', 'NNP'),
#  ('의', 'JKG'),
#  ('축제', 'NNG'),
#  ('에', 'JKB'),
#  ('놀', 'VV'),
#  ('러', 'EC'),
#  ('가', 'VV'),
#  ('고', 'EC'),
#  ('싶', 'VX'),
#  ('습니다', 'EF'),
#  ('.', 'SF')]

# %%
from konlpy.tag import Komoran

tagger = Komoran()  # 형태소 분석기
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
import requests
import lxml.html
import codecs

#투캅스 시나리오 읽어오기
#이 시나리오 데이터는 제공되어질수 없으며 배포가 불가능하오니 
#http://www.korean.go.kr(국립국어원)에서 회원가입을 하시고 다운을 받아주세요. 
articles = []
fp = codecs.open("투캅스(배포불가).txt", "r", encoding="utf-8")
soup = BeautifulSoup(fp, "html.parser")
body = soup.select_one("body")
text = body.getText()
articles = text.split("\n")
len(articles)
fp.close()

# %%
articles
# Out:
# ['',
#  '씬 1 달리는 버스 안',
#  '타이틀이 끝나고 F.I 되면―',
#  '경쾌하게 달려와 서는 시내버스.',
#  '치익, 소리와 함께 문이 열리자 기다리고 있던 사람들이 올라탄다.',
#  '버스카드 혹은 현금함 앞으로 오가는 손들을 바라보던',
#  '운전수:(그냥 지나치는 사람을 발견하곤)아저씨, 차비 내셔야죠?',
#  '하며 운전수가 노려보면, 가방을 메고 지나쳐 가다가 뒤돌아보는 꼴통, 특유의 인상을 긁으며 들고있던 볼펜을 운전수에게 내민다. 시선을 피하며 차를 출발시키는 운전수, 꼴통, 버스 가운데쯤에 서서 가방을 털썩 내려놓더니 볼펜 한자루를 치켜들며',
#  '꼴통:(뒤뚱뒤뚱 인사를 하고)차 안에 계신 신사, 숙녀 여러분 안녕하십니까. 저는 홧김에 폭력, 겁도 없이 유괴, 불타는 가슴으로 강간 등 도합, 전과 십이범으로 얼마전에 출소한 대책없는 어린양입니다.(시선을 피한 승객들에게 볼펜을 한자루씩 올려놓으며)아픈 과거는 잊고 꼬딱지만한 포장마차라고 장만할까하니, 액땜한다 생각하시고 가볍게 지갑을 열어주시기 바랍니다. 여러분의 가정에 불행이 없기를 간절히 소망하며(볼펜을 들어보이며)이 볼펜을 단돈 삼천원에 드리겠습니다. 감사합니다.',
#  '인사를 하고는 돈을 거둬들이려 돌아다니는 꼴통, 험악한 인상을 써보이자 순순히 돈을 주는 아가씨. 깐깐해 보이는 남자가 볼펜을 돌려주자',
#  '꼴통:난 열받으면 입보다 주먹이 먼저 나가는 놈이지요.',
#  '하며 사내 앞으로 주먹을 내밀자, 얼른 지갑에서 돈을 꺼내 주는 사내. 이번엔 꾸벅 꾸벅 졸고 있는 고등학생에게 다가가',
#  '꼴통:(툭툭)야, 야!',
#  '하지만 깨지 않자 뒷통수를 퍽퍽치며',
#  '꼴통:임마, 자는 척 하지마.',
#  '학생:왜 그러세요?',
#  '꼴통:삼천원 내.',
#  '학생:왜요?',
#  '꼴통:내라면 내, 빨리 안내!',
#  '고등학생이 돈을 꺼내자 다음으로 넘어간다. 꼴통, 아이를 안고 창밖을 보는 척 하는 아줌마를 보곤 아이의 머리를 쓰다듬으며',
#  '꼴통:아이구 귀여워라.',
#  '아줌마, 돌아보자',
#  '꼴통:저는 겁도 없이 "유괴"를 두 번이나 했던 죽일 놈이지요.',
#  '하며 이번엔 겁먹은 아이의 볼을 살짝 꼬집는다. 아줌마, 얼른 손에 쥐고 있던 돈을 주며 아이를 끌어안는다. 꼴통, 몇몇 사람에게 순순히 돈을 받으며 뒷자리로 향하다가 버스 안에서 일어난 사태를 전혀 의식하지 못한 채 귀엔 이어폰을 끼고 창 밖을 보며 뭔가를 메모하고 있는 한 여자 앞에 다가선다. 꼴통, 다짜고짜 그녀의 어깨에 손을 올려놓고 특유의 인상을 긁으면 깜짝 놀라 돌아보는 긴 생머리의 시원스런 얼굴의 여자, 바로 이 영화의 신임 여형사인 최형사다.',
#  '꼴통:나는 "강간"도(하며 여자의 머리카락을 배배 꼬며)세 번이나 했던…',
#  '어이가 없어 쳐다보는 최형사가 겁이라도 먹은 줄 알고 핸드백을 자기 손으로 열어 돈을 꺼내려다간 수갑, 권총을 발견하곤 굳어지는 꼴통, 하지만 상대가 여잔지라 표정을 다시 정리하며',
#  '꼴통:너 경찰야? 잘 만났다. 난 경찰이라면 이가 갈리는 놈이야!',
#  '순간, 턱! 쪼인트를 맞는 꼴통, 신음과 함께 고개를 치켜들며',
#  '꼴통:어쭈? 쳤어? 이게 내가 누군지 알고…',
#  '하지만 말이 끝나기도 전에 곧장 날아오는 최형사의 주먹에 퍽! 뒤로 나자빠진다.',
#  '꼴통:으…(코피를 쓰윽 닦더니, 질겁하곤 일어나며)피잖아? 이 씨!(웃통을 벗으며)끼어드는 놈 있으면 죽여버릴꺼야!',
#  '겁에 질려 피하는 사람들.',
#  '꼴통:(괜히 버스를 머리로 받으며)씨발, 사고치기 싫다니까, 내 인생은 왜 이렇게 꼬이는 거야?(휙 손가락으로 가리키며)이건 니 잘못이야!',
#  '하며 최형사를 향해 저돌적으로 돌진하는 꼴통! 하지만 달려오는 꼴통을 멋지게 업어치기로 받아넘기는 최형사. 꽈당! 버스 바닥이 찌그러질 정도로 떨어지는 꼴통이다. 꼴통, 자신의 K.O 패를 인정하곤 최형사를 향해 두손을 모아 빌며',
#  '꼴통:아이고, 제가 그만 흥분을 해서……',
#  '최형사, 표정조차 변하지 않은 채 뚜둑 뚜둑, 몸을 풀며 다가선다.',
#  '꼴통:(휘둥그레지며)아니 왜 이러세요? 잘못 했다구요!',
#  '최형사:(멱살을 잡아 일으켜 세우며)아직 안 끝났어!',
#  '씬 2 거리',
#  '달리는 버스에서 과장되게 들려오는 꼴통의 비명소리. 퍽! 퍽! 우두둑! 맞는 소리와함께 좌우로 요동치는 버스. 우지끈! 어딘가 부러지는 듯한 소리와 함께 끼이익 멈춰서는 버스 위로 덥치는 타이틀―<투캅스 3>',
#  '씬 3 어느 집 거실',
#  '자막이 사라지면 선행하는 초인종 소리 속에―',
#  '화면 가득 현관문의 반투명 유리로 남자의 형체가 보이는 속에 끼리릭～끼리릭～ 소리와 함께 문고리가 탁! 하며 위로 젖혀지면, 스르르 열리는 문으로 들어오는 구두에서부터 카메라 틸업하면, 손에 목장갑을 낀 사내가 열고 있는 문으로 흑장갑을 낀 사내가 쌕을 맨 채 들어온다.',
#  '흑장갑이 날카로운 눈매로 고개를 휙 저으면 빠르게 움직이는 목장갑, 방문들을 열어보다가 어느 방 앞에서 흑장갑을 보며 고개를 끄덕이면 그곳으로 걸어가는 흑장갑.',
#  '씬 4 동 방안',
#  '금고에 청진기를 댄 채 번호판을 돌리고 있는 흑장갑 뒤로 각종 그림, 도자기 등이 널린 방의 서랍 따위를 뒤지고 있는 목장갑, 천원짜리 몇 장과 은장도, 씨거, 엽전 등을 쌕에 넣다가 흑장갑의 눈치를 보며 몰래 천원짜리를 주머니에 챙기기도 하는 목장갑.',
#  '흑장갑:(청진기를 댄 채)한 껀 했다고 돈 함부로 쓰지 마라. 상법이가 왜 잡혔는지 아나? 돈 생겼다고 친구들 데리고 룸싸롱에서 쭉쭉빵빵 죽이는 년들 끼고 술 졸나게 퍼마셨지, 근데 이 친구란 새끼들이 아침에 해장국 먹는데 갑자기 이런 생각이 든 거야. 자기들은 어제 한 번 얻어먹었지만 저 새낀 그런 데서 맨날 처먹을 꺼라고 생각하니 괜히 열받잖아? 씨발, 그래서 경찰에 수상한 놈 있다고 찔러서 잡힌거다. 절대 친한 놈들한테 돈쓰지 마라, 알겠냐?',
#  '목장갑:예.',
#  '흑장갑:안본다고 꼬불칠 생각하지 마라, 나중에 죽는다.',
#  '목장갑:(주머니에서 돈을 꺼내며)예.',
#  '하며 다시 천원권 지폐를 꺼내 쌕 안으로 밀어 놓는다. 딸칵! 소리와 함께 미소지으며 금고 손잡이를 잡아 천천히 여는 흑장갑. 목장갑, 재빨리 뒤로 다가온다. 흑장갑, 미소지은 채 금고를 열다간 잉?～ 표정이 확 변한다.',
#  '뒤어어 고개를 들이미는 목장갑의 표정도 확 굳어서 보면, 열린 문 안으로 금고가 하나 더 보인다.',
#  '목장갑:씨발…. 이 새끼는 금고장사하나?',
#  '흑장갑:아니, 도굴꾼이야.',
#  '목장갑:예? 그게 뭡니까?',
#  '흑장갑:몰래 남의 무덤 졸나게 파서 골동품 챙겨다가 팔아먹는 놈이지.',
#  '목장갑:한마디로 벼락맞을 새끼들이네요.',
#  '흑장갑:자방출장 간걸 보면 또 어떤 놈 무덤 졸나게 파고 있을거야.',
#  '씬 5 동 밖',
#  '끼이익! 멈추는 봉고에서 박스 등을 들고 내리는 도굴꾼들. 제법 큰 집의 대문을 열고 짐을 들고 조심스레 안으로 들어가는 속에 그 뒤로 멈춰서는 차. 열리는 차문에서 내리는 누군가의 발에서 틸업하면 바로, 우리의 이형사가 도굴꾼들을 보며 빠르게 다가간다.',
#  '씬 6 동 안',
#  '다시 청진기를 대고 있는 흑장갑 뒤로 시계를 보고 있는 목장갑.',
#  '목장갑:형님, 근데 안에 금고 하나 더 있으면 어떡하죠?하자 휙 보는 흑장갑, 목장갑의 머리, 배 따위를 마구 팬다.',
#  '흑장갑:재수없는 소리하지마, 임마, 안에 금고 또 있으면 너가 죽을줄 알아.',
#  '하고는 금고 문을 여는 순간, 또 다른 금고가 있다.',
#  '흑장갑:(목장갑을 팰 듯이 가며)이리와, 새꺄.',
#  '하는 순간 현관문이 열리는 소리가 들리자 표정이 굳는 흑장갑과 목장갑, 문쪽을 바라본다.',
#  '씬 7 동 거실',
#  '문을 열고 들어오는 도굴꾼1, 뒤돌아보며',
#  '도굴꾼1:조심해, 얼마짜린 줄 알아?',
#  '무거운 듯 박스 등을 들고 들어오는 도굴꾼2, 3, 4 의 모습 속에 들리는',
#  '소리: (이형사의)꼼작마! 경찰이다!',
#  '휙 뒤돌아보는 도굴꾼들, 인상이 확 변하더니 어느새 안으로 뛰어들어오는 이형사에게 박스를 던지지만 피하는 이형사 뒤의 벽에 맞고 깨지는 도자기. 도굴꾼 2, 3, 4. 이형사를 향해 칼, 호미, 삽 따위를 휘두르며 공격해보지만 뒷걸음질치는 도굴꾼1, 뒷편의 방으로 도망간다.',
#  '씬 8 동 방안',
#  '문을 열고 들어오는 도굴꾼1, 창문을 뛰어넘어 도망가는 흑장갑, 목장갑을 보곤',
#  '도굴꾼1:너희들 뭐야?',
#  '하곤 곧장 흑·목이 도망간 창문으로 뛰어나가면 곧이어 들어오는 이형사, 재빨리 창문으로 뒤쫒아간다.',
#  '이형사:거기서!',
#  '씬 9 어느 골목',
#  '쫓아가는 이형사 앞으로 도굴꾼1이 달리고, 그 앞으로 도망가고 있는 흑장갑과 목장갑에게로 쫓아가는 카메라.',
#  '이형사:(달려오며)거기서!',
#  '도굴꾼1:(도망가며, 앞을 보고)야, 이 도둑놈 새끼들아! 감히 누구 집을 털어?',
#  '목장갑:(뒤돌아보며)훔치지도 못했어, 임마.',
#  '흑장갑:(뒤돌아보며)새꺄, 자꾸 우리 따라오지마! 딴 데로 가!',
#  '다시 뒤따라오는 도굴꾼과 이형사를 보여주는 카메라.',
#  '도굴꾼1:(이형사에게 뒤돌아보며)저 새끼들도 도둑놈이예요.',
#  '이형사:일단 너부터 잡을꺼야!',
#  '흑장갑, 길 한켠에 놓인 휴지통을 옆으로 밀치고 뛰면 피하려던 도굴꾼1이 몸을 트는 사이 뒤에서 점프해오는 이형사, 도굴꾼1을 덥치며 뒹군다.',
#  '이형사에게 잡히는 도굴꾼1을 보며 씨익 미소지은 채 도망가는 흑·목장갑 옆으로 스쳐 지나간 차가 도굴꾼1에게 수갑을 채우는 이형사 앞에서 끼이익! 멈춰서 빵빵 클락션을 울려대는 차안의 여자운전수. 짜증스레 40대의 여자운전수를 바라보는 이형사와 도굴꾼1.',
#  '씬 10 경찰서 사무실',
#  '수갑을 찬 도굴꾼들을 툭툭 치며 들어오는 이형사, 다른 경찰에게 도굴꾼들을 유치장 쪽으로 인계하는데',
#  '형사1:또 한껀했나? 하루도 그냥 넘어가는 날이 없구만.',
#  '이형사:예 써.(빈 자리를 보곤)아직 안왔습니까? 첫날부터 자각이야?!',
#  '형사1:아? 신참? 차가 막히나 보지? 참, 자네 파트너 이야기 들었나?',
#  '이형사:아뇨.',
#  '이때 엉망인 몰골로 수갑을 찬 채 뛰어들어오는 꼴통, 정신이 없는지 이곳저곳을 살피며',
#  '꼴통:악! 사람살려!',
#  '경찰1:(꼴통을 보곤)저 자식은 볼때마다 인상이 더러워져?',
#  '꼴통:(다가와선)이형사님! 제발, 살려주세요.',
#  '이형사:가석방 된지 몇 일 됐다고 또 들어왔어?!',
#  '꼴통:(울먹이며)제발 살려만 주세요, 완전히 마녀예요.',
#  '하는 순간 뒤에서 다가와 꼴통의 뒷덜미를 잡는 최형사.',
#  '최형사:이리와!',
#  '꼴통, 울먹이며 최형사에게 후다닥 뛰어가면',
#  '이형사:누굽니까?',
#  '형사1:몰라? 자네의 새로운 파트너잖아?',
#  '이형사:예?!',
#  '다른 경찰에게 꼴통을 넘기는 최형사의 늘씬한 다리에서부터 얼굴까지 쭈욱 훑어보고는 불만이 가득한 표정으로 바뀌는 속에',
#  '형사1:(최형사를 보며)잘 빠졌는데? 몇 일 버틸까?',
#  '형사2:(이형사를 보며 슬쩍 만원을 꺼내며)일주일. 어? 이형사, 어디가?',
#  '이형사:(일어나 가며)과장님 계시지요?',
#  '형사2:응.(만원을 꺼내며)내일.',
#  '씬 11 동 과장실',
#  '화면 가득 책상위로 내민 흰 봉투를 집어드는 과장, 맞은 편에 서있는 이형사를 보며',
#  '과장:이게 뭐야?',
#  '이형사:파트너 바꿔 주십시오, 아니면 사표 내겠습니다.',
#  '과장:뭐어～?!',
#  '이형사:요즘 강력사건이 얼마나 많이 발생하는데 여자를 붙이시면 어떡합니까?',
#  '과장:임마. 그래도 이번에 경찰학교 수석 졸업했어.',
#  '이형사:요즘엔 수석을 아무나 하나보죠?',
#  '과장:여자라고 우습게 보지 말고 앞으로 잘 해봐.',
#  '이형사:안됩니다. 수사하다가 갑자기 사랑 때문에 질질 짜고, 중요한 놈을 체포하려는 순간에 생리라도 하면 어떡합니까? 당장 바꿔 주십시오.',
#  '과장:이 자식이 싸움 잘한다고 봐줬더니…. 알았어.',
#  '이형사:예? 정말 그만 둔다니까요.',
#  '과장:수리했다니까 임마, 짜식이 건방지게 인사권까지 참견하려해? 당장 나가, 임마.',
#  '이형사:과장님!',
#  '과장:(밀치며)관둘려면 관둬! 임마, 나가서 짐이나 싸! 어서!',
#  '씬 12 달리는 차 안',
#  '운전을 하는 이형사, 그 옆에 창밖을 보는 최형사.',
#  '이형사:(화난 듯)경찰학교 수석졸업, 정말이야?!',
#  '최형사:예. 선배님이 세운 기록도 깼습니다.',
#  '이형사:그래?(다시 한번 보곤)대책없이 인심이 좋아졌군. 근데 경찰 학교엔 왜 갔나? 조용히 시집이나 가지!',
#  '최형사:(휙 보며)선배님, 제가 온 게 불만입니까?!',
#  '이형사:(힐끗보며)자넬 위해서 하는 소리야. 여잔 자고로 남편 사랑 받으면서 집안 일이나 하는 게 최고야. 안그래?',
#  '최형사:(노려보며)항상 그렇게 여자를 무시합니까?',
#  '이형사:경찰 일이란게 사기꾼, 강간범, 도둑놈, 깡패 같은 놈들의 더러운 꼴만 보는 거야. 여차하면 놈들이 휘두른 쇠파이프에 뼈가 부러지고, 칼에 찔리고, 무식한 놈은 도끼까지 들고 설쳐대서 병신되기 쉽상이지. 사랑이고 결혼같은 건 꿈도 못꿔.',
#  '최형사:알고 있습니다.',
#  '이형사:그래? 그럼, 당장 그만둬. 뭐할려구 해?',
#  '최형사:근데 어쩔 수 없어요. 팔자예요.',
#  '이형사:뭐?',
#  '최형사:타고난 운명이라구요. 태몽에서부터 용하다는 점쟁이들까지 모두 제가 사회의 악을 처단하는 강직한 전사같은 삶을 살꺼랬어요.',
#  '이형사:태몽?',
#  '최형사:한 손엔 불과 다른 손엔 칼을 쥐고 있었대요.',
#  '이형사:불과 칼이라…. 그럼 주방장 아닌가?',
#  '최형사:(경멸하듯 바라보며)….',
#  '최형사와 이형사, 서로를 바라보는데 이형사 뒷편으로 소매치기가 어느 아줌마의 지갑을 낚아채 도망가는 모습이 보인다.',
#  '최형사:차 세워요!',
#  '하면 끼이익～ 선행하는 브레이크 소리와 함께―',
#  '씬 13 어느 시장통',
#  '핸드백을 쥔 채 빠르게 도망가는 놈을 쫓아가는 최형사.',
#  '최형사:거기서!',
#  '사람들을 부닥쳐가며 도망가는 놈을 거의 잡기 직전, 놈이 밀친 아이를 피하려다 다른 곳에 부닥치며 넘어지는 최형사. 멀어져가는 놈, 여유 띤 미소를 짓는데 불쑥 나타난 누군가의 발에 걸려 넘어지고 만다. 넘어진 놈의 뒷덜미를 낚아채는 이형사.',
#  '이형사:(일어나는 최형사에게 다가가)역시 여자라 별 수 없군. 범인 체포의 기본을 달리기야! 그렇게 뛰어서 누굴 잡겠나?',
#  '하며 여유를 부리는데 눈치를 보던 놈, 이형사의 팔을 쳐내곤 다시 도망간다. 순간, 몸을 날리는 최형사, 놈을 덥치며 넘어뜨린 뒤 핸드백을 감아쥔 놈의 손목을 잡아 우두둑 꺽어버린다. 비명을 지르는 놈. 놀란 듯 바라보는 이형사.',
#  '최형사:(수갑을 채우며)이런 놈들을 잠시도 방심하면 안되죠. 다음부턴 주의하세요.',
#  '하며 놈을 끌고가는 최형사를 뻥찐듯 바라보는 이형사다.',
#  '씬 14 햄버거 집 안',
#  '햄버거를 가져와 앉는 이형사 맞은 편에 있는 최형사.',
#  '이형사:팔까지 부러뜨릴 필요는 없었잖아?',
#  '최형사:눈에는 눈, 이에는 이. 나쁜짓을 한 놈은 다신 그 짓을 못 하게 만들어 놔야 범죄 재발을 막을 수 있습니다.',
#  '이형사:(햄버거를 먹으며)그래서?',
#  '최형사:(햄버거 안에 있는 고기, 치즈 등을 빼내며)도둑질 한 놈은 손가락을 부러뜨리고, 공갈협박한 놈은 다신 입을 못 놀리게 하는 거죠.',
#  '이형사:그럼 강간한 놈은?',
#  '최형사:거길 잘라버려야죠.',
#  '이형사:말은 잘하는군. 근데 뭐하는거야? 다이어트 하나? 여자들은 그래서 안되는거야. 잘먹고 운동할 생각해야지, 안먹고 운동도 안하니까 비실비실 하잖아? 정말 한심해서……',
#  '최형사:저도 그렇게 보입니까?',
#  '이형사:(먹으며)응.',
#  '씬 15 어느 곳',
#  '멈춰서는 차에서 내리는 이형사와 최형사.',
#  '이형사:관내에서 발생한 연쇄 강도범들이야. 목숨 아까운 줄 모르는 살벌한 놈들이지.',
#  '최형사:지원요청은 하셨습니까?',
#  '이형사:(손가락을 두둑거리며)혼자 몸풀기에도 모자라.(어깨를 짚으며)위험하니까 최형사는 안에서 콜라나 마셔. 김빠지기 전에 돌아오지.',
#  '씩씩하게 건물 쪽으로 들어가는 이형사를 바라보는 최형사.',
#  '씬 16 마약 아지트 안',
#  '꽝 문을 박차고 들어오는 이형사를 보고 놀라는 마약상들.',
#  '마약상1:튀어!',
#  '이와 동시에 역동적으로 보여지는, 가방을 들고 튀는 마약상1 뒤로 칼, 쇠파이프 따위를 쥔 채 도망가는 마약상 2, 3, 4, 5. 쫓아오는 이형사를 보곤 마약상 4, 5가 이형사에게 칼, 쇠파이프 따위를 휘두르며 공격해보지만 이형사의 화려한 액션에 나가떨어진다. 이형사, 마약상 1, 2, 3이 나간 뒷문으로 뒤쫓아나간다.',
#  '씬 17 동 밖',
#  '문을 열고 나오는 이형사, 작은 골목으로 꺽어 들어가는 마약상 1, 2, 3의 뒤를 쫓아 달려간다. 달리는 이형사의 모습 위로 들리는 꺄악! 한 여자의 비명소리와 함께 우당탕! 퍽! 쾅! 하는 소리에 아차～ 하는 생각이 드는 이형사.',
#  '이형사:가만있으라니까, 이런 멍청한!',
#  '하며 총을 꺼내며 달려가는 이형사.',
#  '씬 18 동 다른 골목',
#  '총을 빼든 채 달려오는 이형사.',
#  '이형사:꼼짝마!',
#  '하고 둘러보면, 한 여자가 겁에 질린 채 웅크리고 있는 옆에서 놈들이 널부러져 있고 최형사가 한 놈에게 수갑을 채우고 있다.',
#  '최형사:아직도 비실비실해 보이나요?',
#  '이형사:제법하는데? 죽도록 노력하면 한 5년 뒤엔 내 수준 근처까지 오겠어.',
#  '최형사:선배님도 제가 오기 전까진 제법한다는 말 많이 들었겠는데요?',
#  '이형사:호? 좋아. 자신감이 대단하군. 어디 한 번 제대로 해보겠나?',
#  '최형사:처단해야 할 놈들이 있는 곳이라면 어디든지요!',
#  '이형사:좋아! 렛츠 고!',
#  '최형사:오케이!',
#  '씬 19 거리(N)',
#  '경쾌한 음악 속에 화려한 밤거리를 씩씩하게 걸어가는 투캅스. 호객행위를 하던 삐끼들이 이형사를 보고 숨기도 하고, 중년의 사람(사장)들이 반갑게 인사도 건네고, 덩치들이 서로 패싸움이라도 하려는 듯 각목, 철봉, 체인 등을 들고 숨기고 쩔쩔매는 표정으로 90도로 인사를 하기도 한다. 이런 사람들을 보며 고개를 끄덕이며 지나가는 이형사를 어이없는 표정으로 보던 최형사.',
#  '최형사:경찰하기 전에 깡패였어요?',
#  '이형사, 이런 최형사를 인상을 쓴 채 쳐다본다.',
#  '씬 20 나이트 클럽 안',
#  '터져 나오는 음악과 휘황찬란하게 돌아가는 조명 속에 춤추는 사람들 너머로 보이는 투캅스.',
#  '이형사, 유리로 된 룸 안에 보이는 많은 건달들 가운데에 있는 험악하게 생긴 한명을 가리키며',
#  '이형사:김한철! 폭력전과 10범에 수배중이지. 혼자 잡을 수 있겠나?',
#  '최형사:맥주나 마시세요. 김빠지기 전에 잡아올게요.',
#  '하며 씩씩하게 걸어간다. 점점 가까워지는 룸 안의 모습을 보면, 미니스커트들을 끼고 십 여명의 우락부락한 건달들이 술을 마시고 그 앞에 웨이터 두명이 완전 쫄아서 90도 씩 절을 해대고 있다. 최형사, 긴장한 듯 심호흡을 하는 모습 뒤로 저 편에서 이형사가 씩 쪼개며 바라보고 있다. 몸을 두둑이며 룸으로 천천히 걸어가는 최형사. 이때, 룸에서 나온 웨이터가 다짜고짜 최형사의 팔을 잡는다.',
#  '웨이터:아가씨, 나 좀 살려주세요.',
#  '최형사:왜 이래요?',
#  '웨이터:제발 살려주세요. 부킹 한번만 해요 부킹. 부킹.',
#  '최형사:어?',
#  '최형사의 팔을 잡고 룸 안으로 데리고 들어가는 웨이터, 최형사를 룸에 밀어놓고는 재빨리 빠져 나와 안도의 한숨을 쉰다. 건달들, 최형사를 보며 고개를 끄덕이기도 하며 어깨에 손을 올리자 휘 쳐다보는 최형사.',
#  '건달1, 덥썩 최형사를 안는 순간 빠르게 올라가는 최형사의 무릎이 그곳을 강타한다. 읔, 신음을 내며 내려앉는 건달1을 잡는 최형사, 입구의 문으로 내던져버린다. 와장창! 유리문을 박살내며 나자빠지는 건달1. 손에 칼과 병 따위를 들고 벌떡 일어나는 건달들, 까약! 비명을 내지르며 나가는 미니스커트들 옆으로 병을 들고 설쳐대는 건달2의 팔목을 병으로 내리치는 손, 비명을 지르는 놈을 내차는 발. 많은 건달들에 맞서 홀홀 단신으로 싸우는 최형사. 겁에 질린 사람들, 비명을 지르며 뒤로 물러나는 뒤로 저 편에 이형사가 팔짱을 끼고 서서 바라본다. 최형사를 향해 공격해 들어가는 건달들, 하지만 최형사의 무자비하리만치 강한 몸놀림에 하나 둘 쓰러진다. 테이블을 부수고, 디제이박스를 박살내며 날아가는 놈들. 물러나있던 사람들이 탄성을 지르며 하나 둘 앞으로 다가와 구경하는 속에 서있는 이형사.',
#  '사람1:와… 저 여자 죽이는데?',
#  '사람2:정말 폼 나는데! 끝내준다. 끝내줘 햐……',
#  '이런 사람1, 2와 최형사를 번갈아가며 보는 이형사. 이때 최형사 뒤에서 한놈이 칼을 휘두르는 순간 퍼벅! 내리치며 싸움판에 끼어드는 이형사.',
#  '최형사:(한놈을 해치우곤)도망가는 놈들이나 잡으라니까 왜 끼어들어요?',
#  '이형사:도와줘도 잔소리군!',
#  '하며 다시 사람들 사이로 들어가는 이형사. 최형사에게 건달들이 쓰러져 나가자 안되겠는지 보스인 듯한 놈이 사람들을 헤집고 뒷문으로 도망간다.',
#  '최형사:뭐해요?!',
#  '이형사, 인상을 구기곤 사람들 사이로 튀어나가면 뒤따라 나가는 최형사.',
#  '씬 21 동 밖',
#  '허겁지겁 튀어나오는 최형사와 이형사. 보면 저 편에서 차를 막아 세우며 운전수를 밀쳐내는 보스. 달려가는 이형사, 보스를 향해 점프하지만 문을 닫고 안으로 들어가는 보스, 쓰러진 이형사 옆으로 휭하니 차를 몰고 가버린다. 넘어진 이형사 옆으로 곧장 끼이익 멈춰서는 차안에 최형사가 보인다. 이형사가 타면 급출발하는 차.',
#  '씬 22 도로',
#  '끼이익! 빠르게 달리는 투캅스의 차. 다른 차들은 이리저리 젖히다간 급회전해 반대편 차선으로 달린다.',
#  '씬 23 차 안',
#  '마주보고 달려오는 차들의 클락션을 울려대는 속에 당황해하는 이형사와 결의에 가득찬 최형사의 표정속에―',
#  '씬 24 도로',
#  '엉망진창으로 뒤엉키는 차들 속에 달려가는 투캅스의 차. 오른쪽으로 보이는 차안에서 놈이 힐끗 보곤 핸들을 꺽는 순간 끼이익! 급회전하며 부닥쳐 들어오는 투캅스의 차. 끼이익! 쿵! 부닥치면서 다른 도로로 급회전해 들어간다.',
#  '씬 25 차 안',
#  '공사중인 도로의 가설대를 밀쳐내며 놈의 차와 들이받는 속에',
#  '이형사:혹시 최형사도 폼 나니까 경찰한건가?',
#  '최형사:그런 정신나간 놈도 있나요?',
#  '인상이 팍 구겨지는 이형사.',
#  '씬 26 도로',
#  '투캅스의 차를 뒤로한 채 끼이익! 도로 가로수를 들이받으며 멈춰서는 차. 허겁지겁 내리는 보스, 어느 쇼핑타운 안으로 뛰어들어간다.',
#  '씬 27 달리는 차 안',
#  '인도를 보며 액셀레이터를 밟는 최형사. 이형사, 휘둥그레지며',
#  '이형사:안돼, 멈춰!',
#  '하지만 최형사는 결의에 찬 얼굴로 밀어 부친다.',
#  '씬 28 쇼핑타운',
#  '밀고 들어오는 투캅스의 차에 비명을 지르며 피하는 사람들. 놈이 들어가는 쇼핑타운 안으로 곧장 밀고 들어가는 차. 쾅! 가제의 대형 쇼윈도우를 박살내며 멈춰서는 차. 보스, 힐끗 뒤돌아보곤 겁에 질린 채 내달음친다. 차에서 튀어나오는 최형사.',
#  '최형사:(달려가며)거기서!',
#  '최형사 뒤로 천천히 삐그덕 열리는 문으로 거의 넋이 나간 듯 나오는 이형사.',
#  '이형사:헉……?',
#  '씬 29 동 건물 안',
#  '도망가는 보스를 향해 저돌적으로 달려가는 최형사. 꺄아악! 비명을 내지르는 사람들 사이로 달려가는 보스와 최형사. 간격이 좁혀지자 힘껏 점프해 보스를 덥치는 최형사. 다른 가게문을 박살내며 뒹구는 두사람. 보스, 어느 틈엔지 칼을 꺼내들고 최형사를 향해 휘두른다. 멋지게 보스를 쓰러뜨리는 최형사. 보스의 팔을 내리치고, 다리를 우지끈 차버린다. 비명을 지르며 완전 맛이 간 보스의 목이라도 확 꺽어버릴 듯 하는 최형사를 보곤 질겁한 채 달려오는 이형사.',
#  '이형사:안돼!',
#  '하며 최형사를 덥친다.',
#  '바닥에 최형사를 덥친 채 엎어지는 이형사의 모습 속에서―',
#  '씬 30 경찰서 과장실',
#  '인상을 쓴 채 버럭 버럭 고함을 질러대는 과장 앞에 고개를 숙이고 있는 이형사와 최형사.',
#  '과장:도대체 뭐하는 거야!(서류를 들어 보이며)나이트클럽, 자동차 8대에 쇼윈도우까지 전부 얼만지 알아?',
#  '이형사:(고개를 숙인채)….',
#  '과장:지금 전쟁났어?! 기다렸다가 나올 때 잡으면 그 자식이 썩어 없어지기라도 해?',
#  '이형사:죄송합니다.',
#  '과장:(이형사에게)여자 신참 왔다고 너무 오버하지마! 임마. 안봐도 훤해! 감봉 10개월.',
#  '이형사:예 써.',
#  '과장:(최형사의 어깨를 토닥이며)오자마자 하필 이런 놈 만나 억울하겠지만 할 수 없네. 감봉 1개월. 미안해 최형사.',
#  '최형사:(앞으로 한발 나서며)과장님. 똑같이 징계내려 주십시오. 저도 10개월로 하겠습니다.',
#  '과장:뭐? … 최형사는 이쁜데다가 의리까지 있구만.',
#  '이형사:아닙니다. 상사인 제 잘못이 더 큽니다. 모두 제가 책임지겠습니다.',
#  '과장:(이형사에게)나도 그러고 싶어. 임마! 최형사를 봐서 징계문제는 더 가벼운 걸로 위에 건의해 보지.',
#  '최형사:예. 고맙습니다.',
#  '이형사:(과장과 최형사를 번갈아보며)….',
#  '과장:(최형사의 어깨를 다독이며)차근차근 일 배우고(이형사의 귀를 잡아당기며)성깔 좀 죽여! 알겠어?',
#  '씬 31 동 사무실',
#  '과장실 문을 열고 나오는 투캅스.',
#  '최형사:죄송해요, 선배님. 저 때문에…',
#  '이형사:아니, 괜찮아. 가지.',
#  '최형사:어딜요?',
#  '이형사:(손을 두두둑거리며)일해야지.',
#  '씬 32 대연회장 입구',
#  '<신영회 단합대회>라는 플랭카드가 걸린 대연회장의 주차장에 정차하는 차에서 내리는 이형사, 뒤따라 나오는 최형사를 보곤',
#  '이형사:이번엔 내 차례야.',
#  '최형사:네?',
#  '이형사:자네는 구경이나 하고 있어.',
#  '하고 걸어가는 이형사에게 다가오는 중년의 사장.',
#  '사장:(제지하듯 손을 내밀며)오늘은 예약손님만 받습니다.',
#  '이형사:(형사증을 내보이며)…',
#  '사장:아니, 저 형사님…',
#  '하는데 다가오는 양복차림의 건달 1, 2.',
#  '건달1 :뭐야?',
#  '하며 다가오는 건달1, 2를 보곤 곧장 퍼버벅! 주먹으로 눕히곤 안으로 들어가는 이형사.',
#  '씬 33 동 연회장 안',
#  '문을 열고 들어오는 이형사 뒤로 다가오는 사장.',
#  '사장:형사님… 여기서 이러지 말고 있다가….',
#  '이형사, 그런 사장을 밀치고 보면, 폭력 조직인듯한 놈들이 좌악 줄지어 앉아 있다가 일제히 휙 바라본다. 건달3의 고개짓에 따라 이형사를 향해 일제히 일어나는 건달들. 이형사, 손을 두두둑 거리며 미소를 지은 채 놈들에게 다가가면 울상이 된 채 이 모습을 바라보는 사장 뒤로 최형사가 들어온다.',
#  '야～아! 기합을 내지르며 덩치 좋은 건달들이 화면을 향해 달려온다. 순간, 구둣발 하나가 치솟아 오르더니 건달의 면상을 강타한다. 쿵! 어느 테이블을 박살내며 나자빠지는 건달. 보면, 이번엔 더 많은 놈들이 이형사를 향해 쇠파이프, 야구 방망이, 회칼 등을 들고 공격해온다. 이리저리 몸을 날리면서 놈들을 쓰러뜨리는 이형사. 순식간에 아수라장이 되는 연회장. 히익～ 울상이 된 채 바라보는 사장, 누군가가 던진 칼과 날아오는 몽둥이에 카운터 아래로 몸을 숙인다. 쿵! 쾅! 퍽! 부러지고 맞고, 박살나는 소리 속에 사장 주변으로 날아오는 온갖 병, 의자, 건달 등에 일어서려다 번번히 몸만 피하는 사장. 뒷편에서 지켜보던 두목과 몇몇 부하들, 안되겠다 싶은지 뒷문으로 도망간다. 이형사, 그놈들을 쫓아가려는 순간 뒷문으로 앞장서 도망가던 부하1이 면상을 맞고 뒤로 나자빠진다. 칼을 휘두르며 나서는 부하2 또한 복부를 맞고 움찔하는 사이 누군가의 단수가 우두둑! 손목뼈가 부러질 정도로 내려친다.',
#  "악! 비명을 지르며 나자빠지는 부하2. 보면 두목과 부하들 앞을 최형사가 막고 서 있다. 이형사, 의외인 듯 바라보며 다가가자 움찔했던 두목 등 중 부하3이 쇠파이프를 휘두르며 공격해 보지만 이형사의 화려한 발차기에 와장창 진열대를 박살내며 뻗고 만다. 이형사, 어깨를 두둑거리며 어떻냐는듯 최형사를 바라보는 순간 최형사를 향해 발차기를 하며 공격하는 부하4, 최형사의 맞발차기에 우두둑! 다리뼈라도 부러진 듯 하더니 비명을 지르며 다른 테이블을 박살내며 쓰러진다. 이번엔 최형사가 고개를 돌려가며 어떻냐는듯 이형사를 본다 완전히 갇혀 버린 두목과 부하 등, 양쪽으로 나뉘어 공격을 한다. 최형사와 이형사, 마치 경쟁하듯 달려드는 놈들을 처치한다. 이형사, 체인을 들고 달려드는 놈을 몸을 슬쩍 숙여 피하곤 멋진 훅 한방으로 박살을 내곤 이형사를 보며 '봤지?' 이형사, '어쭈?' 하곤 달려드는 엄청난 덩치를 잡아 빗장걸이 한판으로 창문으로 내던지곤 '이건 안될걸!' 하곤 보면, 최형사, '겨우 그 정도야?' 하곤 더욱 엄청난 덩치를 업어치기해 또 다른 창문으로 확 던져 버리곤, '난 이정도야!'.",
#  "'으잉? 제게 여자야?'하며 보다간 달려드는 놈에게 턱을 한 대 얻어맞는 이형사, 열이 확 받은듯 휘돌려 차기로 처리하곤 머쓱한 얼굴로 최형사를 보다간 휘둥그레지는 이형사, 한놈이 최형사를 향해 라이트 훅을 날리고 있다. 최형사, 급히 한팔을 들어 막으며 놈의 턱을 강타하곤 이단 옆차기로 마무리를 하며 '어때요?' 수차례 한번씩 서로의 멋진 공격이 교차하자 마지막으로 남은 두목이 둘 사이에 울상으로 서 있다. 최형사와 이형사가 마지막 남은 두목을 향해 동시에 주먹을 내지르려면, 털썩 바닥에 무릎을 꿇고 살려달라는 두목 위로 서로가 뻗은 주먹을 잡고 있는 최형사와 이형사, 서로를 노려본다. 이런 투캅스의 모습이 원경으로 보이면, 대롱대롱 매달린 형광등에 박살난 테이블, 의자, 깨진 유리창 등 완벽하게 폐허가 되버린 연회장의 모습이 과장되게 보여진다.",
#  '씬 34 경찰서 과장실',
#  '이형사의 멱살을 잡고 있는 과장.',
#  '과장:차라리 날 죽여라, 죽여. 야 이 인간아. 파트너 안바꿔준다고 나 짤리게 만들려는거지? 응?!',
#  '이형사:(고개를 숙인 채)죄송합니다.',
#  '과장:(마구 흔들며)이게 죄송하다고 될 일이야?! 나까지 감봉당했어, 인간아!?',
#  '씬 35 이형사 집 앞(N)',
#  '단아한 한옥 대문 옆의 초인종을 누르는 이형사.',
#  '소리: (엄마의)누구세요?',
#  '이형사:접니다. 경찰.',
#  '삐 소리와 함께 문이 열리면 안으로 들어가는 이형사.',
#  '씬 36 동 마당',
#  'ᄀ자 형태의 집에 작은 마당으로 걸어오는 이형사, 마당 한켠에서 태권도복을 입은 채 심호흡을 하더니 기왓장을 격파하는 아버지.',
#  '이형사:(지나치며)다녀왔습니다.',
#  '아버지:봤지? 응? 이제 여섯장까진 가뿐해. 어때? 내기 한번 할까? 응?',
#  '엄마:(마루에서 다가와)그만하세요. 태풍불면 지붕 날아가겠어요.',
#  '아버지:지붕이 중요해? 건강이 중요해?',
#  '이형사:(들어가며)들어가시죠, 아버지.',
#  '아버지:임마, 사내자식이 왜 젖은 풀빵처럼 축 늘어졌어?',
#  '씬 37 동 방안',
#  '군대용 식판이 놓인 술상에서 술잔을 90도로 절도있게 꺽어 들며 마시고 있는 아버지와 이형사.',
#  '아버지:야 이, 자식아 나가 죽어라! 죽어 내가 겨우 그 정도로밖에 못키웠어?',
#  '이형사:죄송합니다.',
#  '아버지:세상을 휘어잡아도 모자랄 사내놈이 그깟 여자하나 때문에 쩔쩔매다니….',
#  '이때 소주를 가져오는 엄마.',
#  '엄마:난 그래도 니가 일찍 오니 좋은데?',
#  '아버지:좋긴 뭐가 좋아?! 남자는 집에 있는 시간이 많을수록 밖에서 밀리는 법이야 하여튼 여자들은 단순하다니까!',
#  '엄마:요즘은 가정적인 남자가 성공한데요.',
#  '아버지:어떤 썩을 놈이 그런 말 해? 제발 티브이에서 하는 말 좀 믿지마! 응! 부자지간에 모처럼 이야기하는데 방해하지 말고 가서 노가리나 구워와.',
#  '으휴―. 눈을 흘기며 엄마가 일어나면 이형사에게 술을 따라주는 아버지.',
#  '아버지:임마, 여자는 초반에 기선 제압 못하면 끝장이야.',
#  '이형사:걘 자기가 쟌다르크인줄 알아요.',
#  '아버지:그래봤자, 여자야! 임마! 여자가 하자는 대로 일일이 받아주니까 피곤한거아냐? 임마.',
#  '이형사:그럼 어떻게요?',
#  '아버지:니 엄마 봐, 임마. 첨엔 대들더니 이젠 말 한마디면 되잖아? 임마! 상대방의 약점을 생각해! 여잔 여자일 수밖에 없다는 걸 보여줘. 알겠어?',
#  '이형사:아버님.',
#  '아버지:왜?',
#  '이형사:(두 손으로 잔을 들며)존경합니다.',
#  '아버지:(잔을 부닥치며)완 샷!',
#  '씬 38 고수부지',
#  '여명이 비추이는, 아직은 새벽인 고수부지에서 규칙적인 발소리에 따라 추리닝 차림으로 조깅을 하고 있는 이형사와 최형사.',
#  '이형사:(달리며)상쾌하지 않나? 좋은 경찰이 되려면 우선 체력이 강해야돼. 범인을 추적하다 보면 몇 일씩 밤새기 일쑤지.',
#  '최형사:(달리며)모처럼 같이 뛸 사람 있어서 좋은데요?',
#  '이형사:매일 조깅했나?',
#  '최형사:예 하루 10킬로씩요.',
#  '이형사:그으래?',
#  '최형사:이제 몸이 좀 풀리는데?',
#  '하며 빠르게 뛰어가는 최형사를 보며 달려가는 이형사.',
#  '씬 39 헬스장',
#  '땀에 젖은 채 헬스기구로 운동을 하는 투캅스. 서로 뒤지지 않을 듯 열심히 기구운동하는 모습이 보여진 뒤',
#  '이형사:(최형사를 보며)제법 하는데?(일어나는 최형사를 보곤)벌써 지친 건 아니지?',
#  '최형사:(다가와선)지치긴요?',
#  '하고 서로의 기구를 바꿔 운동하는 투캅스.',
#  '최형사:(기구로 운동을 하다간)할만 한데요? 좀 더 올려야겠군.',
#  '뒤지지 않고 이형사도 무게를 올린다. 투캅스, 땀에 뻘뻘 절은 채 서로를 노려보며 힘겹게 운동을 한다.',
#  '씬 40 수영장',
#  '출발점에서 수영복차림으로 몸을 풀고 있는 투캅스.',
#  '이형사:유연성과 지구력을 키우는덴 수영이 최고지. 열 번 왕복하고 한번 쉰다. 오케이?',
#  '최형사:그냥 하면 심심하니까 점심내기 할래요?',
#  '이형사:첫날부터 너무 무리하는 거 아냐?',
#  '최형사:(출발점에서 서며)괜찮아요. 어릴 적에 수영선수였어요.',
#  '인상이 찌푸려지는 이형사를 보며 수경을 쓰는 최형사. 동시에 풀로 점프해 들어가는 투캅스. 자유형으로 빠르게 허부적대는 이형사와 한참을 잠수한 뒤 불쑥 솟아오르는 최형사, 이형사를 한참 앞지른 채 헤엄친다.',
#  '자유형으로 꿋꿋하게 헤엄치는 이형사 맞은 편에서 버터플라이로 헤엄쳐오는 최형사, 중간에서 엇갈린 채 스쳐가는데',
#  '최형사:벌써 지친 건 아니죠?',
#  '여유만만하게 바라보면, 이를 악물고 지나쳐 가던 이형사가 으윽～ 다리에 쥐라도 난 듯 다리를 움켜쥔 채 물속으로 뽀르르 빠져든다. 최형사, 이런 이형사를 보곤 뒤돌아 헤엄쳐간다. 물 속에서 허부적거리는 이형사에게 다가가 물 속으로 더 쳐박아버리는 최형사, 힘이 빠진 듯 축 늘어지는 이형사를 보고서야 뒤에서 안은 채 밖으로 데려나간다.',
#  '씬 41 달리는 차 안',
#  '심각한 표정으로 말없이 운전을 하는 이형사, 하품을 쩌억 하다가 옆을 보면 최형사가 본다.',
#  '최형사:수영장에서부터 한마디도 안한 거 아세요? 아무리 여자한테 도움받았다 그래도 고맙단 말 정돈 해야되는 거 아녜요?',
#  '이형사:고마워.',
#  '최형사:(차를 한켠에 끼익 세우며)도대체 왜 그래요? 아침부터 불러내서 갑자기 조깅에, 헬스장에다 수영까지 강행군시키고. 그렇게 해서라도 날 그만두게 하고 싶은 거예요? 나랑 일하는게 그렇게 불편한가요?',
#  '이형사:좋아. 나도 최형사를 위해 솔직히 이야기하지. 최형사, 무술은 제법하는거 인정해. 하지만 그만둬. 아무리 개나 소나 경찰하는 세상이라지만 여자는 안돼. 경찰 일은 남자가 하는거야!',
#  '최형사:좋아요, 만약 여자가 해선 안되는 일이라면 그만두겠어요. 오케이?!',
#  '이형사:오케이!',
#  '씬 42 락까페 안',
#  '크지 않은 락까페에 음산한 음악에 맞춰 사람들이 북적거리며 오가고, 한켠에서 바라보는 이형사와 최형사.',
#  '이형사:여자들은 상황 판단이 느리지. 지금 이곳에서 무슨 일이 벌어지고 있나?',
#  '최형사:마약 거래군요.',
#  '이형사:잘찍는데? 어떤 놈인지 알겠나?',
#  '최형사:(쟈켓을 입고 나가는 한 놈을 보고 일어나며)지금 나가는군요.(이형사가 어떻게 알았냐는 듯 보면)여자의 직감은 가장 정확하죠.',
#  '씬 43 다른 거리',
#  '어느 편의점에서 계산을 하고 나오는 쟈켓을 바라보는 최형사와 이형사.',
#  '이형사:여자들은 미행할 때 금방 눈에 띄지.',
#  '나가는 쟈켓 뒤를 따라가는 최형사.',
#  '씬 44 어느 호텔 앞',
#  '걸어가는 쟈켓을 뒤따라가는 최형사. 쟈켓, 호텔 앞에서 침을 탁 뱉고는 힐끗 뒤돌아보곤 최형사에게 슬쩍 윙크를 하고는 호텔 안으로 들어간다. 최형사, 저 편에서 이형사가 다가오면',
#  '최형사:하지만 여자한텐 방심하게 마련이죠.',
#  '이형사:좋아. 하지만 여자들이 갈 수 없는 곳에서 놈들이 거래를 하는 경우가 많지.(호텔 사우나를 가리키며)잡을 수 있겠나?',
#  '씬 45 동 싸우나 안',
#  '옷을 벗고 있던 남자들, 카메라를 보곤 히익 놀란 채 몸을 가리기도 하는 속에 꿋꿋하게 걸어가는 최형사. 카메라, 탈의실을 지나 사우나 안으로 들어가는 최형사를 뒤따라가면 히익 놀라 물 속으로 뛰어드는 남자, 몸을 가리는 남자 등의 욕탕을 지나 한증막 안으로 들어간다. 그 안에서 수건을 교환하던 쟈켓의 남자와 문신을 한 남자가 뻥찐듯 최형사를 보면 곧장 경찰증을 보이는 최형사, 이런! 놀란 쟈켓과 문신이 최형사를 향해 덤비지만 최형사의 화려한 공격에 퍽! 두둑! 발차기와 엎어치기에 창문을 깨고 날아가는 놈들의 모습을 보며 뭐, 저런게 다 있지? 라는 듯 바라보는 이형사를 득의만만하게 바라보는 최형사.',
#  '씬 46 경찰서 사무실',
#  '최형사, 쟈켓과 문신을 데리고 들어와 다른 경찰에게 인도하는데 저 편에 앉아있는 투피스의 젊은 여자를 사이에 두고 중년의 남녀가 마구 다투고 있는 모습이 보인다.',
#  '중년여:(강사의 머리타락을 잡은 채)야 이, 자식아 내 딸 어떻게 할 꺼야? 너같은 놈은 콩밥을 먹어야돼!',
#  '강사:왜 이러시는 겁니까?',
#  '이런 두 사람에게 다가가 말리는 최형사와 이형사.',
#  '최형사:(미니에게)무슨 일입니까?',
#  '중년여:우리 애가 대학생인데, 이자식이 저녁 먹자고 꼬셔서 술을 먹인 뒤에(다시 강사를 덥치며)야이 나쁜 놈아!',
#  '강사:(뿌리치며, 점잖게)제가 억지로 데려간 게 아니라고 말씀드렸잖습니까?',
#  '중년여:술취했다고 거짓말하지마! 이 나쁜 놈아!',
#  '강사:명백하게 저항하지 않으면 강간으로 볼 수 없다는 판례아시죠? 물어보세요? 내가 강간했나? 응?',
#  '투피스:(고개를 흔들며)모르겠어요.',
#  '강사:보세요? 그리고 난 이혼상태니까 간통죄도 아닙니다. 법대로 해결하면 되잖습니까?',
#  '중년여:법? 그래? 이 더러운 놈아, 너 많이 배웠다!',
#  '하며 덤비는 중년여를 잡는 이형사.',
#  '이형사:이러지 마십시오, 저희가 알아서 하겠습니다.',
#  '강사:(여유있게)그럼, 법대로 하자구. 응?',
#  '하다간 갑자기 멱살을 움켜쥐는 손에 끌려 일어나는 강사. 보면 최형사가 강사를 잡고 있다.',
#  '강사:왜이래? 아가씬 뭐야?',
#  '최형사:나? 경찰!',
#  '하며 곧장 강사의 면상을 갈기면 뒤로 확 나자빠지는 강사.',
#  '최형사:(강사를 일으켜 도장 퍼버벅! 난타하며)일어나! 법보다 더 중요한 게 있어! 힘없는 여자에게 나쁜 짓을 하고도 뭐? 법대로?',
#  '주변의 형사들과 과장 등이 놀란 듯이 모습을 바라본다.',
#  '과장:(다가와서 잡으며)이봐, 최형사! 경찰이 이러면 안돼!',
#  '최형사:놓으세요! 이런 자식은 죽여 버려야 돼요!',
#  '하며 말리는 과장도 확 밀쳐버리자 뒤로 나자빠진다. 이형사, 안되겠는지 다가가서 강사에게 다시 주먹을 내지르는 최형사의 손목을 낚아챈다.',
#  '이형사:그만해!',
#  '최형사:놓으세요!',
#  '이형사:경찰서에서 이게 무슨 짓이야?! 당장 과장님하고, 이 남자분에게 사과해!',
#  '최형사:(노려보다가)좋아요. 사과하죠.',
#  '엉거주춤 일어나는 강사에게 다가가는 최형사, 다시 강사의 그 곳을 퍽! 발로 차버리곤 돌아서 나가버린다. 히익! 다시 고꾸라지는 강사, 돌아서 나가는 최형사를 뻥찐듯 바라보는 과장 등 경찰들.',
#  '이형사:(따라나가려 하며)최형사! 저게 정말….',
#  '과장:(괜히 이형사에게 귀를 잡으며)어딜 도망가? 야 이, 자식아, 다 누구 때문인데? 너하고 다니더니 최형사까지 개망나니가 됐잖아?! 임마!',
#  '팍 인상이 일그러지는 이형사의 모습에서―',
#  '형사들이 모두 빠져나간 텅 빈 사무실에서 최형사를 다그치는 이형사.',
#  '이형사:도대체 위계질서를 어떻게 아는거야? 군이나 경찰에게 제일 중요한 건 첫째도 복종! 둘째도 복종이란 거 모르나?! 하긴 여자라 군에 안갔다와서 모르겠군. 아무튼, 모든 팀웍은 부하의 절대 복종에서 나오는거야? 알겠나?',
#  '최형사:죄송합니다. 저 때문에 선배님까지 내근하게 되서….',
#  '이형사:(보지도 않은 채)됐어. 그 아주머니한테나 다음에 인사드려. 강사가 폭행죄로 최형사를 고소하겠다는 걸 아주머니가 나서서 서로 고소않는 걸로 합의해줬으니 망정이지 안 그럼 구속됐을 꺼야.',
#  '인상이 굳어지는 최형사.',
#  '최형사:그랬나요?',
#  '이형사:(혼잣말처럼)에휴, 이러니 여자들이 나서면 될 일도 안된다고 하지.',
#  '최형사:뭐라구요? 선배님 지금 말을 너무 심하게 하는 것 아닙니까?',
#  '이형사:또 대드는거야?! 방금 내 이야기 들은거야? 안들은거야?',
#  '화난 듯 서로를 노려보는 투캅스. 이때 울리는 전화벨소리에 동시에 손을 뻗는 투캅스. 최형사가 한발 빠르다.',
#  '최형사:예. 경찰서입니다.',
#  '소리:(아줌마의 절박한, Filter)우리 아이가 유괴당했어요.',
#  '최형사:예?!',
#  '씬 47 피해자 집 거실',
#  '의아한 표정으로 보는 이형사와 최형사에게 두 손을 내젖는―',
#  '아저씨:유괴라뇨? 그런 일 없습니다.',
#  '최형사:분명히 신고가 들어왔습니다.',
#  '아저씨:제가요? 다른 집이겠죠. 자, 그럼….',
#  '하며 투캅스를 막아서는 아저씨 뒤로 부엌에서 투캅스의 눈치를 보는 불안한 표정의 아줌마를 발견한',
#  '최형사:(다가서며)아주머니가 신고하셨죠?',
#  '아줌마:전, 전…',
#  '망설이는 아줌마, 뭔가 말을 하려 하자 아저씨가 먼저 말을 한다.',
#  '남편:어허, 어허, 자기 자식이 없어졌는데 그걸 숨길 부모가 어딨습니까?',
#  '이형사:최형사, 또 장난 전화에 속았구만, 도대체 일을 어떻게 하는거야?',
#  '최형사:아주머니, 사실대로 말씀해주세요. 저희가 해결하겠습니다.',
#  '남편:(안되겠다는 듯)전화한 적 없다니까 왜 이렇게 귀찮게 하는거야? 자, 이만 나가주세요.',
#  '최형사:아주머니, 왜 두려워하세요?',
#  '이형사:최형사, 남자분이 아니라는데 아줌마한테 왜 자꾸 물어?(아저씨에게)착오가 있었나봅니다. 죄송합니다.',
#  '남편:(현관으로 몰아내며)아닙니다. 괜한 걸음 하셨군요. 이거 약소하지만 차비나 하시고….',
#  '안주머니에서 돈을 꺼내 최형사에게 건내려하는 남편.',
#  '최형사:유괴범한테도 이렇게 돈으로 해결할껀가요?',
#  '이때 탁자위에 있는 전화가 울린다.',
#  '순간 남편과 아줌마가 긴장한 듯 전화기를 바라본다. 투캅스의 눈치를 보는 아줌마와 남편의 안절부절하는 모습을 보곤',
#  '최형사:제가 받을까요?',
#  '아줌마:(동시에)안돼!',
#  '남편:(동시에)안돼!',
#  '씬 48 유괴범의 아지트',
#  '화면 가득 겁에 질린 아이의 모습속에서',
#  '아이:(핸드폰을 대고)엄마 살려줘! 나 무서워!',
#  '소리: (아줌마의Filter)지선아! 지선아!',
#  '어둡고 허름한 창고 같은 곳에 있는 유괴범 세 명. 아이의 목을 팔로 조르고 있던 놈, 핸드폰을 빼앗는다.',
#  '유괴범:돈은 준비했나?…. 좋아, 설마 경찰에 신고는 안했겠지?',
#  '아이:(겁에 질린 채, 울먹이며)엄마!',
#  '유괴범:(아이를 때리며)시끄러!(핸드폰을 대고)만약 경찰 그림자라도 보이면 애는 죽어.',
#  '씬 49 어느 곳(N)',
#  '어둠을 가르며 달리는 그랜져가 지나치면 한적한 도로 변에서 커다란 가방을 들고 서있는 아줌마의 모습이 어둠속에 보인다. 주변의 편의점 안에서 직원 복장을 한 채 바라보는 형사1, 카세트테이프 가판대에서 장사를 하는 형사2, 그 옆에 주차한 어두운 차안에 엎드리다시피 숨어있는 형사 3, 4맞은 편 도로의 어두운 골목에 세워진 차 안에 있는 이형사 등의 모습이 빠르게 보여진다.',
#  '드문드문 오가는 사람을 바라보는 형사들의 눈빛들 너머의 건너편 도로로 그랜져가 천천히 지나간다.',
#  '형사1:(손목 시계에 대고)안 올것 같은데?',
#  '형사2:(귀에 찬 이어폰을 만지며)거기 히터 나오지? 지금이 몇월인데 왜 이리 추워? 젠장.',
#  '형사3:(바닥에 엎드려, 손목시계에 대고)그러게 사다리를 잘 타야지.',
#  '씬 50 달리는 차 안',
#  '천천히 이동하는 차 안의 시점으로 보이는 아줌마와 주변의 모습들. 운전을 하며 밖을 바라보는 유괴범1, 백미러로 보이는 아줌마의 모습이 작아져간다.',
#  '씬 51 동 어느 곳',
#  '어둠을 가르며 달려오는 자가용의 불빛이 비치자',
#  '형사2:(손목시계에 대고)뻐꾸기 하나, 뻐꾸기 하나….',
#  '형사1:진돗개 대기.',
#  '다가오던 자가용, 휭하니 지나쳐 가버리면 커다란 가방을 들고 서있는 아줌마의 모습이 어둠속에 보인다. 이때 저 편에서 도로에 비치는 불빛과 함께 달려오는 차가 내뿜는 헤드라이트에 비친 아줌마의 모습, 바로 변장한 최형사이다. 눈이 부신 듯 고개를 돌리는 최형사 앞으로 끼이익 멈춰서는 차. 재빠르게 내리는 유괴범1.',
#  '유괴범1:돈은?',
#  '최형사:(가방을 열어보이며)…',
#  '유괴범1:액수는 정확하겠지?',
#  '최형사:아이는 어딨어요?',
#  '유괴범1:다른 곳에 있어. 걱정하지 말고 돌아가',
#  '최형사:안돼요. 돈 가져왔으니까 아이도 풀어주세요.',
#  '유괴범1:(가방을 잡으며)시간없어! 10분 내로 안 돌아가면 애는 죽어.',
#  '최형사:(가방을 꽉 움켜쥐며)그럼 같이 가요. 내가 데려갈게요',
#  '하며 잡아 당기지만 가방을 꽉 감싸앉는 최형사. 긴장한 채 최형사와 유괴범을 지켜 보던',
#  '형사1:어떻게 하지?',
#  '형사2:애는 차안에 없어. 일단 최형사에게 맡겨.',
#  '최형사, 가방을 잡으려고 하는 유괴범1을 확 밀치며',
#  '최형사:애 풀어주기 전엔 절대 못줘.',
#  '유괴범1:안 놔? 이 개같은 년이 확～',
#  '하며 주먹을 내지르려는 유괴범1의 뺨에 번쩍 와닿는 최형사의 손. 퍽! 소리와 함께 고개가 돌아가는 유괴범1.',
#  '유괴범1:어쭈?',
#  '하며 다시 주먹을 내지르는 유괴범1. 하지만 어느새 최형사의 가방이 휙 날아와 유괴범의 머리를 내친다. 퍽! 뒤로 자빠지는 유괴범1',
#  '최형사:애 어딨어?',
#  '씬 52 동 부근',
#  '어느 나무 뒤의 오토바이에서 이 모습을 바라보고 있는 이형사와 아줌마, 놀란 표정이다.',
#  '아줌마:(작게)어머? 왜 저러는 거죠?',
#  '이형사:(작게)저도 몰라요.',
#  '아줌마:(나가려하며)저러면 우리 애 죽어요 안돼요.',
#  '이형사:(말리며)괜찮을겁니다. 안심하세요.',
#  '아줌마:(이형사를 퍽 치며)안심하긴 뭘 안심하란 말야? 놔!',
#  '이형사:(막으며)안됩니다!',
#  '나가려는 아줌마를 잡는 이형사, 아줌마의 몸부림에 마구 맞는다.',
#  '씬 53 동 그 곳',
#  '뒤로 자빠졌다가 일어나는 유괴범1',
#  '유괴범1:이게 누굴 패? 난 유괴범이야. 니 애를 데리고 있다고, 이 멍청한 년아',
#  '최형사:애 데리고 와. 안그러면 가방 못 줘',
#  '유괴범1:너 혹시 계모아냐? 빨리 안가면 애 죽는다니까 이 또라이 같은 년이….',
#  '하는 순간 저 편에서 패트롤카가 다가오자 멈칫하며 바라보는 두 사람.',
#  '유괴범1:이 년이 경찰을 불러?',
#  '최형사:아, 아냐. 내가 부른 게 아니에요',
#  '유괴범1:(작게)내가 잡히면 니 애는 바로 죽어, 알아?',
#  '하는데 멈춰지는 패트롤카에서 내리는 경찰1',
#  '경찰1:거기서 뭐하는 겁니까?',
#  '최형사:아, 아뇨.(유괴범을 툭치며)남편이 절 마중나와서 이제 가려는데요?',
#  '유괴범1:아, 예. 맞습니다.',
#  '경찰1:근데 이 가방은 뭡니까?',
#  '최형사:아? 이 가방요?',
#  '씬 54 동 근처',
#  '안절부절하며 이 모습을 바라보는 아줌마와 이형사.',
#  '아줌마:도대체 뭐하는 거에요?',
#  '이형사:걱정하지 마십시오. 잘될겁니다.',
#  '아줌마:잘 되긴 뭐가 잘돼?(이형사의 멱살을 잡으며)우리 애 잘못되면 죽을 줄 알아!',
#  '씬 55 동 그 곳',
#  '최형사와 유괴범1 앞에 서 있는 경찰1. 유괴범1, 뒷주머니에서 칼을 빼든다.',
#  '경찰1:두 분이 싸우는 것 같던데요?',
#  '최형사:아뇨. 그럴 리가 있나요?(팔짱을 끼며)그치? 자기?',
#  '유괴범1:(어색하게 웃으며)그럼요.',
#  '경찰, 이상한 듯 두 사람을 다시보자 어색한 미소를 짓는 최형사와 얼굴이 맞아 부어오른 유괴범1',
#  '경찰1:부부 싸움은 집에서 하세요.',
#  '하며 엉망이 된 유괴범1을 한심한 듯 보며 경찰차에 올라탄다. 최형사와 유괴범1, 긴장한 채 지나쳐 가는 경찰차를 본다.',
#  '씬 56 달리는 차 안',
#  '운전을 하는 유괴범1 옆에 최형사가 가방을 안고 있다.',
#  '유괴범1:모처럼 경찰 한 번 죽여보나 했더니…. 씨발.',
#  '최형사:경찰까지 죽인 적 있나요?',
#  '유괴범1:그럼, 날 귀찮게 쫓아다닌 놈이 있었거든, 야구방망이로 내리친 뒤 살려달라도 애원하는 걸 보며 생매장했지. 그때 느낀 건데 역시 경찰 죽일때가 제일 스릴있단 말야.',
#  '최형사:정말 죽일 놈이군.',
#  '유괴범1:뭐? 이 썅년이. 아까부터 계속 성질돋구네.',
#  '하고 때리려하면 먼저 최형사의 손바닥이 유괴범1의 뺨을 때린다.',
#  '최형사:운전이나 똑바로 해.',
#  '유괴범1:씨발…. 무슨 엄마가 이래?',
#  '씬 57 도로',
#  '인적없는 도로를 달리는 차 뒤로 라이트를 끈 채 이형사와 아줌마가 오토바이를 타고 간다.',
#  '씬 58 유괴범의 아지트',
#  '인적이 없는 한적한 야외의 어두컴컴하고 허름한 창고 앞에 멈춰서는 차에서 내리는 유괴범1과 최형사.',
#  '유괴범1:(문을 세 번, 한번 두드리곤)나야. 유괴범.',
#  '씬 59 아지트 안',
#  '문을 여는 유괴범2, 유괴범1 뒤로 최형사가 들어오자 놀란다. 최형사, 안을 보면 아이가 묶인 채 바닥에 앉아있는 옆에 유괴범3이 담배를 피우고 있다.',
#  '유괴범2:여잔 왜 데리고 왔어?',
#  '유괴법1:어차피 내 얼굴을 봤는데 애새끼랑 같이 죽여버려야지.',
#  '유괴범3:(아이를 툭 치며)임마, 니엄마 왔다.',
#  '최형사:(다가가며)지선아! 괜찮니?',
#  '아이:우리엄마 어딨어요?',
#  '휙 쳐다보는 유괴범 1, 2, 3',
#  '최형사:지선아, 엄마야.',
#  '아이:아줌만 누구야?',
#  '유괴범3, 다가오는 최형사를 보곤 재빨리 아이의 목에 칼을 갖다댄다.',
#  '유괴범3:움직이지마! 너 누구야?',
#  '최형사:도대체 아이한테 무슨 짓을 한거예요? 엄마도 못알아보잖아요? 임마, 자세히 봐! 엄마잖아?',
#  '유괴범3:(아이에게)니네 엄마 맞아?',
#  '아이:아냐, 우리엄마 어딨어?(울며)엄마! 엄마!',
#  '유괴범1:그럴 줄 알았다. 이 썅년.',
#  '유괴범3:죽여!',
#  '유괴범2, 재빠르게 칼을 꺼내드는데 유괴범2를 돌려차기로 날려버리는 최형사, 휘둥그레진 유괴범1, 금방이라도 팰 듯이 가다간 최형사가 휙 뒤돌아보면 겁에 질린 듯 멈칫한다.',
#  '유괴범3:뭐해? 새꺄?!',
#  '하는 순간 어느새 총을 꺼내 든 최형사, 유괴범3을 겨누며',
#  '최형사:(유괴범3을 겨눈 채)꼼짝마!',
#  '유괴범3:(아이의 목에 칼을 댄 채)총버려! 총안버리면 죽여버릴꺼야!(아이의 목에 댄 칼에 힘을 주며)하나! 두울!',
#  '최형사:(바라보다가)좋아, 대신 아이는 살려줘!',
#  '유괴범3:알았어. 약속하지.',
#  '총을 천천히 내려 총알을 밖으로 빼버린 채 저 편으로 던지는 최형사. 유괴범3, 신경질적으로 아이를 뒤로 밀치곤 최형사에게 다가간다.',
#  '유괴범3:이 년이 겁도 없이….',
#  '유괴범1:(바닥에 떨어진 총과 총알을 집으며)임마, 저 여자 싸움 졸나 잘 해!',
#  '유괴범3:병신같은 게 기집년한테 겁먹기는 비켜! 임마.',
#  '하며 칼을 휘두르며 공격해 들어가는 유괴범3. 최형사, 슬쩍 피하며 칼을 든 손을 우두둑 꺽으며 바닥에 내동댕이친다. 바닥에 널부러진 유괴범3을 보며 허겁지겁 총과 총알을 드는 유괴범1, 총알을 넣으려고 하지만 긴장한듯 번번히 떨어지기만 하는데 어느새 다가오는 최형사를 보곤 곧장 총을 바닥에 떨어뜨리고 손을 든다. 이와 동시에 문을 쾅 차고 들어오는 이형사와 아줌마, 울먹이는 아이와 엄마가 포옹하는 모습을 바라보는 투캅스의 모습속에…',
#  '씬 60 서장실',
#  '선행하는 박수 소리와 함께 정복 차림의 최형사의 어깨 위에 잎파리 세 개의 계급장을 달아주는 서장.',
#  '서장:(악수를 하며)축하해. 최경장, 최단 기간 승진 기록이야. 개망신 당할 뻔한 우리 경찰서를 최형사가 구해줬어.',
#  '최형사:감사합니다.',
#  '뒷편에서 박수를 치는 동료형사들 속에 이형사도 보인다.',
#  '씬 61 동 복도',
#  '커피 자판기 앞에 있는 최형사에게 다가가는 이형사.',
#  '이형사:축하해, 최형사!',
#  '최형사:(돌아보며)어? 고마워. 이형사. 한잔 하겠나?',
#  '이형사:뭐? 지금 나한테 반말하는 거야?',
#  '대뜸 나오는 최형사의 반말에 어이가 없다. 최형사, 돌아보며 이형사에게 뽑은 커피를 내밀며',
#  '최형사:같은 경장끼리 앞으로 잘해보자구. 응?',
#  '이형사:하루 잎파리 호봉 무서운 줄 모른다더니, 같은 경장이라고 맞먹자는거야?',
#  '최형사:응. 이젠 상사와 부하가 아닌 동등한 파트너 관계로 일해보자는 거야 똑같은 조건에서의 경쟁, 할만하지 않아?',
#  '이형사:(정면으로 노려보며)지금 나한테 도전하겠다는 거야?',
#  '최형사:(어깨를 툭툭 치며 지나치며)아니, 분발하라는 거야.(커피를 마시며)음, 커피 맛 좋은데?',
#  '휙, 고개를 돌려 지나치는 최형사를 노려보는 이형사, 커피를 곧장 휴지통에 확 버린다.',
#  '씬 62 은행 계단',
#  '은행의 유리문을 보며 계단으로 꺽어져 들어가는 흑장갑과 목장갑, 둘 다 모자를 눌러쓴 채 계단의 모퉁이에 멈춰선다.',
#  '흑장갑:지난 번 실패를 거울 삼아 이번엔 제대로 하자, 위험이 큰 만큼 더 짭짤하다. 남자가 은행 정도는 털어야 한다고 어릴 때부터 다짐하곤 했었다.',
#  '목장갑:형님 어릴 때 꿈이 은행강도였습니까?',
#  '흑장갑:(담배를 꺼내 물며)그래. 넌?',
#  '목장갑:제 꿈은 우리 같은 은행강도를 빵! 빵! 총으로 쏴죽이는 경찰이 되는 거였습니다.',
#  '흑장갑:(답배를 피우며 팰 듯이)개새꺄, 개소리 계속하면 개패듯이 패버릴꺼야, 알았어?',
#  '목장갑:(벽에 붙은 금연표시를 보곤)행님, 여기 금연구역인데요?',
#  '흑장갑:(휙 보더니 마구 때리며)씨발놈이, 법 지킬려면 경찰하지 미쳤다고 은행강도하냐?',
#  '하는데 계단에서 한 여자가 올라오자 멈칫하며 어색하게 목장갑이 옷을 털어주는 흑장갑. 목장갑의 소매에 숨긴 쇠파이프가 흘러나오자 쓸어올리며 자신의 소매에 숨긴 쇠파이프도 감추는 흑장갑. 치마를 입고 올라가는 여자를 보며 슬쩍 미소짓는 흑, 목. 위로 향하는 여자를 보며 고개를 숙이다간 둘이 눈이 마주치자',
#  '흑장갑:(모자를 다시 눌러쓰며)시작하자.(은행 안으로 들어가며)수표는 절대 챙기지마.',
#  '씬 63 동 은행 안',
#  '제법 사람들이 있는 은행의 뒷문으로 들어오는 흑장갑과 목장갑. 흑장갑의 신호에 따라 청원경찰 쪽으로 고개를 숙인채 다가가는 목장갑. 목장갑, 청원 경찰의 뒤로 다가가 소매안에 있는 쇠파이프를 꺼내려는데 팔꿈치에서 틱! 걸린다. 당황한 목장갑, 뒤돌아서는 청원경찰을 굳은 표정으로 바라보는 순간, 퍽～하는 소리와 함께 목장갑 앞으로 쓰러지는 청원경찰. 의아스레 바라보면, 은행강도1이 총을 들고 서있다. 이와 동시에 창구 위로 훌쩍 뛰어 올라가는 은행강도2.',
#  '강도2:(총을 꺼내들고)모두 엎드려! 움직이는 놈은 죽여버릴꺼야!',
#  '하며 천장에 대고 총을 쏜다.',
#  '꺄악! 비명을 지르며 바닥에 엎드리는 사람들 속에 흑장갑과 목장갑, 바닥에 엎드린 채 서로를 본다.',
#  '목장갑:(바닥에 엎드린 채)형님, 어떻게 된겁니까?',
#  '흑장갑:(바닥에 엎드린 채)내가 아냐? 임마.',
#  '목장갑:우리도 은행강도잖아요? 그냥 이렇게 당하고 있을 껍니까?',
#  '흑장갑:그럼 동업이라도 하자고 해봐. 임마!',
#  '강도1:(다가와선)조용히 안해?! 죽고싶어?!',
#  '겁에 질린 듯 바닥에 얼굴을 묻는 흑·목장갑의 모습에서….',
#  '씬 64 어느 은행 앞',
#  '많은 경찰차들과 경찰들이 북적거리는 곳으로 걸어 들어오는 투캅스. 한 경찰이 이형사를 알아보고 경례를 하면 통과하는 이형사 뒤로 걸어가는 최형사를 잡는 경찰. 최형사, 경찰증을 보이며 이형사를 뒤따라간다.',
#  '이형사:몇 명이야?',
#  '경찰2:두 놈입니다.',
#  '이형사:그래?',
#  '경찰2:인질들을 잡고 대치중입니다. 총을 가지고 있습니다.',
#  '이형사:(최형사에게)수준차이를 보여주지. 잘 봐.',
#  '하면서 권총을 뽑아들고 건물 뒤로 달려간다.',
#  '씬 65 동 은행 안',
#  '엎드려있는 사람들 속에 가방 두 개를 들고 불안스레 밖을 보는 강도1, 2.',
#  '소리:(경찰의 확성기)너희는 완전히 포위됐다. 무기를 버리고 투항하라!',
#  '강도2:어떡하지?',
#  '강도1:씨발, 어떡하긴…(흑장갑을 툭툭 차며)일어나!',
#  '흑장갑:예? 저요?',
#  '강도1:죽고 싶어?',
#  '흑장갑:(벌떡 일어나며)아뇨. 사실 우리도 당신처럼….',
#  '강도1:시끄러!(흑장갑의 뒷덜미를 잡아 일으켜 머리에 총을 대보이며)비켜! 안 그러면 1분마다 한 명씩 죽여버릴꺼야!',
#  '흑장갑:(겁먹은 채)살려주세요. 제, 제발….',
#  '목장갑, 이런 흑장갑이 모습을 보며 휴. 안도의 한숨을 내쉬는데 뒷문을 쾅 열고 들어오는 이형사, 총을 들고 있다.',
#  '이형사:(총을 겨누며)꼼짝마!',
#  '강도1:(흑장갑의 머리에 총을 겨눈 채)총 버려! 죽여버릴꺼야.',
#  '흑장갑:제발… 살려주세요.',
#  '이형사:여기가 미국인 줄 알아? 가짜총인지 알고 있어.',
#  '강도1:가짜 아냐!',
#  '하며 천장을 향해 총을 쏜다. 탕! 총에 맞아 깨지는 형광등. 총소리에 놀라 비명을 지르는 사람들. 다가가던 이형사 멈칫한다. 강도1에게 인질로 잡힌 흑장갑, 완전 사색이 된 채 오줌이라고 싼 듯 바지에서 물을 주루룩 흘러내린다.',
#  '강도1:이래도 장난처럼 보여?',
#  '이형사:나도 장난 아냐. 임마! 총 버려!',
#  '하며 천장에 대고 총을 쏘는 이형사. 탕! 총에 맞아 다른 형광등이 깨진다. 거의 실신한 흑장갑의 다리가 풀리자 강도1이 힘겹게 부축한다.',
#  '이형사:다음은 니 머리야! 빨리 총버려!',
#  '강도1:다가오지마!',
#  '흑장갑:제발…. 살려주세요.',
#  '이형사:사건에 따라 때론 약간의 희생은 불가피하지. 죄송합니다.',
#  '강도2:저거, 미친 놈 아냐?',
#  '이형사:셋, 둘.(노리쇠를 당긴 후)하..',
#  '하는 순간 뒤에서 누군가의 손이 이형사의 뒷덜미를 내리친다. 퍽! 힘없이 바닥으로 쓰러지는 이형사 뒤로 보이는 목장갑의 모습.',
#  '강도1:(총을 겨누며)넌 뭐야?!',
#  '목장갑:(움찔하며)총 좀 치워요. 저 형하고 나도 원래는….',
#  '강도1:아는 사이야?',
#  '목장갑:예. 사실 우리도 은행 털려고 왔는데 형씨들이…',
#  '강도2:(목장갑의 목에 총을 대고)개소리하지마. 시간없어. 새꺄, 따라와!',
#  '하며 끌고 뒷문 쪽으로 나가려하는데 문 앞에 최형사가 버티고 서있다.',
#  '강도2:뭐야? 비켜!',
#  '하며 최형사를 위협적으로 밀치고 가려는 순간 흑장갑의 부부를 퍽! 발로 차고는 읔…. 흑장갑이 앞으로 몸을 숙이는 순간 강도2의 면상을 그대로주먹으로 갈기는 최형사. 휘청! 비틀거리는 강도2를 화려한 발차기로 퍼억! 쓰러뜨리는 최형사. 히익! 놀란 듯 최형사에게 총을 겨누는 강도1.',
#  '순간 더 빠르게 총을 꺼내드는 최형사, 타앙! 총성과 함께 어깨에 총을 맞고 뒤로 튕겨나는 강도1. 쾅! 강도1의 총이 허공으로 쏴지는 순간, 재빠르게 강도1을 덥치는 최형사. 총을 집어드는 강도1의 손을 밟는 최형사. 두두둑! 아악! 비명을 지르는 강도1. 최형사, 강도1의 손에 철컥 수갑을 채우는 모습 뒤로 겁에 질린 채 옴짝달싹 못하고 있는 흑장갑을 부축해 빨리도 기어 도망가는 목장갑 등이 우스꽝스레 보인다.',
#  '씬 66 서장실',
#  '선행하는 박수소리 속에 최형사의 어깨에 잎파리 네 개의 계급장을 달아주는 서장.',
#  '서장:축하해. 최경사. 경찰 사상 최고 빠른 승진기록이야!',
#  '최형사:감사합니다. 서장님.',
#  '뒷편에서 박수를 치는 경찰들 속에 이형사의 모습도 보인다.',
#  '서장:여성 최초의 강력계 형사 반장이야. 잘 해낼 수 있겠지?',
#  '최형사:주위분들이 도와주셔야죠.',
#  '서장:(주위를 보며 호통을 치듯)모두 잘들어! 특히 형사 3반. 앞으로 나이 어린 여자라고 말 안 들으면 다 짤라버릴꺼야. 알았어?',
#  '경찰들:(힘차게)네!',
#  '씬 67 달리는 차안',
#  '보조석에 앉아있는 이형사. 옆에 운전하는 최형사.',
#  '이형사:(슬쩍 보곤)축하해, 최형사. 제대로 된 사람은 올라갈수록 겸손해진다더니, 최형사가 운전하겠다고 할 줄 몰랐어. 아무튼, 이번엔 내가 진 걸 인정하지. 최형사 말대로 앞으로 잘해보자구.',
#  '최형사:이형사, 반말하지마!',
#  '이형사:(놀라)뭐?',
#  '최형사:이전에도 상관한테 항상 반말했나?',
#  '이형사:아니. 하지만 최형사….',
#  '최형사:(말을 막으며)나한테 위계질서를 강조한 사람이 이형사 아니었나? 같이 일하는 동안에는 상사로써 대우하도록. 알겠나?',
#  '이형사:(끓는 듯 바라보며)….',
#  '최형사:만약 이형사가 평생 내 부하로 일할거라면 대답 안해도 돼.',
#  '이형사:(바라보기만 하며)…. 예 써.',
#  '씬 68 대학교 정문',
#  '경례하는 수위를 뒤로 한 채 학교로 들어가는 차.',
#  '씬 69 강의실',
#  '<여성의 사회적 지위 향상 …> 등이 쓰인 칠판 앞에서 강의하는 강사.',
#  '강사:어느 나라가 과연 얼마만큼 진보했는가를 알려면, 그 사회에서 여성의 지휘를 보면 된다 라고 했듯이….',
#  '하는 순간 문을 벌컥 열고 들어오는 최형사. 웅성거리는 학생들을 보며 당황하는 강사.',
#  '강사:(학생들에게)잠깐만…(최형사에게 다가가며)아니, 강의하는데 이렇게 들어오면 어떡합…',
#  '하는 순간 곧장 강사의 배를 퍽! 갈기는 최형사. 말을 하다가 곧장 힘없이 앞으로 쓰러지는 강사를 올려매는 최형사.',
#  '와～ 어머～ ……. 웅성거리는 학생들.',
#  '최형사:(강사를 올려맨 채)오늘 강의는 이것으로 마친다. 이상!',
#  '하며 밖으로 나가는 최형사.',
#  '씬 70 다른 곳',
#  '공사라도 하는 건물 벽에 양손과 발을 벌린 채 묶여있는 강사가 버럭 버럭 고함을 지른다.',
#  '강사:당장 풀어! 지난 번에 봐줬더니 또 무슨 짓이야? 불법 감금에 인권유린이라는 거 몰라?! 나가면 당장 고발할꺼야!',
#  '하며 고함을 지르는 강사 앞에 뒤돌아서있는 이형사.',
#  '이형사:(다시 뒤돌아서며)어쩔 수 없습니다. 잠시만 기다리십시오.',
#  '강사:이 여자 어디갔어? 당장 데려와!',
#  '하는데 선행하는 최형사의 목소리.',
#  '최형사:아직도 큰 소리군!',
#  '휙 뒤돌아보는 이형사.',
#  '이형사:최반장님. 우선 풀어주고 정식적인 절차를 밟아서….',
#  '최형사:(커다란 가위를 들어보이며)구해왔어.',
#  '이형사:(질겁해서)예? 최반장님… 설마….',
#  '최형사:(다가가며)법으로 악을 막을 수 없다면 힘으로 막아야 돼.',
#  '이형사:(잡으며)그건 경찰의 임무가 아닙니다.',
#  '최형사:때론 범인체포보다 범죄예방이 더 중요해.',
#  '이형사:안됩니다.',
#  '강사:(분위기 파악못한 채)지금 뭘 짜르겠다는 거야?',
#  '최형사:(뿌리치며)저런 놈은 화장실 갈 자격도 없어!(가위를 높이 들고)비켜!',
#  '강사:안돼! 잘못했어요. 제발… 이것만은…',
#  '최형사:(가위로 자크를 잘라내며)뭘 잘못해? 강간한 게 아니라며?',
#  '이형사:(다시 잡으며)최반장님!',
#  '강사:여자가 반항했어요. 제가 강간한거라구요. 제 가슴에 보면 상처도 있다구요. 제발 구속시켜주세요. 제발!',
#  '이런 강사를 보는 이형사와 최형사의 모습에서―',
#  '씬 71 달리는 차 안',
#  '운전을 하는 최형사 옆에 앉아있는 이형사.',
#  '이형사:최반장님.',
#  '최형사:왜?',
#  '이형사:사적인 질문 하나 해도 괜찮겠습니까?',
#  '최형사:뭐?',
#  '이형사:혹시 가족이나 친척 중에 아내를 버리고 도망간 남편이 있었습니까?',
#  '최형사:(바라보다간)지금― 시비거는 거야?',
#  '이형사:아뇨. 그냥 물어보고 싶었습니다.',
#  '최형사:아직까진 없어.',
#  '이형사:그럼 이전에 남자한테 심하게 배신당한 적 있습니까?',
#  '최형사:그 전에 내가 먼저 물어보지. 혹시 이형사 가족 중에 정신이상자는 없었나?',
#  '이형사:(바라보다간)됐습니다.',
#  '최형사:제발 바보같은 질문하지마. 알았어?',
#  '씬 72 어느 계곡',
#  '사람이 없는 야산에서 추리닝 차림으로 달리는 흑장갑과 목장갑.',
#  '목장갑:형님, 언제까지 달리기만 할껍니까?',
#  '흑장갑:백 번 성공하는 것 보단 한번 잡히지 않는 게 더 중요하다.',
#  '목장갑:전 잡혀도 좋으니 뭐든 딱 한번이라도 성공해봤으면 좋겠습니다.',
#  '흑장갑:새꺄, 깜빵들어간 대통령들 봐라, 몇 천억 있으면 뭐하냐? 써보지도 못하고 인생 쫑쳤잖아? 임마.',
#  '목장갑:그 사람들도 달리기를 못해서 잡혔습니까?',
#  '흑장갑:씨발 놈아, 말이 그렇다는거지… 근데, 이 개새끼가…',
#  '하며 휙～ 주먹을 휘두르면 피하는 목장갑, 재빨리 도망간다.',
#  '흑장갑:어쭈? 이리 안와?',
#  '목장갑:(산 쪽으로 도망가며)또 팰라구?',
#  '흑장갑:(쫓아가며)안 때릴게! 새꺄, 하나님을 걸고 맹세한다.',
#  '목장갑:(도망가며)형은 믿지도 않잖아요!',
#  '흑장갑:(바닥의 돌을 던지며)이 새끼가 맹세한다니까… 너 잡히면 죽었어!',
#  '하면서 산 쪽으로 빠르게 도망가는 목장갑, 무언가에 걸린 듯 우당탕 넘어지면 그 위로 덥치는 흑장갑.',
#  '흑장갑:(손을 두둑 꺽으며)넘어질 줄 알았다. 이 새끼가….',
#  '목장갑:(발 아래를 보곤, 경악스레)허억! 저기… 저기.',
#  '흑장갑:쨉쓰지마, 새꺄.',
#  '위협적으로 다가가던 흑장갑, 목장갑이 겁에 질린 눈으로 발 아래를 가리키는곳을 보면 나무가지들 속에서 누군가의 팔이 터억 나와있다. 으아악～ 비명을 내지르는 흑장갑과 목장갑의 모습에서…',
#  '타임 컷―',
#  '패트롤카의 사이렌 소리 속에 카메라, 빨간 불을 뿜으며 돌아가는 경광등의 경찰차 너머로 이동하면 검시관 등이 북적거리는 사이로 걸어가는 투캅스.',
#  '목과 머리에 피를 흘린 채 죽어있는 여자를 보며 다가가는 이형사.',
#  '이형사:(최형사를 힐끗 보며)어디 한 번 살펴볼까?',
#  '하며 여자의 눈동자를 살피곤 목에 깊이 패인 상처를 본다.',
#  '이형사:(목을 살피며)이런 잔인한 놈! 가위로 한 번에 목을 땄군. 칼로 그으면 오른쪽과 왼쪽의 깊이가 차이날 수밖에 없 죠.',
#  '검시관:(큰 가위를 보이며)범행 현장에서 발견된 겁니다.',
#  '이형사:날카로운 면이 왼 쪽에 있는 걸 보면 놈은 왼손잡이야.',
#  '이런 이형사 뒤로 다가와 바라보는 최형사. 이형사, 이번엔 목에 난 피를 스윽 닦아내 입가로 가져간다.',
#  '이형사:(피를 맛보며)하루 정도 지났군.',
#  '검시관:혈흔 채취를 저희가 했습니다.',
#  '최형사:이형사, 그런 건 검시관한테 맡겨.',
#  '하며 이형사를 보지만 아무런 반응이 없다.',
#  '이형사:(이번엔 더 깊숙이 찔러대며)아닌가? 이틀인가? 오늘 점심은 뭘 먹지? 내장탕 어때요?',
#  '최형사:(뒤로 팔을 확 꺽으며)하지 말라고 했잖아? 죽은 사람한테 무슨 짓이야! 당신 드라큐라야? 응?',
#  '이형사:이 사건은 제가 맡기로 했잖습니까?',
#  '최형사:사건 맡으라고 했지, 시체 주무르라고 했어?! 죽은 사람이라고 함부로 대해도 되는거야?(팔을 꺽은 채 이형사의 얼굴을 시체에게로 밀치며)당장 사과해!',
#  '이형사:(눈을 뜨고 죽은 시체와 얼굴을 맞댄 채)죄송합니다.',
#  '최형사:나한테 말고 이 여자한테!',
#  '이형사:(눈을 뜨고 죽은 시체를 코앞에서 보며)이 여자한테요?',
#  '최형사:그래, 빨리 해!',
#  '이형사:(시체를 보며)아가씨, 미안해.',
#  '최형사:더 크게!',
#  '이형사:(시체와 얼굴을 맞댄 채)미안하다구요!',
#  '씬 73 공사중인 건물 계단',
#  '공사중인 건물 계단으로 올라가는 투캅스.',
#  '최형사:여긴 왜 온거야?',
#  '공사장의 턱을 넘는 최형사의 모습 위로 선행하는',
#  '소리: (정보원들의)… 여덟. 아홉. 열. 번호 끝.',
#  '씬 74 동 안',
#  '의아한 표정으로 들어오는 최형사. 어깨에 잔뜩 힘이 들어간 이형사 앞에 일렬로 정열해 있는 인상 더러운 정보원들이 경례를 한다.',
#  '정보원들:추웅～성!',
#  '이형사:(정보원들 앞으로 걸으며)오늘 내가 제군들을 집합시킨 이유는…',
#  '최형사:이형사, 이 사람들 뭐야?',
#  '이형사:(최형사에게)저를 하늘처럼 믿고 따르는 정보원들입니다.(정보원들에게)우리 구역에서 발생한 살인사건을 모두 알 것이다….',
#  '이형사가 폼을 잡고 왔다갔다하며 말하는 동안 정보원들을 쭉 둘러보던 최형사, 가운데에 있는 한 정보원 앞에 서더니',
#  '최형사:너 이한구지?',
#  '정보원1:왜 그래?',
#  '최형사:절도에 특수강도. 합이 전과 5범. 맞지?',
#  '정보원1:근데, 왜?',
#  '최형사:(정보원1을 퍽 까곤)말높여! 임마. 나도 경찰이야.(또 한 명을 발견하곤)어? 너 강간폭행했던 김한일이지?',
#  '정보원2:그래. 왜?',
#  '최형사:(다시 퍽 까곤)말 높이라니까.',
#  '정보원2:(당황한 듯)이형사님!',
#  '최형사:(한명씩 툭툭 치며)강간, 폭행, 절도, 관내 우범자들을 모두 다 모여있잖아?(이형사에게)이게 뭐야?',
#  '이형사:(수갑을 채우려는 최형사를 잡으며)하지만 지금은 모두 손 씻고 제 정보원을 하고 있습니다.',
#  '최형사:뭐? 손을 끊어? 말도 안되는 소리하지마! 이런 놈들 다 필요 없어.(정보원들에게)모두 해산해!',
#  '어리둥절한 정보원들, 웅성거리며 이형사의 눈치를 본다. 이형사를 보며 어떻게 된거야? 등등을 말하며 웅성거리는 정보원들.',
#  '이형사:정보원 없이 무슨 수사를 한단 말입니까? 최반장님이 아직 현실을 몰라서…',
#  '최형사:그렇다고 범죄자들과 손잡으라곤 안했어. 3초내로 해산 안하면 모두 연행한다. 하나. 둘!',
#  '정보원들, 이형사님. 죄송합니다― 등을 말하며 가려하자',
#  '이형사:(정보원들에게)모두 움직이지마!(최형사에게)당신 정말 이런 식으로 할겁니까?!',
#  '최형사:지금 항명하는거야?!',
#  '이형사:(화난 듯)예 써!',
#  '최형사:한 번 해보겠다는 거야?!',
#  '이형사:(가소롭다는 듯 바라보며)허, 참….',
#  '하는 순간 날아오는 최형사의 주먹을 맞고 자빠지는 이형사. 정보원들, 일제히 이형사님, 죄송합니다. 따위를 말하며 일순간에 흩어지는 속에 일어나는 이형사.',
#  '정보2:야… 경찰에 신고해야 되는거 아냐?',
#  '정보2:놔둬. 지들끼리 싸우는데 뭐.',
#  '씬 75 무도관',
#  '텅빈 무도관, 무도복 차림의 최형사 앞에서 화려한 예비동작으로 몸이라도 푸는 이형사, 멈춰 뒤돌아서더니',
#  '이형사:여지껏 여자를 때리는 놈만큼 한심한 놈은 없다고 믿었지만, 지금은 예외야! 날 원망하지마!',
#  '최형사:그래? 말 끝났으면 시작하지?',
#  '이형사:선제 공격해! 그 정돈 접어주지.',
#  '최형사:각오해!',
#  '이형사:(기합을 내지르며)햐!',
#  '최형사의 빠른 발놀림을 피하는 이형사. 최형사가 내뻗는 주먹을 피하고 엎어치기라도 할 듯 가슴팍을 확 잡았다가는 놀란 듯 멈칫 하며 바라보면, 날아오는 최형사의 발차기에 뒤로 나자빠진다. 다시 겨루기를 하는 투캅스, 이번에도 서로의 공격을 잘 막다가 이형사가 주먹으로 최형사의 가슴을 때리려다 움찔하면 어느새 최형사가 퍼버벅! 연타 공격을 해 뒤로 나자빠지는 이형사.',
#  '이형사:더 이상 안봐줘!',
#  '이야! 고함을 지르며 최형사와 다시 겨루는 이형사. 두사람, 화려하게 공격을 하다간 서로 동시에 발차기에 맞고 넘어졌다간 동시에 훌쩍 일어난다.',
#  '그렇게 난타전을 벌이는 도중 서로 지친 상태에서 이형사가 최형사의 가슴팍을 때리곤 최형사가 가슴을 잡고 움찔하자 힘껏 올라오는 발이 이형사의 사타구니를 강타한다. 읔! 그 곳을 맞은 채 완전히 몸이 굳는 이형사, 손을 그 곳으로 가져가는 순간, 최형사의 주먹에 이은 발차기가 강타한다.',
#  '퍽! 뒤로 나자빠지는 이형사.',
#  '최형사:이건 상사로써가 아니라 여지껏 여자들을 무시한 대가예요. 억울하면 소문내고 다니세요.',
#  '하며 휙 돌아서가는 최형사 뒤로 그곳을 만지며 웅크리고 있는 이형사의 모습 속에―',
#  '씬 76 이형사 집 방 안(N)',
#  '화면 가득 멍이 든 눈을 한 이형사가 아버지와 술을 마시고 있다. 인상을 쓴 채 술을 마시고 잔을 내려놓는 아버지.',
#  '아버지:뭐? 사표?',
#  '이형사:더 이상 스타일 구기면서 다닐 수는 없습니다.',
#  '아버지:(뒷통수를 때리며)임마! 구겨졌으면 펴야지! 도망가면 어떡해? 너, 만약 최형사의 마수에서 벗어날 수만 있다면 뭐든 지 다 할 수 있어?',
#  '이형사:예. 뭐든지요.',
#  '아버지:그럼 됐어. 최형사, 애인있어?',
#  '이형사:그 성격에 남아날 남자가 있겠습니까?',
#  '아버지:그러니까 이를 갈잖아, 임마. 잘들어, 정공법이야! 남자로써 접근해',
#  '이형사:예?',
#  '아버지:니 엄마도 옛날엔 여장부였어, 임마. 약올리면 주먹부터 나갔는데 나도 한방에 기절했다니까. 그런데 어느날, 물레방앗간에서 같이 별을 보며 하룻밤을 보내고 난 뒤론 내가 말만 하면 고개 숙이고 예～ 딱, 그냥 한방에 바뀌더라니까.',
#  '이형사:예? 그럼 최형사하고…?(질겁하며)으… 안됩니다.',
#  '아버지:왜 안돼, 임마? 넌 결혼 안할꺼야? 니가 당한거 평생 복수하면서 살 수 있다니까?',
#  '할말이 없는 듯 아버지를 보는 이형사.',
#  '이형사:그냥 사표 쓰겠습니다. 아버지',
#  '씬 77 경찰서',
#  '깔끔한 정장을 쫙 빼입고 무스까지 뿌린 채 걸어오는 이형사. 주변의 형사들이 의아하게 바라보는 가운데 최형사도 힐끗 본다.',
#  '형사1:와～ 이형사, 멋진데? 오늘 선이라도 봐?',
#  '이형사:아뇨, 스타일 바꿨습니다.(미소)괜찮습니까? 최반장님.',
#  '최반장:(무시하고, 일어나며)자, 다 모였으면 조례 시작하겠습니다. 오늘은…',
#  '김빠지는 이형사. 이때, 배달원이 기웃거리며 다가와',
#  '배달원:저, 최형사님?',
#  '최형사:그런데요?',
#  '배달원:(꽃을 내밀며)어떤 남자 분이 전화로 주문하셨습니다.(서류를 내밀며)여기 사인 좀….',
#  '형사2:와… 죽이는데? 아침부터 꽃 선물받고….',
#  '이형사:(너스레)최반장님, 좋겠습니다.',
#  '최형사, 배달원이 인사를 하고 가면 재채기와 함께 꽃을 휴지통에 확 내던진다.',
#  '최형사:아이, 증말 어떤 놈이야? 꽃 알레르기 있는 사람 죽으란 거야? 뭐야? 아침부터 재수없게! 에취!',
#  '이런 최형사를 보며 인상을 쓴 채 고개를 돌리는 이형사.',
#  '씬 78 달리는 차 안',
#  '부드러운 음악이 흐르는 속에 운전을 하는 이형사 옆에 앉은 최형사.',
#  '이형사:날씨 정말 좋다. 이런 날엔 산과 강이 쫘악～ 펼쳐진 야외로 드라이브나 가면 끝내주겠군. 안 그래요?',
#  '최형사:(재채기를 하곤 인상을 쓰며)이형사, 향수 뿌렸나?',
#  '이형사:네, 어떻습니까?',
#  '최형사:(창문을 열며)갑자기 왜 안하던 짓 하고 그래? 나 토할려고 하잖아?!',
#  '씬 79 어느 골목',
#  '작은 골목의 어느 꽃집 건너편에 천천히 멈춰서는 투캅스의 차.',
#  '씬 80 차 안',
#  '천천히 정차하는 차를 운전하는 이형사 옆에 앉아있는 최형사.',
#  '최형사:(놀란 듯)그게 사실이야?',
#  '이형사:예. 확실한 정보원의 제보입니다. 현재로선 가장 유력한 용의자입니다.',
#  '최형사:어떤 놈이야?',
#  '이형사:(어느 꽃집을 가리키며)저기… 저 놈입니다.',
#  '하고 보면, 험악하게 생긴 놈이 큰 가위를 들고 꽃가지를 쳐대고 있다.',
#  '이형사:바람피운 마누라가 잠든 순간, 가위로 목을 따 살인하고 얼마 전에 출소했는데 항상 가위가 든 가방을 들고 다닌다고 합니다.',
#  '최형사:그래?(나가려하며)그럼, 잡아야지.',
#  '이형사:(잡으며)지금 체포하면 안됩니다. 확실한 물증을 잡아야죠!',
#  '씬 81 꽃집',
#  '이형사, 어느 장미를 가리키자 용의자, 장미를 빼내 가위로 자르곤 뒷쪽에서 포장하는 동안 한켠에 놓은 가방으로 다가가는 이형사, 몰래 가방옆 쪽에 작은 기계를 부착한다. 슬쩍 보는 용의자와 눈이 마주치면 윙크를 하는 이형사와 고개를 끄덕이며 장미를 포장하는 용의자.',
#  '씬 82 차 안(D―N)',
#  '들어오는 이형사, 꽃을 최형사에게 건네며',
#  '이형사:설치했습니다.',
#  '최형사:(재채기를 하며)에취!(고개를 돌린 채)저리 치워!',
#  '타임 컷 ―',
#  '어느덧 밤이 된 거리를 바라보며 앉아있는 최형사. 꽃가게도 불이 켜져 있고, 한 여자가 용의자와 웃음을 교환하더니 용의자와 같이 나온다. 가게불을 끄는 용의자를 보곤, 졸고있는 이형사를 툭툭 치는 최형사.',
#  '최형사:놈이 움직여!',
#  '이형사:(졸다가 깨선, 시동을 걸며)저도 봤습니다.',
#  '씬 83 러브텔 안',
#  '망원경으로 보이는―',
#  '여자의 속옷을 가위로 자르는 용의자.',
#  '?소리:꼭 이렇게 해야 돼?',
#  '?소리:난 가위가 없으면 흥분이 안돼.',
#  '?소리: (키스를 하며)오빠가 속옷 사 줘야돼.',
#  '불이 꺼진 방안에서 망원경으로 건너편을 바라보고 있는 최형사와 소형카세트를 조작하는 이형사.',
#  '최형사:(다가와선)이런 건 언제 구했어?',
#  '이형사:항상 비상용으로 가지고 다니죠.(망원경을 뺏으며)이젠 내가 감시하죠.',
#  '최형사:(다시 뺏으며)보긴 뭘 봐?',
#  '곧이어 뽀뽀하는 소리가 여자의 간드러지는 소리에서 신음소리로 바뀌면 이형사와 최형사, 서로 눈이 마주치자 뒤로 물러나 앉는다.',
#  '최형사:이제 끄지?',
#  '이형사:껐습니다.',
#  '최형사:계속 들리잖아?',
#  '이형사:도청기 소리가 아닙니다.',
#  '양 쪽 벽에서 들리는 여자의 신음소리에 어색한 듯 일어나는 최형사. 방을 둘러보다간 다시 앉는다. 이형사, 이런 최형사를 보다간 침대 한켠에 걸터앉는다. 투캅스, 옆방에서 들리는 신음소리 속에 침대 양 구석에 서로 앉아 있다가 아무래도 어색한 듯 일어나는 이형사.',
#  '이형사:티브이 켤까요?',
#  '최형사:(재빠르게)그래, 그게 좋겠어.',
#  '이형사, 앞쪽의 티브이를 켜고 다시 앉으면 티브이에서도 애로영화가 숨가쁘게 진행중이다. 투캅스, 그런 티브이를 보다가 다시 눈이 마주치면',
#  '최형사:(괜히 시비쪼로)뭐해? 안끄구?!',
#  '이형사:본 겁니까?',
#  '최형사:보긴 뭘 봐?! 나도 안본거야.',
#  '최형사, 말하고 보니 이상한 듯 다시 이형사와 눈이 마주친다.',
#  '이형사:그럼 볼까요? 특별히 할 것도 없잖습니까?',
#  '최형사:그래, 알아서 해.',
#  '하고 다시 화면을 보면 더 육감적인 살결이 오가고, 옆방의 소리는 점점 고조되고 있다. 투캅스, 서로 티브이를 보지 않는 척 고개를 갸웃거리면서 힐끔힐끔 화면을 보다가 침을 꿀꺽 삼키는 소리가 과장되게 들린다. 점점 극에 달하는 화면. 이형사, 이런 티브이를 보다가 최형사를 슬쩍 보다간',
#  '이형사:음료수 드시겠습니까?',
#  '최형사:됐어.',
#  '이형사:혹시… 제가 필요한 일 없습니까?',
#  '최형사:없어.',
#  '이형사, 콜라 캔을 뒤로 마구 흔든 뒤 최형사 쪽에서 따는 순간, 뿜어져 나오는 거품이 최형사의 옷을 덥친다.',
#  '이형사:이런!(최형사의 옷을 닦아주며)닦아줄께요',
#  '최형사:(이형사의 손을 치고 닦으며)괜찮아. 됐어.',
#  '이형사:괜찮긴요. 휴지론 안되겠는데요? 벗으세요. 얼룩지기 전에 닦아내고 오겠습니다.',
#  '최형사:여기서 벗으라구?',
#  '이형사:뭐 어떻습니까? 동료끼리 같이 일하다 보면 그럴 수도 있지요.',
#  '최형사:됐어! 내 옷을 이형사한테 왜 맡겨? 이형사 옷이나 신경써!',
#  '이형사:(옷을 보다가)이런… 나도 엉망이군요.',
#  '하며 웃통을 벗고 최형사 앞에서 근육질의 몸을 괜히 으쓱해 보이곤 최형사에게 다가와 진지한 표정으로 바라본다.',
#  '이형사:최형사님.',
#  '최형사:왜 그래?',
#  '이형사:(다시 으쓱하며)살다보면 때론 이성보단 본능에 충실하고 싶을 때가 있지 않습니까?',
#  '최형사:무슨 말하고 싶은거야?',
#  '이형사:다시 묻겠습니다. 전 이미 마음의 준비가 돼 있으니 편하게 대답하십시오. 정말 저한테 원하는 거 없습니까?',
#  '최형사:있어.',
#  '이형사:(다가오며)뭡니까?',
#  '최형사:보기 흉하니까 벌거벗고 다닐려면 욕실 가서 벗어!',
#  '이형사:(활짝 미소로)예 써～!(가다가 뒤돌아보며)비디오 보고 계십시오. 샤워하고 얼른 나오죠.',
#  '이형사가 욕실로 들어가면 불이 꺼진 건너편 방을 보는 최형사. 소형 카세트를 작동시키면 계속 여자의 신음소리가 들린다.',
#  '씬 84 건너편 모텔 방',
#  '규칙적으로 반동을 줘 삐그덕거리는 불꺼진 방의 침대에 떨어져 앉아 있는 용의자와 여자, 가방을 앞에 두고 신음소리를 내고 있다.',
#  '여자:아～ 아～(작게)목 아파.～ 아～(작게)언제까지 이래야 돼?',
#  '용의자:으….(슬쩍 건너편의 불꺼진 방을 보며, 작게)조금만 더 해.',
#  '여자:아….',
#  '하는 순간, 문을 박차고 들어오는 최형사.',
#  '최형사:(총을 겨눈 채)꼼짝마!',
#  '하고 보면, 용의자와 여자가 침대에 걸터 앉아있다가 손을 든다.',
#  '씬 85 모텔 방 안',
#  '문을 열고 들어오는 최형사, 방안을 보면 이형사가 팬티만 입은 채 침대에 점프하듯 눕는다.',
#  '이형사:(고통스러운 신음소리를 내며)아… 어디 갔다 왔습니까?',
#  '최형사:왜 그래?',
#  '이형사:(엎어져 누운 채)목욕탕에서 미끌어졌습니다. 아무래도 겹질린 것 같아요.',
#  '최형사:(다가오며)그래? 내가 치료해 줄까?',
#  '이형사:그래 주시겠습니까?',
#  '최형사:(어깨를 만지며)이쪽이야?',
#  '이형사:아뇨. 약간 더 아래…',
#  '하는 순간 이형사의 두 팔을 확 꺽는 최형사.',
#  '이형사:(고통스러운 듯)왜 이러십니까?',
#  '하고 돌아보면 문 앞에 용의자와 여자가 고개를 숙인 채 서있다.',
#  '이형사:어?',
#  '하는 순간 더 세게 팔을 꺽는 최형사, 이형사의 등짝에 손바닥을 찌억! 소리나게 때린다. 흐윽! 벌겋게 손자국이 남은 등짝에 굳은 표정으로 비명을 지르는 이형사.',
#  '최형사:일어나!',
#  '이형사:자, 잘못했….',
#  '하는 순간 이형사의 면상에 쩌억～ 정통으로 강타하는 최형사의 손바닥.',
#  '뒤로 나자빠져 침대에서 떨어지는 이형사를 보곤 겁에 질린 용의자와 여자, 슬금슬금 문밖으로 도망친다.',
#  '최형사:아침에 꽃 보낸 것도 너지?',
#  '이형사:(멍이든 채 고개를 끄덕이며)사실은 제가…',
#  '최형사:(어느새 이형사의 등짝에 발을 내리꽂으며)필요없어! 하루 종일 공무집행 방해에다 상사 성희롱까지 할려구 해?',
#  '이형사:(바닥에 완전 퍼진 채)잠깐… 잠깐…',
#  '최형사:흥～ 당장 사표에다 구속시킬 수도 있지만, 그건 내 성질에 안맞아. 아까부터 옷벗고 싶어했지? 따라나와!',
#  '하며 이형사의 머리를 잡아 일으킨다.',
#  '이형사:아니… 최형사님….',
#  '최형사:(퍼억～ 이형사의 배에 주먹을 꽂으며)시끄러! 확실히 버릇을 고쳐주지.',
#  '씬 86 거리',
#  '지나가는 사람들이 키키덕거리며 웃는 곳을 보면, 운전을 하고 있는 최형사의 차 백미러에 연결된 수갑을 손목에 찬 채 팬티차림으로 빠르게 쫓아가는 이형사, 등짝과 얼굴에 멍이 들어있다. 손짓도 해가며 키키덕거리는 사람들이 시선을 피하며 창문을 두들기기도 하는 속에 무표정하게 운전을 하는 최형사.',
#  '이형사, 난감한 듯 고개를 숙이고 가는데 사람들이 많은 곳에서 점점 속도를 줄이는 차, 화려한 네온사인 속에 조명까지 받는 이형사. 이런 이형사를 바라보는 최형사의 모습 위로 들리는',
#  '?무전:여기는 HQ, 여기는 HQ ….',
#  '씬 87 강변 어느 곳',
#  '누군가의 손이 가운을 벗기면, 목에 상처를 입고 발가벗겨진 채 눈을 뜨고 죽은 여자 시체의 모습 뒤로 최형사가 살펴보는 뒤로 최형사를 이글거리는 증오감속에 바라보는 이형사.',
#  '최형사:(휙 뒤돌아보며)공과 사도 구분 못해? 일 안할거면 당장 사표 써. 불명예퇴직 시켜줄테니!',
#  '이형사:좋습니다. 일단 사건 해결하고 봅시다.',
#  '하며 시체 옆으로 다가가는 이형사, 눈을 뜨고 죽은 시체의 목에 난 상처를 살핀다.',
#  '이형사:같은 놈이군.(하다간 시체의 얼굴 가까이 다가가 냄새를 맡는다.)',
#  '최형사:(뒤로 다가와서)또 뭐하는 거야?',
#  '이형사:(휙 뒤돌아보곤)그냥 보는 것도 안됩니까? 또 사과할까요?(다시 시체에 대고, 장난스레)아가씨, 미안해. 응? 미안하다구.',
#  '하며 최형사를 노려보며 지나치는 이형사.',
#  '씬 88 경찰서 사무실(D)',
#  '피곤한 듯 하품을 쩍쩍해대는 형사들에게 호통을 치고 있는 최형사.',
#  '최형사:도대체 뭘 하는 겁니까?! 그깟 몇 일 야근한 걸 갖고 벌써 지치면 어떡해요?!',
#  '형사1:이봐, 최반장, 집에 좀 가자구, 속옷도 좀 갈아입고….',
#  '이런 형사들 앞에서 전화기를 붙잡고 있는 어딘가와 통화하고 있는',
#  '이형사:(수화기를 든 채)그럼 사체에서 발견된 화학약품은 없습니까? 분명 이상한 냄새가 났다니까요.',
#  '이와 동시에 뒷모습으로 보이는 최형사 등의 모습',
#  '최형사:범인 잡기 전에 집에 들어갈 생각마세요! 알겠습니까?!',
#  '형사1:예.',
#  '형사2:(고개를 돌린 채, 작게)정말 악질이다. 악질.',
#  '이형사:(수화기를 든 채)아직도 조사 안하고 뭐하는 겁니까? 일 좀 하세요!',
#  '하며 수화기를 끊자 최형사 등 형사들이 바라본다.',
#  '형사1:왜 그래?',
#  '이형사:아닙니다.(하며 다시 전화버튼을 누른다)',
#  '최형사:(박수를 탁탁 치며)자, 그럼 모두들 힘내세요!',
#  "형사들, 모두 '아이구―' 등의 한숨을 쉬며 일어난다.",
#  '형사1:도대체 몇 일째야? 이러다 밖에서 우리 마누라 봐도 못알아 보겠네, 젠장.',
#  '형사2:전 집이나 제대로 찾아갈 수 있을 지 모르겠어요― 으휴―',
#  '하며 나가는 형사들.',
#  '이형사:(수화기를 들고)예. 경찰입니다. 몇가지 물어 볼 게 있어서….',
#  '이때, 제복을 입은 여경찰이 지나가자 휙 뒤돌아보는 이형사.',
#  '이형사:(벌떡 일어나며)잠깐 잠깐만!',
#  '여경:(뒤돌아보며)예? 저 말예요?',
#  '이형사:(다가가 머리카락을 킁킁거리며)흠― 흠―',
#  '여경:왜 이러세요?',
#  '이형사:이게 무슨 냄새지? 응? 흠― 흠―',
#  '여경:(움찔해 물러나며)왜요? 어제 파마했는데… 왜 그러세요?',
#  '최형사:(다가서며)왜 그래?!',
#  '이형사:(진지한 표정으로)미용실이야! 피해자들 모두 파마약 냄새가 났어. 갑시다!',
#  '하며 나가는 이형사를 뒤쫓아가는 최형사의 모습에서―',
#  '씬 89 동 미용실 안',
#  '어느 여자의 머리를 만지고 있는 느글느글하게 생긴 커트김 옆에 서있는 이형사와 최형사. 대기중인 한 여자손님(다음 피해자)과 여종업원들이 힐끗힐끗 본다.',
#  '커트김:(사진을 건네주며)처음보는 얼굴이라니까요.',
#  '이형사:친구들을 통해 이 미용실에 자주 왔다는 거 알고 있습니다. 다시 한 번 보십시오.',
#  '커트김:글세 모른다니까―(하다간 어떤 사진을 보곤)아, 잠깐만요. 이 언니는 이 미용실이 아니라…. 잠깐만 나오시죠?',
#  '하며 투캅스를 데리고 밖으로 나간다.',
#  '씬 90 동 밖 복도',
#  '가게안이 보이지 않는 코너에 서있는 미용사와 투캅스.',
#  '커트김:이 여자들이 모두 여기 단골인 건 사실입니다. 하지만 정말 우리 가게하곤 아무런 상관없어요. 이런 불미스런 일에 우리 가게가 어떻게건 관련된게 알려지면 우린 끝장이예요.(어느 종이를 내밀며)여기 나 뿐만이 아니라 우리 애들 연락처 다 있어요. 협조가 필요하면 영업 마치고 와주세요.(표정을 바꿔)그게 아니면 영장가지고 오시든지요. 그럼 이만…',
#  '하며 안으로 들어가버리는 커트김. 이형사, 뒤쫓아가려 하면 최형사가 붙잡는다.',
#  '최형사:그만둬.',
#  ...]

# %%
# 텍스트를 처리하기
twitter = Twitter()
results = []
lines = articles
words_all = []

for line in lines:
    # 형태소 분석하기
    malist = twitter.pos(line, norm=True, stem=True)
    print(malist)
    
    r = []
    for word in malist:
        # 명사/동사/부사만 걸러내기 
        if word[1] in ['Noun','Verb','Adjective']:
            r.append(word[0])
            words_all.append(word[0])
    rl = (" ".join(r)).strip()
    results.append(rl)
    #print(rl)
# Out:
# []
# [('씬', 'Noun'), ('1', 'Number'), ('달리다', 'Verb'), ('버스', 'Noun'), ('안', 'Noun')]
# [('타이틀', 'Noun'), ('이', 'Josa'), ('끝나다', 'Verb'), ('F', 'Alpha'), ('.', 'Punctuation'), ('I', 'Alpha'), ('되다', 'Verb'), ('―', 'Foreign')]
# [('경쾌', 'Noun'), ('하다', 'Verb'), ('달려오다', 'Verb'), ('서다', 'Verb'), ('시내버스', 'Noun'), ('.', 'Punctuation')]
# [('치익', 'Noun'), (',', 'Punctuation'), ('소리', 'Noun'), ('와', 'Josa'), ('함께', 'Adverb'), ('문', 'Noun'), ('이', 'Josa'), ('열리다', 'Verb'), ('기다리다', 'Verb'), ('있다', 'Adjective'), ('사람', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('올라타다', 'Verb'), ('.', 'Punctuation')]
# [('버스', 'Noun'), ('카드', 'Noun'), ('혹은', 'Adverb'), ('현금', 'Noun'), ('함', 'Noun'), ('앞', 'Noun'), ('으로', 'Josa'), ('오가다', 'Verb'), ('손', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('바라보다', 'Verb')]
# [('운전', 'Noun'), ('수', 'Noun'), (':(', 'Punctuation'), ('그냥', 'Noun'), ('지나치다', 'Verb'), ('사람', 'Noun'), ('을', 'Josa'), ('발견', 'Noun'), ('하곤', 'Josa'), (')', 'Punctuation'), ('아저씨', 'Noun'), (',', 'Punctuation'), ('차비', 'Noun'), ('내다', 'Verb'), ('?', 'Punctuation')]
# [('하다', 'Verb'), ('운전', 'Noun'), ('수가', 'Noun'), ('놓다', 'Verb'), ('보다', 'Verb'), (',', 'Punctuation'), ('가방', 'Noun'), ('을', 'Josa'), ('메다', 'Verb'), ('지나치다', 'Verb'), ('가다가', 'Noun'), ('뒤', 'Noun'), ('돌아보다', 'Verb'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('특유', 'Noun'), ('의', 'Josa'), ('인상', 'Noun'), ('을', 'Josa'), ('긁다', 'Verb'), ('들다', 'Verb'), ('볼펜', 'Noun'), ('을', 'Josa'), ('울다', 'Verb'), ('내미다', 'Verb'), ('.', 'Punctuation'), ('시선', 'Noun'), ('을', 'Josa'), ('피', 'Noun'), ('하다', 'Verb'), ('차', 'Noun'), ('를', 'Josa'), ('출발', 'Noun'), ('시키다', 'Verb'), ('운전', 'Noun'), ('수', 'Noun'), (',', 'Punctuation'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('버스', 'Noun'), ('가운데', 'Noun'), ('쯤', 'Suffix'), ('에', 'Josa'), ('서서', 'Noun'), ('가방', 'Noun'), ('을', 'Josa'), ('털썩', 'Noun'), ('내려놓다', 'Verb'), ('볼펜', 'Noun'), ('한', 'Determiner'), ('자루', 'Noun'), ('를', 'Josa'), ('치켜', 'Noun'), ('들', 'Suffix'), ('며', 'Josa')]
# [('꼴통', 'Noun'), (':(', 'Punctuation'), ('뒤뚱뒤뚱', 'Noun'), ('인사', 'Noun'), ('를', 'Josa'), ('하다', 'Verb'), (')', 'Punctuation'), ('차', 'Noun'), ('안', 'Noun'), ('에', 'Josa'), ('계시다', 'Verb'), ('신사', 'Noun'), (',', 'Punctuation'), ('숙녀', 'Noun'), ('여러분', 'Noun'), ('안녕하십니까', 'Noun'), ('.', 'Punctuation'), ('저', 'Noun'), ('는', 'Josa'), ('홧김', 'Noun'), ('에', 'Josa'), ('폭력', 'Noun'), (',', 'Punctuation'), ('겁', 'Noun'), ('도', 'Josa'), ('없이', 'Adverb'), ('유괴', 'Noun'), (',', 'Punctuation'), ('불타다', 'Adjective'), ('가슴', 'Noun'), ('으로', 'Josa'), ('강간', 'Noun'), ('등', 'Noun'), ('도합', 'Noun'), (',', 'Punctuation'), ('전과', 'Noun'), ('십이', 'Noun'), ('범', 'Noun'), ('으로', 'Josa'), ('얼마', 'Noun'), ('전', 'Noun'), ('에', 'Josa'), ('추다', 'Verb'), ('소한', 'Noun'), ('대책', 'Noun'), ('없다', 'Adjective'), ('어리다', 'Verb'), ('양', 'Noun'), ('이다', 'Adjective'), ('.(', 'Punctuation'), ('시선', 'Noun'), ('을', 'Josa'), ('피', 'Noun'), ('하다', 'Verb'), ('승객', 'Noun'), ('들', 'Suffix'), ('에게', 'Josa'), ('볼펜', 'Noun'), ('을', 'Josa'), ('한', 'Determiner'), ('자루', 'Noun'), ('씩', 'Suffix'), ('올려놓다', 'Verb'), (')', 'Punctuation'), ('아프다', 'Adjective'), ('과거', 'Noun'), ('는', 'Josa'), ('잊다', 'Verb'), ('꼬', 'Noun'), ('딱지', 'Noun'), ('만', 'Suffix'), ('한', 'Josa'), ('포장마차', 'Noun'), ('라고', 'Josa'), ('장만', 'Noun'), ('하다', 'Verb'), ('하니', 'Noun'), (',', 'Punctuation'), ('액땜', 'Noun'), ('하다', 'Verb'), ('생각', 'Noun'), ('하다', 'Verb'), ('가볍다', 'Adjective'), ('지갑', 'Noun'), ('을', 'Josa'), ('열다', 'Verb'), ('바라다', 'Verb'), ('.', 'Punctuation'), ('여러분', 'Noun'), ('의', 'Josa'), ('가정', 'Noun'), ('에', 'Josa'), ('불행', 'Noun'), ('이', 'Josa'), ('없다', 'Adjective'), ('간절', 'Noun'), ('히', 'Adverb'), ('소망', 'Noun'), ('하다', 'Verb'), ('(', 'Punctuation'), ('볼펜', 'Noun'), ('을', 'Josa'), ('들다', 'Verb'), ('보이', 'Noun'), ('며', 'Josa'), (')', 'Punctuation'), ('이', 'Noun'), ('볼펜', 'Noun'), ('을', 'Josa'), ('단돈', 'Noun'), ('삼천원', 'Noun'), ('에', 'Josa'), ('드리다', 'Verb'), ('.', 'Punctuation'), ('감사', 'Noun'), ('하다', 'Verb'), ('.', 'Punctuation')]
# [('인사', 'Noun'), ('를', 'Josa'), ('하고는', 'Josa'), ('돈', 'Noun'), ('을', 'Josa'), ('거두다', 'Verb'), ('들이다', 'Verb'), ('돌아다니다', 'Verb'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('험악', 'Noun'), ('한', 'Josa'), ('인상', 'Noun'), ('을', 'Josa'), ('쓰다', 'Verb'), ('보이', 'Noun'), ('자', 'Suffix'), ('순순하다', 'Adjective'), ('돈', 'Noun'), ('을', 'Josa'), ('주다', 'Verb'), ('아가씨', 'Noun'), ('.', 'Punctuation'), ('까다', 'Verb'), ('까다', 'Verb'), ('보이다', 'Verb'), ('남자', 'Noun'), ('가', 'Josa'), ('볼펜', 'Noun'), ('을', 'Josa'), ('돌려주다', 'Verb')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('난', 'Noun'), ('열', 'Noun'), ('받다', 'Verb'), ('입', 'Noun'), ('보다', 'Josa'), ('주먹', 'Noun'), ('이', 'Josa'), ('먼저', 'Noun'), ('나가다', 'Verb'), ('놓다', 'Verb'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('사내', 'Noun'), ('앞', 'Noun'), ('으로', 'Josa'), ('주먹', 'Noun'), ('을', 'Josa'), ('내미다', 'Verb'), (',', 'Punctuation'), ('얼른', 'Noun'), ('지갑', 'Noun'), ('에서', 'Josa'), ('돈', 'Noun'), ('을', 'Josa'), ('꺼내다', 'Verb'), ('주다', 'Verb'), ('사내', 'Noun'), ('.', 'Punctuation'), ('이번', 'Noun'), ('엔', 'Josa'), ('꾸벅', 'Noun'), ('꾸벅', 'Noun'), ('졸다', 'Verb'), ('있다', 'Adjective'), ('고등학생', 'Noun'), ('에게', 'Josa'), ('다가가다', 'Verb')]
# [('꼴통', 'Noun'), (':(', 'Punctuation'), ('툭툭', 'Noun'), (')', 'Punctuation'), ('야', 'Exclamation'), (',', 'Punctuation'), ('야', 'Exclamation'), ('!', 'Punctuation')]
# [('하지만', 'Conjunction'), ('깨지다', 'Verb'), ('않다', 'Verb'), ('뒷통수', 'Noun'), ('를', 'Josa'), ('퍽퍽치', 'Noun'), ('며', 'Josa')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('임마', 'Noun'), (',', 'Punctuation'), ('자다', 'Verb'), ('척', 'Noun'), ('하다', 'Verb'), ('.', 'Punctuation')]
# [('학생', 'Noun'), (':', 'Punctuation'), ('왜', 'Noun'), ('그렇다', 'Adjective'), ('?', 'Punctuation')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('삼천원', 'Noun'), ('내', 'Noun'), ('.', 'Punctuation')]
# [('학생', 'Noun'), (':', 'Punctuation'), ('왜', 'Noun'), ('요', 'Josa'), ('?', 'Punctuation')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('내', 'Determiner'), ('라면', 'Noun'), ('내', 'Noun'), (',', 'Punctuation'), ('빨리', 'Adverb'), ('안내', 'Noun'), ('!', 'Punctuation')]
# [('고등학생', 'Noun'), ('이', 'Josa'), ('돈', 'Noun'), ('을', 'Josa'), ('꺼내다', 'Verb'), ('다음', 'Noun'), ('으로', 'Josa'), ('넘어가다', 'Verb'), ('.', 'Punctuation'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('아이', 'Noun'), ('를', 'Josa'), ('안고', 'Noun'), ('창밖', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), ('척', 'Noun'), ('하다', 'Verb'), ('아줌마', 'Noun'), ('를', 'Josa'), ('보다', 'Verb'), ('아이', 'Noun'), ('의', 'Josa'), ('머리', 'Noun'), ('를', 'Josa'), ('쓰다듬다', 'Verb')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('아이구', 'Exclamation'), ('귀엽다', 'Adjective'), ('.', 'Punctuation')]
# [('아줌마', 'Noun'), (',', 'Punctuation'), ('돌아보다', 'Verb')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('저', 'Noun'), ('는', 'Josa'), ('겁', 'Noun'), ('도', 'Josa'), ('없이', 'Adverb'), ('"', 'Punctuation'), ('유괴', 'Noun'), ('"', 'Punctuation'), ('를', 'Noun'), ('두', 'Noun'), ('번', 'Noun'), ('이나', 'Josa'), ('하다', 'Verb'), ('죽이다', 'Verb'), ('놓다', 'Verb'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('이번', 'Noun'), ('엔', 'Josa'), ('겁', 'Noun'), ('먹다', 'Verb'), ('아이', 'Noun'), ('의', 'Josa'), ('볼', 'Noun'), ('을', 'Josa'), ('살짝', 'Noun'), ('꼬집는', 'Noun'), ('다', 'Josa'), ('.', 'Punctuation'), ('아줌마', 'Noun'), (',', 'Punctuation'), ('얼른', 'Noun'), ('손', 'Noun'), ('에', 'Josa'), ('쥐', 'Noun'), ('고', 'Josa'), ('있다', 'Adjective'), ('돈', 'Noun'), ('을', 'Josa'), ('주다', 'Verb'), ('아이', 'Noun'), ('를', 'Josa'), ('끌어안다', 'Verb'), ('.', 'Punctuation'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('몇몇', 'Noun'), ('사람', 'Noun'), ('에게', 'Josa'), ('순순하다', 'Adjective'), ('돈', 'Noun'), ('을', 'Josa'), ('받다', 'Verb'), ('뒷', 'Noun'), ('자리', 'Suffix'), ('로', 'Josa'), ('향', 'Noun'), ('하다', 'Verb'), ('버스', 'Noun'), ('안', 'Noun'), ('에서', 'Josa'), ('일어나다', 'Verb'), ('사태', 'Noun'), ('를', 'Josa'), ('전혀', 'Noun'), ('의식', 'Noun'), ('하다', 'Verb'), ('못', 'Noun'), ('한', 'Josa'), ('채', 'Noun'), ('귀', 'Noun'), ('엔', 'Josa'), ('이어폰', 'Noun'), ('을', 'Josa'), ('끼', 'Noun'), ('고', 'Josa'), ('창', 'Noun'), ('밖', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), ('뭔가', 'Noun'), ('를', 'Josa'), ('메모', 'Noun'), ('하고', 'Josa'), ('있다', 'Adjective'), ('하다', 'Verb'), ('여자', 'Noun'), ('앞', 'Noun'), ('에', 'Josa'), ('다가서다', 'Verb'), ('.', 'Punctuation'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('다짜고짜', 'Noun'), ('그녀', 'Noun'), ('의', 'Josa'), ('어깨', 'Noun'), ('에', 'Josa'), ('손', 'Noun'), ('을', 'Josa'), ('올려놓다', 'Verb'), ('특유', 'Noun'), ('의', 'Josa'), ('인상', 'Noun'), ('을', 'Josa'), ('긁다', 'Verb'), ('깜짝', 'Noun'), ('놀라다', 'Verb'), ('돌아보다', 'Verb'), ('기다', 'Verb'), ('생머리', 'Noun'), ('의', 'Josa'), ('시원', 'Noun'), ('스런', 'Josa'), ('얼굴', 'Noun'), ('의', 'Josa'), ('여자', 'Noun'), (',', 'Punctuation'), ('바로', 'Noun'), ('이', 'Noun'), ('영화', 'Noun'), ('의', 'Josa'), ('신임', 'Noun'), ('여', 'Noun'), ('형', 'Suffix'), ('사인', 'Noun'), ('최', 'Noun'), ('형사', 'Noun'), ('다', 'Josa'), ('.', 'Punctuation')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('나', 'Noun'), ('는', 'Josa'), ('"', 'Punctuation'), ('강간', 'Noun'), ('"', 'Punctuation'), ('도', 'Noun'), ('(', 'Punctuation'), ('하다', 'Verb'), ('여자', 'Noun'), ('의', 'Josa'), ('머리카락', 'Noun'), ('을', 'Josa'), ('배배', 'Noun'), ('꼬', 'Noun'), ('며', 'Josa'), (')', 'Punctuation'), ('세', 'Noun'), ('번', 'Noun'), ('이나', 'Josa'), ('하다', 'Verb'), ('…', 'Foreign')]
# [('어이', 'Noun'), ('가', 'Josa'), ('없다', 'Adjective'), ('쳐다보다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('가', 'Josa'), ('겁', 'Noun'), ('이라도', 'Josa'), ('먹다', 'Verb'), ('줄', 'Noun'), ('알', 'Noun'), ('고', 'Josa'), ('핸드백', 'Noun'), ('을', 'Josa'), ('자기', 'Noun'), ('손', 'Noun'), ('으로', 'Josa'), ('열다', 'Verb'), ('돈', 'Noun'), ('을', 'Josa'), ('꺼내다', 'Verb'), ('수갑', 'Noun'), (',', 'Punctuation'), ('권총', 'Noun'), ('을', 'Josa'), ('발견', 'Noun'), ('하곤', 'Josa'), ('굳어지다', 'Verb'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('하지만', 'Conjunction'), ('상대', 'Noun'), ('가', 'Josa'), ('이다', 'Verb'), ('지라', 'Noun'), ('표정', 'Noun'), ('을', 'Josa'), ('다시', 'Noun'), ('정리', 'Noun'), ('하다', 'Verb')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('너', 'Noun'), ('경찰', 'Noun'), ('야', 'Josa'), ('?', 'Punctuation'), ('자다', 'Verb'), ('만나다', 'Verb'), ('.', 'Punctuation'), ('난', 'Noun'), ('경찰', 'Noun'), ('이', 'Determiner'), ('라면', 'Noun'), ('이', 'Noun'), ('가', 'Josa'), ('갈리', 'Noun'), ('는', 'Josa'), ('놈', 'Noun'), ('이야', 'Josa'), ('!', 'Punctuation')]
# [('순간', 'Noun'), (',', 'Punctuation'), ('턱', 'Noun'), ('!', 'Punctuation'), ('쪼인트', 'Noun'), ('를', 'Josa'), ('맞다', 'Verb'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('신음', 'Noun'), ('과', 'Josa'), ('함께', 'Adverb'), ('고개', 'Noun'), ('를', 'Josa'), ('치켜', 'Noun'), ('들', 'Suffix'), ('며', 'Josa')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('어쭈', 'Noun'), ('?', 'Punctuation'), ('치다', 'Verb'), ('?', 'Punctuation'), ('이', 'Noun'), ('게', 'Josa'), ('내', 'Noun'), ('가', 'Josa'), ('누군지', 'Adverb'), ('알', 'Noun'), ('고', 'Josa'), ('…', 'Foreign')]
# [('하지만', 'Conjunction'), ('말', 'Noun'), ('이', 'Josa'), ('끝나다', 'Verb'), ('전', 'Noun'), ('에', 'Josa'), ('곧장', 'Noun'), ('날아오다', 'Verb'), ('최', 'Noun'), ('형', 'Suffix'), ('사의', 'Noun'), ('주먹', 'Noun'), ('에', 'Josa'), ('퍽', 'Noun'), ('!', 'Punctuation'), ('뒤', 'Noun'), ('로', 'Josa'), ('나다', 'Verb'), ('빠지다', 'Verb'), ('.', 'Punctuation')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('으', 'Adverb'), ('…', 'Foreign'), ('(', 'Punctuation'), ('코피', 'Noun'), ('를', 'Josa'), ('쓰윽', 'Noun'), ('닦다', 'Verb'), (',', 'Punctuation'), ('질겁', 'Noun'), ('하곤', 'Josa'), ('일어나며', 'Noun'), (')', 'Punctuation'), ('피다', 'Verb'), ('?', 'Punctuation'), ('이', 'Noun'), ('씨', 'Noun'), ('!(', 'Punctuation'), ('웃통', 'Noun'), ('을', 'Josa'), ('벗다', 'Verb'), (')', 'Punctuation'), ('끼어들다', 'Verb'), ('놈', 'Noun'), ('있다', 'Adjective'), ('죽이다', 'Verb'), ('버리다', 'Verb'), ('!', 'Punctuation')]
# [('겁', 'Noun'), ('에', 'Josa'), ('지다', 'Verb'), ('피', 'Noun'), ('하다', 'Verb'), ('사람', 'Noun'), ('들', 'Suffix'), ('.', 'Punctuation')]
# [('꼴통', 'Noun'), (':(', 'Punctuation'), ('괜히', 'Adverb'), ('버스', 'Noun'), ('를', 'Josa'), ('머리', 'Noun'), ('로', 'Josa'), ('받다', 'Verb'), (')', 'Punctuation'), ('씨발', 'Noun'), (',', 'Punctuation'), ('사고', 'Noun'), ('치기', 'Noun'), ('싫다', 'Adjective'), (',', 'Punctuation'), ('내', 'Noun'), ('인생', 'Noun'), ('은', 'Josa'), ('왜', 'Noun'), ('이렇게', 'Adverb'), ('꼬이다', 'Adjective'), ('?(', 'Punctuation'), ('휙', 'Noun'), ('손가락', 'Noun'), ('으로', 'Josa'), ('가리키다', 'Verb'), (')', 'Punctuation'), ('이', 'Determiner'), ('것', 'Noun'), ('은', 'Josa'), ('니', 'Noun'), ('잘못', 'Noun'), ('이야', 'Josa'), ('!', 'Punctuation')]
# [('하다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('를', 'Josa'), ('향', 'Noun'), ('하다', 'Verb'), ('저돌', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('돌다', 'Verb'), ('꼴통', 'Noun'), ('!', 'Punctuation'), ('하지만', 'Conjunction'), ('달려오다', 'Verb'), ('꼴통', 'Noun'), ('을', 'Josa'), ('멋지다', 'Adjective'), ('업다', 'Verb'), ('받다', 'Verb'), ('넘기다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation'), ('꽈당', 'Adverb'), ('!', 'Punctuation'), ('버스', 'Noun'), ('바닥', 'Noun'), ('이', 'Josa'), ('찌', 'Noun'), ('그렇다', 'Adjective'), ('정도', 'Noun'), ('로', 'Josa'), ('떨어지다', 'Verb'), ('꼴통', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('자신', 'Noun'), ('의', 'Josa'), ('K', 'Alpha'), ('.', 'Punctuation'), ('O', 'Alpha'), ('패', 'Noun'), ('를', 'Josa'), ('인정', 'Noun'), ('하곤', 'Josa'), ('최', 'Noun'), ('형사', 'Noun'), ('를', 'Josa'), ('향', 'Noun'), ('하다', 'Verb'), ('두', 'Determiner'), ('손', 'Noun'), ('을', 'Josa'), ('모으다', 'Verb'), ('빌다', 'Verb')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('아이고', 'Exclamation'), (',', 'Punctuation'), ('제', 'Noun'), ('가', 'Josa'), ('그만', 'Adverb'), ('흥분', 'Noun'), ('을', 'Josa'), ('하다', 'Verb'), ('……', 'Foreign')]
# [('최', 'Noun'), ('형사', 'Noun'), (',', 'Punctuation'), ('표정', 'Noun'), ('조차', 'Josa'), ('변하다', 'Adjective'), ('않다', 'Verb'), ('채', 'Noun'), ('뚜둑', 'Noun'), ('뚜둑', 'Noun'), (',', 'Punctuation'), ('몸', 'Noun'), ('을', 'Josa'), ('풀다', 'Verb'), ('다가서다', 'Verb'), ('.', 'Punctuation')]
# [('꼴통', 'Noun'), (':(', 'Punctuation'), ('휘둥그레지', 'Noun'), ('며', 'Josa'), (')', 'Punctuation'), ('아니다', 'Adjective'), ('왜', 'Noun'), ('이르다', 'Verb'), ('?', 'Punctuation'), ('잘못', 'Noun'), ('하다', 'Verb'), ('!', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':(', 'Punctuation'), ('멱살', 'Noun'), ('을', 'Josa'), ('잡다', 'Verb'), ('일으키다', 'Verb'), ('세우다', 'Verb'), (')', 'Punctuation'), ('아직', 'Noun'), ('안', 'Noun'), ('끝나다', 'Verb'), ('!', 'Punctuation')]
# [('씬', 'Noun'), ('2', 'Number'), ('거리', 'Noun')]
# [('달리다', 'Verb'), ('버스', 'Noun'), ('에서', 'Josa'), ('과장', 'Noun'), ('되게', 'Adverb'), ('들려오다', 'Verb'), ('꼴통', 'Noun'), ('의', 'Josa'), ('비명', 'Noun'), ('소리', 'Noun'), ('.', 'Punctuation'), ('퍽', 'Noun'), ('!', 'Punctuation'), ('퍽', 'Noun'), ('!', 'Punctuation'), ('우두둑', 'Noun'), ('!', 'Punctuation'), ('맞다', 'Verb'), ('소리', 'Noun'), ('와', 'Josa'), ('함께', 'Adverb'), ('좌우', 'Noun'), ('로', 'Josa'), ('요동', 'Noun'), ('치다', 'Verb'), ('버스', 'Noun'), ('.', 'Punctuation'), ('우지끈', 'Noun'), ('!', 'Punctuation'), ('어딘가', 'Noun'), ('부러지다', 'Verb'), ('듯', 'Noun'), ('한', 'Josa'), ('소리', 'Noun'), ('와', 'Josa'), ('함께', 'Adverb'), ('끼', 'Noun'), ('이익', 'Noun'), ('멈추다', 'Verb'), ('서다', 'Verb'), ('버스', 'Noun'), ('위로', 'Noun'), ('덥다', 'Adjective'), ('타이틀', 'Noun'), ('―', 'Foreign'), ('<', 'Punctuation'), ('투캅스', 'Noun'), ('3', 'Number'), ('>', 'Punctuation')]
# [('씬', 'Noun'), ('3', 'Number'), ('어느', 'Adverb'), ('집', 'Noun'), ('거실', 'Noun')]
# [('자막', 'Noun'), ('이', 'Josa'), ('사라지다', 'Verb'), ('선행', 'Noun'), ('하다', 'Verb'), ('초인종', 'Noun'), ('소리', 'Noun'), ('속', 'Noun'), ('에', 'Josa'), ('―', 'Foreign')]
# [('화면', 'Noun'), ('가득', 'Noun'), ('현관문', 'Noun'), ('의', 'Josa'), ('반투명', 'Noun'), ('유리', 'Noun'), ('로', 'Josa'), ('남자', 'Noun'), ('의', 'Josa'), ('형체', 'Noun'), ('가', 'Josa'), ('보이다', 'Verb'), ('속', 'Noun'), ('에', 'Josa'), ('끼', 'Noun'), ('리릭', 'Noun'), ('～', 'Foreign'), ('끼', 'Noun'), ('리릭', 'Noun'), ('～', 'Foreign'), ('소리', 'Noun'), ('와', 'Josa'), ('함께', 'Adverb'), ('문고', 'Noun'), ('리가', 'Noun'), ('탁', 'Noun'), ('!', 'Punctuation'), ('하다', 'Verb'), ('위로', 'Noun'), ('젖다', 'Verb'), (',', 'Punctuation'), ('스르르', 'Noun'), ('열리다', 'Verb'), ('문', 'Noun'), ('으로', 'Josa'), ('들어오다', 'Verb'), ('구두', 'Noun'), ('에서부터', 'Josa'), ('카메라', 'Noun'), ('틸업하', 'Noun'), ('면', 'Josa'), (',', 'Punctuation'), ('손', 'Noun'), ('에', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), ('을', 'Josa'), ('끼다', 'Verb'), ('사내', 'Noun'), ('가', 'Josa'), ('열다', 'Verb'), ('있다', 'Adjective'), ('문', 'Noun'), ('으로', 'Josa'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('을', 'Josa'), ('끼다', 'Verb'), ('사내', 'Noun'), ('가', 'Josa'), ('쌕', 'Noun'), ('을', 'Josa'), ('맨', 'Noun'), ('채', 'Noun'), ('들어오다', 'Verb'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), ('이', 'Josa'), ('날카롭다', 'Adjective'), ('눈매', 'Noun'), ('로', 'Josa'), ('고개', 'Noun'), ('를', 'Josa'), ('휙', 'Noun'), ('저으', 'Noun'), ('면', 'Josa'), ('빠르다', 'Adjective'), ('움직이다', 'Verb'), ('목', 'Noun'), ('장갑', 'Noun'), (',', 'Punctuation'), ('방문', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('열다', 'Verb'), ('가다', 'Verb'), ('어느', 'Adverb'), ('방', 'Noun'), ('앞', 'Noun'), ('에서', 'Josa'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), ('고개', 'Noun'), ('를', 'Josa'), ('끄덕이다', 'Verb'), ('그', 'Determiner'), ('곳', 'Noun'), ('으로', 'Josa'), ('걸어가다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('4', 'Number'), ('동', 'Noun'), ('방안', 'Noun')]
# [('금고', 'Noun'), ('에', 'Josa'), ('청진기', 'Noun'), ('를', 'Josa'), ('대다', 'Verb'), ('채', 'Noun'), ('번호판', 'Noun'), ('을', 'Josa'), ('돌리다', 'Verb'), ('있다', 'Adjective'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('뒤', 'Noun'), ('로', 'Josa'), ('각종', 'Noun'), ('그림', 'Noun'), (',', 'Punctuation'), ('도자기', 'Noun'), ('등', 'Noun'), ('이', 'Josa'), ('널린', 'Noun'), ('방', 'Noun'), ('의', 'Josa'), ('서랍', 'Noun'), ('따위', 'Noun'), ('를', 'Josa'), ('뒤지다', 'Verb'), ('있다', 'Adjective'), ('목', 'Noun'), ('장갑', 'Noun'), (',', 'Punctuation'), ('천원', 'Noun'), ('짜다', 'Verb'), ('몇', 'Noun'), ('장', 'Noun'), ('과', 'Josa'), ('은장도', 'Noun'), (',', 'Punctuation'), ('씨거', 'Noun'), (',', 'Punctuation'), ('엽전', 'Noun'), ('등', 'Noun'), ('을', 'Josa'), ('쌕', 'Noun'), ('에', 'Josa'), ('넣다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('의', 'Josa'), ('눈치', 'Noun'), ('를', 'Josa'), ('보다', 'Verb'), ('몰래', 'Noun'), ('천원', 'Noun'), ('짜다', 'Verb'), ('리', 'Noun'), ('를', 'Josa'), ('주머니', 'Noun'), ('에', 'Josa'), ('챙기다', 'Verb'), ('기도', 'Noun'), ('하다', 'Verb'), ('목', 'Noun'), ('장갑', 'Noun'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':(', 'Punctuation'), ('청진기', 'Noun'), ('를', 'Josa'), ('대다', 'Verb'), ('채', 'Noun'), (')', 'Punctuation'), ('하다', 'Verb'), ('껀', 'Noun'), ('하다', 'Verb'), ('돈', 'Noun'), ('함부로', 'Noun'), ('쓰다', 'Verb'), ('마르다', 'Adjective'), ('.', 'Punctuation'), ('상법', 'Noun'), ('이', 'Suffix'), ('가', 'Josa'), ('왜', 'Noun'), ('잡히다', 'Verb'), ('아', 'Noun'), ('나', 'Josa'), ('?', 'Punctuation'), ('돈', 'Noun'), ('생기다', 'Verb'), ('친구', 'Noun'), ('들', 'Suffix'), ('데리', 'Noun'), ('고', 'Josa'), ('룸싸롱', 'Noun'), ('에서', 'Josa'), ('쭉쭉', 'Noun'), ('빵빵', 'Noun'), ('죽이다', 'Verb'), ('년', 'Noun'), ('들', 'Suffix'), ('끼', 'Noun'), ('고', 'Josa'), ('술', 'Noun'), ('졸다', 'Verb'), ('퍼마셨', 'Noun'), ('지', 'Josa'), (',', 'Punctuation'), ('근데', 'Adverb'), ('이', 'Noun'), ('친구', 'Noun'), ('란', 'Noun'), ('새끼', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('아침', 'Noun'), ('에', 'Josa'), ('해장국', 'Noun'), ('먹다', 'Verb'), ('갑자기', 'Noun'), ('이렇다', 'Adjective'), ('생각', 'Noun'), ('이', 'Josa'), ('들다', 'Verb'), ('.', 'Punctuation'), ('자기', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('어제', 'Noun'), ('하다', 'Verb'), ('번', 'Noun'), ('얻어먹다', 'Verb'), ('저', 'Noun'), ('새', 'Noun'), ('끼다', 'Verb'), ('그렇다', 'Adjective'), ('데', 'Noun'), ('서', 'Josa'), ('맨날', 'Adverb'), ('처', 'Noun'), ('먹다', 'Verb'), ('끄다', 'Verb'), ('생각', 'Noun'), ('하다', 'Verb'), ('괜히', 'Adverb'), ('열', 'Noun'), ('받다', 'Verb'), ('?', 'Punctuation'), ('씨발', 'Noun'), (',', 'Punctuation'), ('그래서', 'Adverb'), ('경찰', 'Noun'), ('에', 'Josa'), ('수상한', 'Noun'), ('놈', 'Noun'), ('있다', 'Adjective'), ('찌다', 'Verb'), ('잡히다', 'Verb'), ('.', 'Punctuation'), ('절대', 'Noun'), ('친하다', 'Adjective'), ('놈', 'Noun'), ('들', 'Suffix'), ('한테', 'Josa'), ('돈', 'Noun'), ('쓰다', 'Verb'), ('마르다', 'Adjective'), (',', 'Punctuation'), ('알다', 'Verb'), ('?', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':', 'Punctuation'), ('예', 'Noun'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('안', 'VerbPrefix'), ('보다', 'Verb'), ('꼬불칠', 'Noun'), ('생각', 'Noun'), ('하다', 'Verb'), ('마르다', 'Adjective'), (',', 'Punctuation'), ('나중', 'Noun'), ('에', 'Josa'), ('죽다', 'Verb'), ('.', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':(', 'Punctuation'), ('주머니', 'Noun'), ('에서', 'Josa'), ('돈', 'Noun'), ('을', 'Josa'), ('꺼내다', 'Verb'), (')', 'Punctuation'), ('예', 'Noun'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('다시', 'Noun'), ('천원', 'Noun'), ('권', 'Suffix'), ('지폐', 'Noun'), ('를', 'Josa'), ('꺼내다', 'Verb'), ('쌕', 'Noun'), ('안', 'Noun'), ('으로', 'Josa'), ('밀다', 'Verb'), ('놓다', 'Verb'), ('.', 'Punctuation'), ('딸칵', 'Noun'), ('!', 'Punctuation'), ('소리', 'Noun'), ('와', 'Josa'), ('함께', 'Adverb'), ('미소', 'Noun'), ('지다', 'Verb'), ('금고', 'Noun'), ('손잡이', 'Noun'), ('를', 'Josa'), ('잡다', 'Verb'), ('천천히', 'Adverb'), ('여', 'Noun'), ('는', 'Josa'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('.', 'Punctuation'), ('목', 'Noun'), ('장갑', 'Noun'), (',', 'Punctuation'), ('재빨리', 'Adverb'), ('뒤', 'Noun'), ('로', 'Josa'), ('다가오다', 'Verb'), ('.', 'Punctuation'), ('흑', 'Adverb'), ('장갑', 'Noun'), (',', 'Punctuation'), ('미소', 'Noun'), ('지은', 'Noun'), ('채', 'Noun'), ('금고', 'Noun'), ('를', 'Josa'), ('열다', 'Verb'), ('잉', 'Noun'), ('?', 'Punctuation'), ('～', 'Foreign'), ('표정', 'Noun'), ('이', 'Josa'), ('확', 'Noun'), ('변하다', 'Adjective'), ('.', 'Punctuation')]
# [('뒤', 'Noun'), ('어어', 'Noun'), ('고개', 'Noun'), ('를', 'Josa'), ('들이다', 'Verb'), ('밉다', 'Adjective'), ('목', 'Noun'), ('장갑', 'Noun'), ('의', 'Josa'), ('표정', 'Noun'), ('도', 'Josa'), ('확', 'Noun'), ('굳다', 'Adjective'), ('보다', 'Verb'), (',', 'Punctuation'), ('열리다', 'Verb'), ('문', 'Noun'), ('안', 'Noun'), ('으로', 'Josa'), ('금고', 'Noun'), ('가', 'Josa'), ('하나', 'Noun'), ('더', 'Noun'), ('보이다', 'Verb'), ('.', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':', 'Punctuation'), ('씨발', 'Noun'), ('…', 'Foreign'), ('.', 'Punctuation'), ('이', 'Noun'), ('새끼', 'Noun'), ('는', 'Josa'), ('금고', 'Noun'), ('장', 'Suffix'), ('사하나', 'Noun'), ('?', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('아니다', 'Adjective'), (',', 'Punctuation'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('이야', 'Josa'), ('.', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':', 'Punctuation'), ('예', 'Noun'), ('?', 'Punctuation'), ('그게', 'Noun'), ('뭡', 'Noun'), ('니까', 'Josa'), ('?', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('몰래', 'Noun'), ('남', 'Noun'), ('의', 'Josa'), ('무덤', 'Noun'), ('졸다', 'Verb'), ('파서', 'Noun'), ('골동품', 'Noun'), ('챙기다', 'Verb'), ('팔', 'Noun'), ('아', 'Josa'), ('먹다', 'Verb'), ('놓다', 'Verb'), ('.', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':', 'Punctuation'), ('한마디', 'Noun'), ('로', 'Josa'), ('벼락', 'Noun'), ('맞다', 'Verb'), ('새끼', 'Noun'), ('들이다', 'Verb'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('자', 'Noun'), ('방출', 'Noun'), ('장', 'Suffix'), ('간걸', 'Noun'), ('보다', 'Verb'), ('또', 'Noun'), ('어떻다', 'Adjective'), ('놈', 'Noun'), ('무덤', 'Noun'), ('졸다', 'Verb'), ('파고', 'Noun'), ('있다', 'Adjective'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('5', 'Number'), ('동', 'Noun'), ('밖', 'Noun')]
# [('끼', 'Noun'), ('이익', 'Noun'), ('!', 'Punctuation'), ('멈추다', 'Verb'), ('봉고', 'Noun'), ('에서', 'Josa'), ('박스', 'Noun'), ('등', 'Noun'), ('을', 'Josa'), ('들다', 'Verb'), ('내리다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Noun'), ('들', 'Suffix'), ('.', 'Punctuation'), ('제법', 'Noun'), ('크다', 'Verb'), ('집의', 'Noun'), ('대문', 'Noun'), ('을', 'Josa'), ('열다', 'Verb'), ('짐', 'Noun'), ('을', 'Josa'), ('들다', 'Verb'), ('조심', 'Noun'), ('스레', 'Noun'), ('안', 'Noun'), ('으로', 'Josa'), ('들어가다', 'Verb'), ('속', 'Noun'), ('에', 'Josa'), ('그', 'Noun'), ('뒤', 'Noun'), ('로', 'Josa'), ('멈추다', 'Verb'), ('서다', 'Verb'), ('차', 'Noun'), ('.', 'Punctuation'), ('열리다', 'Verb'), ('차문', 'Noun'), ('에서', 'Josa'), ('내리다', 'Verb'), ('누군가', 'Noun'), ('의', 'Josa'), ('발', 'Noun'), ('에서', 'Josa'), ('틸업하', 'Noun'), ('면', 'Josa'), ('바로', 'Noun'), (',', 'Punctuation'), ('우리', 'Noun'), ('의', 'Josa'), ('이', 'Determiner'), ('형사', 'Noun'), ('가', 'Josa'), ('도굴', 'Noun'), ('꾼', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('보다', 'Verb'), ('빠르다', 'Adjective'), ('다가가다', 'Verb'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('6', 'Number'), ('동', 'Noun'), ('안', 'Noun')]
# [('다시', 'Noun'), ('청진기', 'Noun'), ('를', 'Josa'), ('대고', 'Noun'), ('있다', 'Adjective'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('뒤', 'Noun'), ('로', 'Josa'), ('시계', 'Noun'), ('를', 'Josa'), ('보고', 'Noun'), ('있다', 'Adjective'), ('목', 'Noun'), ('장갑', 'Noun'), ('.', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':', 'Punctuation'), ('형님', 'Noun'), (',', 'Punctuation'), ('근데', 'Adverb'), ('안', 'Noun'), ('에', 'Josa'), ('금고', 'Noun'), ('하나', 'Noun'), ('더', 'Noun'), ('있다', 'Adjective'), ('어떻다', 'Adjective'), ('하다', 'Verb'), ('?', 'Punctuation'), ('하자', 'Noun'), ('휙', 'Noun'), ('보다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), (',', 'Punctuation'), ('목', 'Noun'), ('장갑', 'Noun'), ('의', 'Josa'), ('머리', 'Noun'), (',', 'Punctuation'), ('배', 'Noun'), ('따위', 'Noun'), ('를', 'Josa'), ('마구', 'Noun'), ('팬', 'Noun'), ('다', 'Josa'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('재수', 'Noun'), ('없다', 'Adjective'), ('소리', 'Noun'), ('하다', 'Verb'), (',', 'Punctuation'), ('임마', 'Noun'), (',', 'Punctuation'), ('안', 'Noun'), ('에', 'Josa'), ('금고', 'Noun'), ('또', 'Noun'), ('있다', 'Adjective'), ('너', 'Noun'), ('가', 'Josa'), ('죽다', 'Verb'), ('알', 'Noun'), ('아', 'Josa'), ('.', 'Punctuation')]
# [('하고는', 'Josa'), ('금고', 'Noun'), ('문', 'Noun'), ('을', 'Josa'), ('여', 'Noun'), ('는', 'Josa'), ('순간', 'Noun'), (',', 'Punctuation'), ('또', 'Noun'), ('다른', 'Noun'), ('금고', 'Noun'), ('가', 'Josa'), ('있다', 'Adjective'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':(', 'Punctuation'), ('목', 'Noun'), ('장갑', 'Noun'), ('을', 'Josa'), ('팰', 'Noun'), ('듯이', 'Noun'), ('가다', 'Verb'), (')', 'Punctuation'), ('이', 'Determiner'), ('리', 'Noun'), ('와', 'Josa'), (',', 'Punctuation'), ('새꺄', 'Noun'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('순간', 'Noun'), ('현관문', 'Noun'), ('이', 'Josa'), ('열리다', 'Verb'), ('소리', 'Noun'), ('가', 'Josa'), ('들리다', 'Verb'), ('표정', 'Noun'), ('이', 'Josa'), ('굳다', 'Adjective'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('과', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), (',', 'Punctuation'), ('문쪽', 'Noun'), ('을', 'Josa'), ('바라보다', 'Verb'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('7', 'Number'), ('동', 'Noun'), ('거실', 'Noun')]
# [('문', 'Noun'), ('을', 'Josa'), ('열다', 'Verb'), ('들어오다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), (',', 'Punctuation'), ('뒤', 'Noun'), ('돌아보다', 'Verb')]
# [('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), (':', 'Punctuation'), ('조심', 'Noun'), ('하다', 'Verb'), (',', 'Punctuation'), ('얼마', 'Noun'), ('짜다', 'Verb'), ('린', 'Noun'), ('줄', 'Noun'), ('알', 'Noun'), ('아', 'Josa'), ('?', 'Punctuation')]
# [('무겁다', 'Adjective'), ('듯', 'Noun'), ('박스', 'Noun'), ('등', 'Noun'), ('을', 'Josa'), ('들다', 'Verb'), ('들어오다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('2', 'Number'), (',', 'Punctuation'), ('3', 'Number'), (',', 'Punctuation'), ('4', 'Number'), ('의', 'Noun'), ('모습', 'Noun'), ('속', 'Noun'), ('에', 'Josa'), ('들리다', 'Verb')]
# [('소리', 'Noun'), (':', 'Punctuation'), ('(', 'Punctuation'), ('이형', 'Noun'), ('사의', 'Noun'), (')', 'Punctuation'), ('꼼작마', 'Noun'), ('!', 'Punctuation'), ('경찰', 'Noun'), ('이다', 'Josa'), ('!', 'Punctuation')]
# [('휙', 'Noun'), ('뒤', 'Noun'), ('돌아보다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Noun'), ('들', 'Suffix'), (',', 'Punctuation'), ('인상', 'Noun'), ('이', 'Josa'), ('확', 'Noun'), ('변하다', 'Adjective'), ('어느새다', 'Adjective'), ('안', 'Noun'), ('으로', 'Josa'), ('뛰어들다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), ('에게', 'Josa'), ('박스', 'Noun'), ('를', 'Josa'), ('던지다', 'Verb'), ('피', 'Noun'), ('하다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), ('뒤', 'Noun'), ('의', 'Josa'), ('벽', 'Noun'), ('에', 'Josa'), ('맞다', 'Verb'), ('깨지다', 'Verb'), ('도자기', 'Noun'), ('.', 'Punctuation'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('2', 'Number'), (',', 'Punctuation'), ('3', 'Number'), (',', 'Punctuation'), ('4', 'Number'), ('.', 'Punctuation'), ('이', 'Determiner'), ('형사', 'Noun'), ('를', 'Josa'), ('향', 'Noun'), ('하다', 'Verb'), ('칼', 'Noun'), (',', 'Punctuation'), ('호미', 'Noun'), (',', 'Punctuation'), ('삽', 'Noun'), ('따위', 'Noun'), ('를', 'Josa'), ('휘', 'Noun'), ('두르다', 'Verb'), ('공격', 'Noun'), ('해보다', 'Verb'), ('뒷걸음질', 'Noun'), ('치다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), (',', 'Punctuation'), ('뒷편', 'Noun'), ('의', 'Josa'), ('방', 'Noun'), ('으로', 'Josa'), ('도망가다', 'Verb'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('8', 'Number'), ('동', 'Noun'), ('방안', 'Noun')]
# [('문', 'Noun'), ('을', 'Josa'), ('열다', 'Verb'), ('들어오다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), (',', 'Punctuation'), ('창문', 'Noun'), ('을', 'Josa'), ('뛰어넘다', 'Verb'), ('도망가다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), (',', 'Punctuation'), ('목', 'Noun'), ('장갑', 'Noun'), ('을', 'Josa'), ('보다', 'Verb')]
# [('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), (':', 'Punctuation'), ('너희', 'Noun'), ('들', 'Suffix'), ('뭐', 'Noun'), ('야', 'Josa'), ('?', 'Punctuation')]
# [('하곤', 'Josa'), ('곧장', 'Noun'), ('흑', 'Adverb'), ('·', 'Foreign'), ('목', 'Noun'), ('이', 'Josa'), ('도망가다', 'Verb'), ('창문', 'Noun'), ('으로', 'Josa'), ('뛰어나가다', 'Verb'), ('곧이어', 'Adverb'), ('들어오다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), (',', 'Punctuation'), ('재빨리', 'Adverb'), ('창문', 'Noun'), ('으로', 'Josa'), ('뒤', 'Noun'), ('쫒다', 'Verb'), ('간다', 'Noun'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('거기', 'Noun'), ('서', 'Josa'), ('!', 'Punctuation')]
# [('씬', 'Noun'), ('9', 'Number'), ('어느', 'Adverb'), ('골목', 'Noun')]
# [('쫓다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), ('앞', 'Noun'), ('으로', 'Josa'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), ('이', 'Noun'), ('달리', 'Noun'), ('고', 'Josa'), (',', 'Punctuation'), ('그', 'Noun'), ('앞', 'Noun'), ('으로', 'Josa'), ('도망가다', 'Verb'), ('있다', 'Adjective'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('과', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), ('에게로', 'Josa'), ('쫓다', 'Verb'), ('카메라', 'Noun'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':(', 'Punctuation'), ('달려오다', 'Verb'), (')', 'Punctuation'), ('거기', 'Noun'), ('서', 'Josa'), ('!', 'Punctuation')]
# [('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), (':(', 'Punctuation'), ('도망가다', 'Verb'), (',', 'Punctuation'), ('앞', 'Noun'), ('을', 'Josa'), ('보고', 'Noun'), (')', 'Punctuation'), ('야', 'Exclamation'), (',', 'Punctuation'), ('이', 'Noun'), ('도둑', 'Noun'), ('놈', 'Noun'), ('새끼', 'Noun'), ('들', 'Suffix'), ('아', 'Josa'), ('!', 'Punctuation'), ('감히', 'Noun'), ('누구', 'Noun'), ('집', 'Noun'), ('을', 'Josa'), ('털다', 'Verb'), ('?', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':(', 'Punctuation'), ('뒤', 'Noun'), ('돌아보다', 'Verb'), (')', 'Punctuation'), ('훔치다', 'Verb'), ('못', 'VerbPrefix'), ('하다', 'Verb'), (',', 'Punctuation'), ('임마', 'Noun'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':(', 'Punctuation'), ('뒤', 'Noun'), ('돌아보다', 'Verb'), (')', 'Punctuation'), ('새꺄', 'Noun'), (',', 'Punctuation'), ('자꾸', 'Noun'), ('우리', 'Noun'), ('따라오다', 'Verb'), ('!', 'Punctuation'), ('따다', 'Verb'), ('데', 'Noun'), ('로', 'Josa'), ('가다', 'Verb'), ('!', 'Punctuation')]
# [('다시', 'Noun'), ('뒤따르다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('과', 'Josa'), ('이', 'Determiner'), ('형사', 'Noun'), ('를', 'Josa'), ('보이다', 'Verb'), ('카메라', 'Noun'), ('.', 'Punctuation')]
# [('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), (':(', 'Punctuation'), ('이', 'Determiner'), ('형사', 'Noun'), ('에게', 'Josa'), ('뒤', 'Noun'), ('돌아보다', 'Verb'), (')', 'Punctuation'), ('저', 'Noun'), ('새끼', 'Noun'), ('들', 'Suffix'), ('도', 'Josa'), ('도둑', 'Noun'), ('놓다', 'Verb'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('일단', 'Noun'), ('너', 'Noun'), ('부터', 'Josa'), ('잡다', 'Verb'), ('!', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (',', 'Punctuation'), ('길', 'Noun'), ('하다', 'Verb'), ('켜다', 'Verb'), ('놓이다', 'Verb'), ('휴지통', 'Noun'), ('을', 'Josa'), ('옆', 'Noun'), ('으로', 'Josa'), ('밀', 'Noun'), ('치고', 'Josa'), ('뛰다', 'Verb'), ('피', 'Noun'), ('하다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), ('이', 'Noun'), ('몸', 'Noun'), ('을', 'Josa'), ('틀다', 'Verb'), ('사이', 'Noun'), ('뒤', 'Noun'), ('에서', 'Josa'), ('점프', 'Noun'), ('해오다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), (',', 'Punctuation'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), ('을', 'Josa'), ('덥다', 'Adjective'), ('뒹군', 'Noun'), ('다', 'Josa'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), ('에게', 'Josa'), ('잡히다', 'Verb'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), ('을', 'Josa'), ('보다', 'Verb'), ('씨익', 'Noun'), ('미소', 'Noun'), ('지은', 'Noun'), ('채', 'Noun'), ('도망가다', 'Verb'), ('흑', 'Adverb'), ('·', 'Foreign'), ('목', 'Noun'), ('장갑', 'Noun'), ('옆', 'Noun'), ('으로', 'Josa'), ('스치다', 'Verb'), ('지나가다', 'Verb'), ('차갑다', 'Adjective'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), ('에게', 'Josa'), ('수갑', 'Noun'), ('을', 'Josa'), ('채우다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), ('앞', 'Noun'), ('에서', 'Josa'), ('끼', 'Noun'), ('이익', 'Noun'), ('!', 'Punctuation'), ('멈추다', 'Verb'), ('빵빵', 'Noun'), ('클락', 'Noun'), ('션', 'Noun'), ('을', 'Josa'), ('울리다', 'Verb'), ('대다', 'Verb'), ('차안', 'Noun'), ('의', 'Josa'), ('여자', 'Noun'), ('운전', 'Noun'), ('수', 'Noun'), ('.', 'Punctuation'), ('짜증', 'Noun'), ('스레', 'Noun'), ('40', 'Number'), ('대의', 'Noun'), ('여자', 'Noun'), ('울다', 'Verb'), ('바라보다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), ('와', 'Josa'), ('도굴', 'Noun'), ('꾼', 'Suffix'), ('1', 'Number'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('10', 'Number'), ('경찰서', 'Noun'), ('사무실', 'Noun')]
# [('수갑', 'Noun'), ('을', 'Josa'), ('찬', 'Noun'), ('도굴', 'Noun'), ('꾼', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('툭툭', 'Noun'), ('치', 'Noun'), ('며', 'Josa'), ('들어오다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), (',', 'Punctuation'), ('다른', 'Noun'), ('경찰', 'Noun'), ('에게', 'Josa'), ('도굴', 'Noun'), ('꾼', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('유치장', 'Noun'), ('쪽', 'Noun'), ('으로', 'Josa'), ('이다', 'Verb')]
# [('형사', 'Noun'), ('1', 'Number'), (':', 'Punctuation'), ('또', 'Noun'), ('한껀했', 'Noun'), ('나', 'Josa'), ('?', 'Punctuation'), ('하루', 'Noun'), ('도', 'Josa'), ('그냥', 'Noun'), ('넘어가다', 'Verb'), ('날', 'Noun'), ('이', 'Josa'), ('없다', 'Adjective'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('예', 'Noun'), ('쓰다', 'Verb'), ('.(', 'Punctuation'), ('빈', 'Noun'), ('자리', 'Noun'), ('를', 'Josa'), ('보다', 'Verb'), (')', 'Punctuation'), ('아직', 'Noun'), ('안', 'VerbPrefix'), ('오다', 'Verb'), ('?', 'Punctuation'), ('첫날', 'Noun'), ('부터', 'Josa'), ('자각', 'Noun'), ('이야', 'Josa'), ('?!', 'Punctuation')]
# [('형사', 'Noun'), ('1', 'Number'), (':', 'Punctuation'), ('아', 'Exclamation'), ('?', 'Punctuation'), ('신참', 'Noun'), ('?', 'Punctuation'), ('차갑다', 'Adjective'), ('막히다', 'Verb'), ('보지', 'Noun'), ('?', 'Punctuation'), ('차다', 'Verb'), (',', 'Punctuation'), ('자네', 'Noun'), ('파트너', 'Noun'), ('이야기', 'Noun'), ('들다', 'Verb'), ('?', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('아뇨', 'Noun'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('때', 'Noun'), ('엉망', 'Noun'), ('인', 'Josa'), ('몰골', 'Noun'), ('로', 'Josa'), ('수갑', 'Noun'), ('을', 'Josa'), ('찬', 'Noun'), ('채', 'Noun'), ('뛰어들다', 'Verb'), ('꼴통', 'Noun'), (',', 'Punctuation'), ('정신', 'Noun'), ('이', 'Josa'), ('없다', 'Adjective'), ('이', 'Determiner'), ('곳', 'Noun'), ('저', 'Determiner'), ('곳', 'Noun'), ('을', 'Josa'), ('살피', 'Noun'), ('며', 'Josa')]
# [('꼴통', 'Noun'), (':', 'Punctuation'), ('악', 'Noun'), ('!', 'Punctuation'), ('사람', 'Noun'), ('살리다', 'Verb'), ('!', 'Punctuation')]
# [('경찰', 'Noun'), ('1', 'Number'), (':(', 'Punctuation'), ('꼴통', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), (')', 'Punctuation'), ('저', 'Noun'), ('자식', 'Noun'), ('은', 'Josa'), ('볼때', 'Noun'), ('마다', 'Josa'), ('인상', 'Noun'), ('이', 'Josa'), ('더러워지다', 'Verb'), ('?', 'Punctuation')]
# [('꼴통', 'Noun'), (':(', 'Punctuation'), ('다가오다', 'Verb'), ('선', 'Noun'), (')', 'Punctuation'), ('이', 'Determiner'), ('형사', 'Noun'), ('님', 'Suffix'), ('!', 'Punctuation'), ('제발', 'Noun'), (',', 'Punctuation'), ('살리다', 'Verb'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('가석방', 'Noun'), ('되다', 'Verb'), ('몇', 'Noun'), ('일', 'Noun'), ('돼다', 'Verb'), ('또', 'Noun'), ('들어오다', 'Verb'), ('?!', 'Punctuation')]
# [('꼴통', 'Noun'), (':(', 'Punctuation'), ('울', 'Noun'), ('먹이', 'Noun'), ('며', 'Josa'), (')', 'Punctuation'), ('제발', 'Noun'), ('살리다', 'Verb'), ('줄다', 'Verb'), (',', 'Punctuation'), ('완전하다', 'Adjective'), ('마녀', 'Noun'), ('예요', 'Josa'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('순간', 'Noun'), ('뒤', 'Noun'), ('에서', 'Josa'), ('다가오다', 'Verb'), ('꼴통', 'Noun'), ('의', 'Josa'), ('뒷덜미', 'Noun'), ('를', 'Josa'), ('잡다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('이', 'Determiner'), ('리', 'Noun'), ('와', 'Josa'), ('!', 'Punctuation')]
# [('꼴통', 'Noun'), (',', 'Punctuation'), ('울', 'Noun'), ('먹이', 'Noun'), ('며', 'Josa'), ('최', 'Noun'), ('형사', 'Noun'), ('에게', 'Josa'), ('후다닥', 'Noun'), ('뛰어가다', 'Verb')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('누구', 'Noun'), ('입', 'Noun'), ('니까', 'Josa'), ('?', 'Punctuation')]
# [('형사', 'Noun'), ('1', 'Number'), (':', 'Punctuation'), ('몰르다', 'Verb'), ('?', 'Punctuation'), ('자네', 'Noun'), ('의', 'Josa'), ('새롭다', 'Adjective'), ('파트너', 'Noun'), ('잖다', 'Verb'), ('?', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('예', 'Noun'), ('?!', 'Punctuation')]
# [('다른', 'Noun'), ('경찰', 'Noun'), ('에게', 'Josa'), ('꼴통', 'Noun'), ('을', 'Josa'), ('넘기다', 'Verb'), ('최', 'Noun'), ('형', 'Suffix'), ('사의', 'Noun'), ('늘씬', 'Adverb'), ('한', 'Determiner'), ('다리', 'Noun'), ('에서부터', 'Josa'), ('얼굴', 'Noun'), ('까지', 'Josa'), ('쭈욱', 'Noun'), ('훑어', 'Noun'), ('보고', 'Noun'), ('는', 'Josa'), ('불만', 'Noun'), ('이', 'Josa'), ('가득하다', 'Adjective'), ('표정', 'Noun'), ('으로', 'Josa'), ('바뀌다', 'Verb'), ('속', 'Noun'), ('에', 'Josa')]
# [('형사', 'Noun'), ('1', 'Number'), (':(', 'Punctuation'), ('최', 'Noun'), ('형사', 'Noun'), ('를', 'Josa'), ('보다', 'Verb'), (')', 'Punctuation'), ('자다', 'Verb'), ('빠지다', 'Verb'), ('?', 'Punctuation'), ('몇', 'Noun'), ('일', 'Noun'), ('버티다', 'Verb'), ('?', 'Punctuation')]
# [('형사', 'Noun'), ('2', 'Number'), (':(', 'Punctuation'), ('이', 'Determiner'), ('형사', 'Noun'), ('를', 'Josa'), ('보다', 'Verb'), ('슬쩍', 'Adverb'), ('만원', 'Noun'), ('을', 'Josa'), ('꺼내다', 'Verb'), (')', 'Punctuation'), ('일주일', 'Noun'), ('.', 'Punctuation'), ('어', 'Noun'), ('?', 'Punctuation'), ('이', 'Determiner'), ('형사', 'Noun'), (',', 'Punctuation'), ('어디가', 'Noun'), ('?', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':(', 'Punctuation'), ('일어나다', 'Verb'), ('가다', 'Verb'), (')', 'Punctuation'), ('과장', 'Noun'), ('님', 'Suffix'), ('계시다', 'Verb'), ('?', 'Punctuation')]
# [('형사', 'Noun'), ('2', 'Number'), (':', 'Punctuation'), ('응', 'Noun'), ('.(', 'Punctuation'), ('만원', 'Noun'), ('을', 'Josa'), ('꺼내다', 'Verb'), (')', 'Punctuation'), ('내일', 'Noun'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('11', 'Number'), ('동', 'Noun'), ('과장', 'Noun'), ('실', 'Noun')]
# [('화면', 'Noun'), ('가득', 'Noun'), ('책상', 'Noun'), ('위로', 'Noun'), ('내미다', 'Verb'), ('희다', 'Adjective'), ('봉투', 'Noun'), ('를', 'Josa'), ('집다', 'Verb'), ('들다', 'Verb'), ('과장', 'Noun'), (',', 'Punctuation'), ('맞다', 'Verb'), ('편', 'Noun'), ('에', 'Josa'), ('서다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), ('를', 'Josa'), ('보다', 'Verb')]
# [('과장', 'Noun'), (':', 'Punctuation'), ('이', 'Noun'), ('게', 'Josa'), ('뭐', 'Noun'), ('야', 'Josa'), ('?', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('파트너', 'Noun'), ('바꾸다', 'Verb'), ('줄다', 'Verb'), (',', 'Punctuation'), ('아니다', 'Adjective'), ('사표', 'Noun'), ('내다', 'Verb'), ('.', 'Punctuation')]
# [('과장', 'Noun'), (':', 'Punctuation'), ('뭐어', 'Noun'), ('～', 'Foreign'), ('?!', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('요즘', 'Noun'), ('강력', 'Noun'), ('사건', 'Noun'), ('이', 'Josa'), ('얼마나', 'Noun'), ('많이', 'Adverb'), ('발생', 'Noun'), ('하다', 'Verb'), ('여자', 'Noun'), ('를', 'Josa'), ('붙이다', 'Verb'), ('어떡하다', 'Adjective'), ('?', 'Punctuation')]
# [('과장', 'Noun'), (':', 'Punctuation'), ('임마', 'Noun'), ('.', 'Punctuation'), ('그래도', 'Adverb'), ('이번', 'Noun'), ('에', 'Josa'), ('경찰', 'Noun'), ('학교', 'Noun'), ('수석', 'Noun'), ('졸업', 'Noun'), ('하다', 'Verb'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('요즘', 'Noun'), ('엔', 'Josa'), ('수석', 'Noun'), ('을', 'Josa'), ('아', 'Exclamation'), ('무', 'Noun'), ('나', 'Josa'), ('하나', 'Noun'), ('보다', 'Verb'), ('?', 'Punctuation')]
# [('과장', 'Noun'), (':', 'Punctuation'), ('여자', 'Noun'), ('라고', 'Josa'), ('울다', 'Verb'), ('보지', 'Noun'), ('말고', 'Josa'), ('앞', 'Noun'), ('으로', 'Josa'), ('자다', 'Verb'), ('해보다', 'Verb'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('안', 'Noun'), ('되다', 'Verb'), ('.', 'Punctuation'), ('수사', 'Noun'), ('하다', 'Verb'), ('갑자기', 'Noun'), ('사랑', 'Noun'), ('때문', 'Noun'), ('에', 'Josa'), ('질질', 'Noun'), ('짜다', 'Verb'), (',', 'Punctuation'), ('중요하다', 'Adjective'), ('놈', 'Noun'), ('을', 'Josa'), ('체포', 'Noun'), ('하다', 'Verb'), ('순간', 'Noun'), ('에', 'Josa'), ('생리', 'Noun'), ('라도', 'Josa'), ('하다', 'Verb'), ('어떡하다', 'Adjective'), ('?', 'Punctuation'), ('당장', 'Noun'), ('바꾸다', 'Verb'), ('줄다', 'Verb'), ('.', 'Punctuation')]
# [('과장', 'Noun'), (':', 'Punctuation'), ('이', 'Noun'), ('자식', 'Noun'), ('이', 'Josa'), ('싸움', 'Noun'), ('잘하다', 'Verb'), ('봐', 'Noun'), ('주다', 'Verb'), ('…', 'Foreign'), ('.', 'Punctuation'), ('알다', 'Verb'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('예', 'Noun'), ('?', 'Punctuation'), ('정말', 'Noun'), ('그만', 'Adverb'), ('두다', 'Verb'), ('요', 'Noun'), ('.', 'Punctuation')]
# [('과장', 'Noun'), (':', 'Punctuation'), ('수리', 'Noun'), ('하다', 'Verb'), ('임마', 'Noun'), (',', 'Punctuation'), ('짜다', 'Verb'), ('식이', 'Noun'), ('건방지다', 'Adjective'), ('인사', 'Noun'), ('권', 'Suffix'), ('까지', 'Josa'), ('참견', 'Noun'), ('하다', 'Verb'), ('?', 'Punctuation'), ('당장', 'Noun'), ('나가다', 'Verb'), (',', 'Punctuation'), ('임마', 'Noun'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('과장', 'Noun'), ('님', 'Suffix'), ('!', 'Punctuation')]
# [('과장', 'Noun'), (':(', 'Punctuation'), ('밀다', 'Verb'), (')', 'Punctuation'), ('관', 'Noun'), ('두다', 'Verb'), ('관', 'Noun'), ('두다', 'Verb'), ('!', 'Punctuation'), ('임마', 'Noun'), (',', 'Punctuation'), ('나가다', 'Verb'), ('짐', 'Noun'), ('이나', 'Josa'), ('싸다', 'Verb'), ('!', 'Punctuation'), ('어서', 'Noun'), ('!', 'Punctuation')]
# [('씬', 'Noun'), ('12', 'Number'), ('달리다', 'Verb'), ('차', 'Noun'), ('안', 'Noun')]
# [('운전', 'Noun'), ('을', 'Josa'), ('하다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), (',', 'Punctuation'), ('그', 'Noun'), ('옆', 'Noun'), ('에', 'Josa'), ('창밖', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':(', 'Punctuation'), ('화난', 'Noun'), ('듯', 'Noun'), (')', 'Punctuation'), ('경찰', 'Noun'), ('학교', 'Noun'), ('수석', 'Noun'), ('졸업', 'Noun'), (',', 'Punctuation'), ('정말', 'Noun'), ('이야', 'Josa'), ('?!', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('예', 'Noun'), ('.', 'Punctuation'), ('선배', 'Noun'), ('님', 'Suffix'), ('이', 'Josa'), ('세운', 'Noun'), ('기록', 'Noun'), ('도', 'Josa'), ('깨다', 'Verb'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('그렇다', 'Adjective'), ('?(', 'Punctuation'), ('다시', 'Noun'), ('한번', 'Noun'), ('보다', 'Verb'), (')', 'Punctuation'), ('대책', 'Noun'), ('없이', 'Adverb'), ('인심', 'Noun'), ('이', 'Josa'), ('좋아지다', 'Adjective'), ('.', 'Punctuation'), ('근데', 'Adverb'), ('경찰', 'Noun'), ('학교', 'Noun'), ('엔', 'Josa'), ('왜', 'Noun'), ('가다', 'Verb'), ('?', 'Punctuation'), ('조용하다', 'Adjective'), ('시집', 'Noun'), ('이나', 'Josa'), ('가지', 'Noun'), ('!', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':(', 'Punctuation'), ('휙', 'Noun'), ('보다', 'Verb'), (')', 'Punctuation'), ('선배', 'Noun'), ('님', 'Suffix'), (',', 'Punctuation'), ('제', 'Noun'), ('가', 'Josa'), ('온', 'Noun'), ('게', 'Noun'), ('불만', 'Noun'), ('입', 'Noun'), ('니까', 'Josa'), ('?!', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':(', 'Punctuation'), ('힐끗', 'Adverb'), ('보다', 'Verb'), (')', 'Punctuation'), ('자넬', 'Noun'), ('위', 'Noun'), ('하다', 'Verb'), ('하다', 'Verb'), ('소리', 'Noun'), ('야', 'Josa'), ('.', 'Punctuation'), ('이다', 'Verb'), ('자고로', 'Noun'), ('남편', 'Noun'), ('사랑', 'Noun'), ('받다', 'Verb'), ('집안', 'Noun'), ('일이', 'Noun'), ('나', 'Josa'), ('하다', 'Verb'), ('게', 'Noun'), ('최고', 'Noun'), ('야', 'Josa'), ('.', 'Punctuation'), ('안', 'VerbPrefix'), ('그렇다', 'Adjective'), ('?', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':(', 'Punctuation'), ('놓다', 'Verb'), ('보다', 'Verb'), (')', 'Punctuation'), ('항상', 'Noun'), ('그렇게', 'Adverb'), ('여자', 'Noun'), ('를', 'Josa'), ('무시', 'Noun'), ('하다', 'Verb'), ('?', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('경찰', 'Noun'), ('일', 'Noun'), ('이란', 'Noun'), ('게', 'Josa'), ('사기꾼', 'Noun'), (',', 'Punctuation'), ('강간범', 'Noun'), (',', 'Punctuation'), ('도둑', 'Noun'), ('놈', 'Noun'), (',', 'Punctuation'), ('깡패', 'Noun'), ('같다', 'Adjective'), ('놈', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('더럽다', 'Adjective'), ('꼴', 'Noun'), ('만', 'Josa'), ('보다', 'Verb'), ('.', 'Punctuation'), ('여차하면', 'Noun'), ('놈', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('휘', 'Noun'), ('두르다', 'Verb'), ('쇠', 'Noun'), ('파이프', 'Noun'), ('에', 'Josa'), ('뼈', 'Noun'), ('가', 'Josa'), ('부러지다', 'Verb'), (',', 'Punctuation'), ('칼', 'Noun'), ('에', 'Josa'), ('찔리다', 'Verb'), (',', 'Punctuation'), ('무식', 'Noun'), ('한', 'Josa'), ('놈', 'Noun'), ('은', 'Josa'), ('도끼', 'Noun'), ('까지', 'Josa'), ('들다', 'Verb'), ('설치다', 'Adjective'), ('대서', 'Noun'), ('병신', 'Noun'), ('되다', 'Verb'), ('쉬다', 'Verb'), ('상이', 'Noun'), ('지', 'Josa'), ('.', 'Punctuation'), ('사랑', 'Noun'), ('이고', 'Josa'), ('결혼', 'Noun'), ('같다', 'Adjective'), ('건', 'Noun'), ('꿈', 'Noun'), ('도', 'Josa'), ('못', 'VerbPrefix'), ('꾸다', 'Verb'), ('.', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('알', 'Noun'), ('고', 'Josa'), ('있다', 'Adjective'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('그렇다', 'Adjective'), ('?', 'Punctuation'), ('그렇다', 'Adjective'), (',', 'Punctuation'), ('당장', 'Noun'), ('그만두다', 'Verb'), ('.', 'Punctuation'), ('뭐', 'Noun'), ('하다', 'Verb'), ('구', 'Noun'), ('해', 'Noun'), ('?', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('근데', 'Adverb'), ('어쩌다', 'Verb'), ('수', 'Noun'), ('없다', 'Adjective'), ('.', 'Punctuation'), ('팔자', 'Noun'), ('예요', 'Josa'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('뭐', 'Noun'), ('?', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('타고나다', 'Verb'), ('운명', 'Noun'), ('이라', 'Josa'), ('고요', 'Noun'), ('.', 'Punctuation'), ('태몽', 'Noun'), ('에서부터', 'Josa'), ('용다', 'Verb'), ('점', 'Noun'), ('쟁이', 'Suffix'), ('들다', 'Verb'), ('모두', 'Noun'), ('제', 'Noun'), ('가', 'Josa'), ('사회', 'Noun'), ('의', 'Josa'), ('악', 'Noun'), ('을', 'Josa'), ('처단', 'Noun'), ('하다', 'Verb'), ('강직', 'Noun'), ('한', 'Josa'), ('전사', 'Noun'), ('같다', 'Adjective'), ('삶', 'Noun'), ('을', 'Josa'), ('살꺼랬어', 'Noun'), ('요', 'Josa'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('태몽', 'Noun'), ('?', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('하다', 'Verb'), ('손', 'Noun'), ('엔', 'Josa'), ('불과', 'Noun'), ('다른', 'Noun'), ('손', 'Noun'), ('엔', 'Josa'), ('칼', 'Noun'), ('을', 'Josa'), ('쥐', 'Noun'), ('고', 'Josa'), ('있다', 'Adjective'), ('대요', 'Noun'), ('.', 'Punctuation')]
# ...
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('야', 'Exclamation'), (',', 'Punctuation'), ('이래서', 'Josa'), ('언제', 'Noun'), ('돈', 'Noun'), ('모으다', 'Verb'), ('L', 'Alpha'), ('.', 'Punctuation'), ('A', 'Alpha'), ('에', 'Josa'), ('찬호', 'Noun'), ('야구', 'Noun'), ('하다', 'Verb'), ('보다', 'Verb'), ('가다', 'Verb'), (',', 'Punctuation'), ('임마', 'Noun'), ('?', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':', 'Punctuation'), ('티끌', 'Noun'), ('모으다', 'Verb'), ('태산', 'Noun'), ('이라고', 'Josa'), ('하다', 'Verb'), ('.', 'Punctuation'), ('형님', 'Noun'), ('말', 'Noun'), ('대로', 'Josa'), ('크다', 'Verb'), ('노려', 'Noun'), ('서', 'Josa'), ('하다', 'Verb'), ('번', 'Noun'), ('이라도', 'Josa'), ('성공', 'Noun'), ('하다', 'Verb'), ('적', 'Noun'), ('없다', 'Adjective'), ('?', 'Punctuation'), ('망', 'Noun'), ('이나', 'Josa'), ('자다', 'Verb'), ('보다', 'Verb'), ('.', 'Punctuation'), ('찬', 'Noun'), ('호가', 'Noun'), ('안', 'Noun'), ('되다', 'Verb'), ('선동렬', 'Noun'), ('이라도', 'Josa'), ('보다', 'Verb'), ('가면', 'Noun'), ('되다', 'Verb'), ('.', 'Punctuation'), ('안', 'VerbPrefix'), ('그렇다', 'Adjective'), ('?', 'Punctuation')]
# [('하다', 'Verb'), ('옆', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), ('운전', 'Noun'), ('석', 'Noun'), ('에서', 'Josa'), ('내다', 'Verb'), ('망', 'Noun'), ('을', 'Josa'), ('보뎐', 'Noun'), ('빨갛다', 'Adjective'), ('장갑', 'Noun'), ('이', 'Josa'), ('끄덕', 'Noun'), ('이며', 'Josa')]
# [('빨갛다', 'Adjective'), ('장갑', 'Noun'), (':', 'Punctuation'), ('네', 'Noun'), (',', 'Punctuation'), ('맞다', 'Verb'), ('.', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':', 'Punctuation'), ('짜다', 'Verb'), ('식', 'Noun'), (',', 'Punctuation'), ('야구', 'Noun'), ('가', 'Josa'), ('어떻다', 'Adjective'), ('하다', 'Verb'), ('건지다', 'Verb'), ('모르다', 'Verb'), ('…', 'Foreign'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('딸각', 'Noun'), ('!', 'Punctuation'), ('전화', 'Noun'), ('박스', 'Noun'), ('함', 'Noun'), ('을', 'Josa'), ('여', 'Noun'), ('는', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), ('.', 'Punctuation'), ('안', 'Noun'), ('에', 'Josa'), ('들다', 'Verb'), ('무수', 'Noun'), ('한', 'Josa'), ('동전', 'Noun'), ('을', 'Josa'), ('손', 'Noun'), ('에', 'Josa'), ('들다', 'Verb'), ('가방', 'Noun'), ('에', 'Josa'), ('퍼담는', 'Noun'), ('다', 'Josa'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('때', 'Noun'), ('약간', 'Noun'), ('떨어지다', 'Verb'), ('곳', 'Noun'), ('에서', 'Josa'), ('모습', 'Noun'), ('을', 'Josa'), ('드러내다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('와', 'Josa'), ('구', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':(', 'Punctuation'), ('흑', 'Adverb'), (',', 'Punctuation'), ('목', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), (')', 'Punctuation'), ('저', 'Determiner'), ('놈', 'Noun'), ('들', 'Suffix'), ('이다', 'Josa'), ('.', 'Punctuation'), ('우리', 'Noun'), ('관내', 'Noun'), ('에서', 'Josa'), ('제일', 'Noun'), ('미꾸라지', 'Noun'), ('같다', 'Adjective'), ('놈', 'Noun'), ('들', 'Suffix'), ('이지', 'Noun'), ('.', 'Punctuation'), ('잡', 'Noun'), ('을', 'Josa'), ('수', 'Noun'), ('있다', 'Adjective'), ('?', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('예', 'Noun'), ('.', 'Punctuation'), ('걱정', 'Noun'), ('말다', 'Verb'), ('.', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('놓치다', 'Verb'), ('일', 'Noun'), ('하다', 'Verb'), ('생각', 'Noun'), ('하다', 'Verb'), ('!', 'Punctuation')]
# [('돈', 'Noun'), ('을', 'Josa'), ('퍼담', 'Noun'), ('는', 'Josa'), ('흑', 'Adverb'), (',', 'Punctuation'), ('목', 'Noun'), ('장갑', 'Noun'), ('에게로', 'Josa'), ('다가가다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation'), ('돈', 'Noun'), ('을', 'Josa'), ('담다', 'Verb'), ('가방', 'Noun'), ('이', 'Josa'), ('무겁다', 'Adjective'), ('힘겹다', 'Adjective'), ('돌아서다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('과', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), ('이', 'Josa'), ('돌아서다', 'Verb'), ('순간', 'Noun')]
# [('구', 'Noun'), ('형사', 'Noun'), (':(', 'Punctuation'), ('흑', 'Adverb'), (',', 'Punctuation'), ('목', 'Noun'), ('의', 'Josa'), ('앞', 'Noun'), ('에서', 'Josa'), ('총', 'Noun'), ('을', 'Josa'), ('꺼내다', 'Verb'), (')', 'Punctuation'), ('꼼짝', 'Noun'), ('마', 'Noun'), ('!', 'Punctuation'), ('경찰', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':(', 'Punctuation'), ('가방', 'Noun'), ('을', 'Josa'), ('구', 'Noun'), ('형사', 'Noun'), ('에게', 'Josa'), ('내다', 'Verb'), (')', 'Punctuation'), ('튀어', 'Noun'), ('!', 'Punctuation')]
# [('움찔', 'Noun'), ('하다', 'Verb'), ('구형', 'Noun'), ('사의', 'Noun'), ('머리', 'Noun'), ('에', 'Josa'), ('맞다', 'Verb'), ('쏟아지다', 'Verb'), ('내리다', 'Verb'), ('동전', 'Noun'), ('들', 'Suffix'), ('.', 'Punctuation'), ('도망가다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('과', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('거기', 'Noun'), ('서', 'Josa'), ('!', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('뭐', 'Noun'), ('해', 'Josa'), ('?', 'Punctuation'), ('저', 'Noun'), ('쪽', 'Noun'), ('이야', 'Josa'), ('!', 'Punctuation')]
# [('흑', 'Adverb'), ('-', 'Punctuation'), ('목', 'Noun'), ('장갑', 'Noun'), ('뒤', 'Noun'), ('로', 'Josa'), ('구형', 'Noun'), ('사오다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('가', 'Josa'), ('달다', 'Verb'), ('나오다', 'Verb'), ('.', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('놓치다', 'Verb'), ('각오', 'Noun'), ('해', 'Josa'), ('!', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('거기', 'Noun'), ('서', 'Josa'), ('!', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('잡다', 'Verb'), ('봐', 'Noun'), ('라', 'Josa'), (',', 'Punctuation'), ('잡히다', 'Verb'), ('!', 'Punctuation')]
# [('골목', 'Noun'), ('으로', 'Josa'), ('꺽어', 'Noun'), ('지다', 'Verb'), ('들어가다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('과', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), ('을', 'Josa'), ('보다', 'Verb'), ('양쪽', 'Noun'), ('으로', 'Josa'), ('나뉘다', 'Verb'), ('달리다', 'Verb'), ('구형', 'Noun'), ('사오다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('146', 'Number'), ('다른', 'Noun'), ('골목', 'Noun')]
# [('달리다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('앞', 'Noun'), ('으로', 'Josa'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('과', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), ('이', 'Josa'), ('도망치다', 'Verb'), ('.', 'Punctuation'), ('다른', 'Noun'), ('골목', 'Noun'), ('으로', 'Josa'), ('꺽어', 'Noun'), ('지다', 'Verb'), ('들어가다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('과', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('147', 'Number'), ('또', 'Noun'), ('다른', 'Noun'), ('골목', 'Noun')]
# [('골목', 'Noun'), ('으로', 'Josa'), ('꺽어', 'Noun'), ('지다', 'Verb'), ('들어오다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), (',', 'Punctuation'), ('보다', 'Verb'), ('꽉', 'Noun'), ('막히다', 'Verb'), ('골목', 'Noun'), ('에', 'Josa'), ('아', 'Exclamation'), ('무도', 'Noun'), ('보이지', 'Noun'), ('않다', 'Verb'), ('.', 'Punctuation'), ('어', 'Noun'), ('?', 'Punctuation'), ('하다', 'Verb'), ('주변', 'Noun'), ('을', 'Josa'), ('살피다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('등', 'Noun'), ('뒤', 'Noun'), ('에서', 'Josa'), ('나타나다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), (',', 'Punctuation'), ('작다', 'Adjective'), ('만능', 'Noun'), ('키로', 'Suffix'), ('구형', 'Noun'), ('사의', 'Noun'), ('등', 'Noun'), ('을', 'Josa'), ('꾸욱', 'Noun'), ('누르다', 'Verb')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('손', 'Noun'), ('들다', 'Verb'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('히', 'Adverb'), ('익', 'Noun'), ('!', 'Punctuation'), ('겁', 'Noun'), ('에', 'Josa'), ('질리', 'Noun'), ('는', 'Josa'), ('구', 'Noun'), ('형사', 'Noun'), (',', 'Punctuation'), ('총', 'Noun'), ('을', 'Josa'), ('들다', 'Verb'), ('손', 'Noun'), ('을', 'Josa'), ('들다', 'Verb'), ('옆', 'Noun'), ('에서', 'Josa'), ('구형', 'Noun'), ('사의', 'Noun'), ('뒷통수', 'Noun'), ('를', 'Josa'), ('때리다', 'Verb'), ('총', 'Noun'), ('을', 'Josa'), ('빼앗다', 'Verb'), ('목', 'Noun'), ('장갑', 'Noun'), ('.', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':', 'Punctuation'), ('새꺄', 'Noun'), (',', 'Punctuation'), ('놓다', 'Verb'), ('!', 'Punctuation'), ('경찰', 'Noun'), ('증', 'Noun'), ('은', 'Josa'), ('어딨다', 'Verb'), ('?', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('안', 'Noun'), ('되다', 'Verb'), ('…', 'Foreign'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('죽다', 'Verb'), ('싶다', 'Verb'), ('?', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (',', 'Punctuation'), ('고개', 'Noun'), ('를', 'Josa'), ('흔들다', 'Verb'), ('주머니', 'Noun'), ('에서', 'Josa'), ('경찰', 'Noun'), ('증', 'Noun'), ('을', 'Josa'), ('꺼내다', 'Verb'), ('웃옷', 'Noun'), ('을', 'Josa'), ('확', 'Noun'), ('벗기다', 'Verb'), ('버리다', 'Verb'), ('목', 'Noun'), ('장갑', 'Noun'), ('.', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('옷', 'Noun'), ('벗다', 'Verb'), ('!', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('왜', 'Noun'), ('요', 'Josa'), ('?', 'Punctuation')]
# [('흑', 'Adverb'), ('장갑', 'Noun'), (':', 'Punctuation'), ('그', 'Determiner'), ('래야', 'Noun'), ('못', 'Noun'), ('쫓다', 'Verb'), (',', 'Punctuation'), ('임마', 'Noun'), ('.', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('안', 'Noun'), ('쫓다', 'Verb'), ('갈다', 'Verb'), ('.', 'Punctuation'), ('진짜', 'Noun'), ('예요', 'Josa'), ('.', 'Punctuation')]
# [('목', 'Noun'), ('장갑', 'Noun'), (':(', 'Punctuation'), ('총구', 'Noun'), ('를', 'Josa'), ('들이다', 'Verb'), ('대다', 'Verb'), (')', 'Punctuation'), ('죽다', 'Verb'), ('싶다', 'Verb'), ('?', 'Punctuation')]
# [('하다', 'Verb'), ('바지', 'Noun'), ('를', 'Josa'), ('스윽', 'Noun'), ('벗다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('뒤', 'Noun'), ('로', 'Josa'), ('슬금슬금', 'Noun'), ('도망가다', 'Verb'), ('흑', 'Adverb'), ('장갑', 'Noun'), ('과', 'Josa'), ('목', 'Noun'), ('장갑', 'Noun'), (',', 'Punctuation'), ('어느', 'Adverb'), ('담', 'Noun'), ('을', 'Josa'), ('훌쩍', 'Noun'), ('뛰어넘다', 'Verb'), ('도망가다', 'Verb'), ('.', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('근데', 'Adverb'), ('우리', 'Noun'), ('오늘', 'Noun'), ('일', 'Noun'), ('은', 'Josa'), ('비밀', 'Noun'), ('로', 'Josa'), ('해주다', 'Verb'), ('.', 'Punctuation'), ('오늘', 'Noun'), ('발령', 'Noun'), ('받다', 'Verb'), ('파트너', 'Noun'), ('가다', 'Verb'), ('알', 'Noun'), ('면', 'Josa'), ('가만', 'Adverb'), ('알다', 'Verb'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('그', 'Noun'), ('앞', 'Noun'), ('으로', 'Josa'), ('달려오다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('를', 'Josa'), ('보다', 'Verb'), ('움찔', 'Noun'), ('하다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('뭐', 'Noun'), ('하다', 'Verb'), ('?', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':(', 'Punctuation'), ('뒤', 'Noun'), ('로', 'Josa'), ('손짓', 'Noun'), ('하다', 'Verb'), (')', 'Punctuation'), ('놈', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('갑자기', 'Noun'), ('뒤', 'Noun'), ('에서', 'Josa'), ('기습', 'Noun'), ('해서', 'Josa'), ('죽이다', 'Verb'), ('위협', 'Noun'), ('하다', 'Verb'), ('…', 'Foreign'), ('.(', 'Punctuation'), ('하다', 'Verb'), ('간', 'Noun'), ('뒤', 'Noun'), ('돌아보다', 'Verb'), ('아', 'Exclamation'), ('무도', 'Noun'), ('없다', 'Adjective'), (')', 'Punctuation'), ('어', 'Noun'), ('?', 'Punctuation'), ('어디', 'Noun'), ('가다', 'Verb'), ('?', 'Punctuation')]
# [('하다', 'Verb'), ('다시', 'Noun'), ('고개', 'Noun'), ('를', 'Josa'), ('돌리다', 'Verb'), ('순간', 'Noun'), ('구형', 'Noun'), ('사의', 'Noun'), ('면상', 'Noun'), ('으로', 'Josa'), ('날아오다', 'Verb'), ('최', 'Noun'), ('형', 'Suffix'), ('사의', 'Noun'), ('주먹', 'Noun'), ('!', 'Punctuation'), ('퍼억', 'Noun'), ('!', 'Punctuation'), ('맞다', 'Verb'), ('나가다', 'Verb'), ('떨어지다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('사표', 'Noun'), ('쓰다', 'Verb'), ('!', 'Punctuation'), ('당장', 'Noun'), ('.', 'Punctuation'), ('알다', 'Verb'), ('?', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('아니다', 'Adjective'), ('왜', 'Noun'), ('이르다', 'Verb'), ('?', 'Punctuation'), ('말로', 'Noun'), ('하다', 'Verb'), ('.', 'Punctuation'), ('말로', 'Noun'), ('!', 'Punctuation')]
# [('하다', 'Verb'), ('구형', 'Noun'), ('사의', 'Noun'), ('얼굴', 'Noun'), ('위로', 'Noun'), ('또다시', 'Adverb'), ('날아가다', 'Verb'), ('최', 'Noun'), ('형', 'Suffix'), ('사의', 'Noun'), ('주먹', 'Noun'), ('.', 'Punctuation')]
# [('씬', 'Noun'), ('148', 'Number'), ('경찰서', 'Noun'), ('사무실', 'Noun')]
# [('양코', 'Noun'), ('에', 'Josa'), ('휴지', 'Noun'), ('를', 'Josa'), ('쑤셔박', 'Noun'), ('은', 'Josa'), ('채', 'Noun'), ('시퍼렇', 'Noun'), ('게', 'Josa'), ('멍', 'Noun'), ('든', 'Josa'), ('눈', 'Noun'), ('으로', 'Josa'), ('씩씩', 'Adverb'), ('거리', 'Noun'), ('며', 'Josa'), ('책상', 'Noun'), ('에', 'Josa'), ('앉다', 'Verb'), ('타이핑', 'Noun'), ('을', 'Josa'), ('하다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':(', 'Punctuation'), ('옆', 'Noun'), ('에', 'Josa'), ('앉다', 'Verb'), ('최', 'Noun'), ('형사', 'Noun'), ('를', 'Josa'), ('보다', 'Verb'), (')', 'Punctuation'), ('당신', 'Noun'), ('각오', 'Noun'), ('해', 'Josa'), ('!', 'Punctuation'), ('나', 'Noun'), ('절대', 'Noun'), ('그냥', 'Noun'), ('못', 'VerbPrefix'), ('넘어가다', 'Verb'), ('!', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('왜', 'Noun'), ('?', 'Punctuation'), ('왜', 'Noun'), ('?', 'Punctuation'), ('무슨', 'Noun'), ('일이', 'Noun'), ('야', 'Josa'), ('?', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('하급', 'Noun'), ('관', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('폭행', 'Noun'), ('에', 'Josa'), ('협박', 'Noun'), ('까지', 'Josa'), ('하다', 'Verb'), ('.', 'Punctuation'), ('무슨', 'Noun'), ('여자', 'Noun'), ('가', 'Josa'), ('깡패', 'Noun'), ('야', 'Josa'), ('?', 'Punctuation'), ('경찰', 'Noun'), ('이야', 'Josa'), ('?', 'Punctuation'), ('당신', 'Noun'), (',', 'Punctuation'), ('각오', 'Noun'), ('해', 'Josa'), ('!', 'Punctuation'), ('여자', 'Noun'), ('가', 'Josa'), ('어디서', 'Adverb'), ('…', 'Foreign'), ('.', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('여자', 'Noun'), ('한테', 'Josa'), ('맞다', 'Verb'), ('더', 'Noun'), ('열', 'Noun'), ('받다', 'Verb'), ('?', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('그렇다', 'Adjective'), ('.', 'Punctuation'), ('남자', 'Noun'), ('한테', 'Josa'), ('맞다', 'Verb'), ('저', 'Noun'), ('도', 'Josa'), ('웃다', 'Verb'), ('넘어가다', 'Verb'), ('.', 'Punctuation'), ('근데', 'Adverb'), ('여자', 'Noun'), ('라고', 'Josa'), ('보다', 'Verb'), ('…', 'Foreign'), ('.', 'Punctuation')]
# [('하다', 'Verb'), ('순간', 'Noun'), ('곧장', 'Noun'), ('구', 'Noun'), ('형사', 'Noun'), ('에게', 'Josa'), ('주먹', 'Noun'), ('을', 'Josa'), ('날리다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('왜', 'Noun'), ('이르다', 'Verb'), ('?', 'Punctuation')]
# [('이', 'Determiner'), ('형사', 'Noun'), (':', 'Punctuation'), ('여기', 'Noun'), ('살벌', 'Noun'), ('한', 'Josa'), ('데', 'Noun'), ('야', 'Josa'), ('.', 'Punctuation'), ('우린', 'Noun'), ('이', 'Noun'), ('게', 'Josa'), ('애정', 'Noun'), ('표현', 'Noun'), ('이지', 'Noun'), ('.', 'Punctuation'), ('안', 'Noun'), ('그렇다', 'Adjective'), ('?', 'Punctuation')]
# [('최', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('그렇다', 'Adjective'), ('.', 'Punctuation'), ('이', 'Determiner'), ('리', 'Noun'), ('와', 'Josa'), ('!', 'Punctuation')]
# [('하다', 'Verb'), ('이', 'Determiner'), ('형사', 'Noun'), ('와', 'Josa'), ('최', 'Noun'), ('형사', 'Noun'), ('가', 'Josa'), ('잡다', 'Verb'), ('갈다', 'Verb'), ('듯', 'Noun'), ('하다', 'Verb'), ('도망가다', 'Verb'), ('구', 'Noun'), ('형사', 'Noun'), ('.', 'Punctuation')]
# [('구', 'Noun'), ('형사', 'Noun'), (':', 'Punctuation'), ('나', 'Noun'), ('안해', 'Noun'), ('!', 'Punctuation'), ('경찰', 'Noun'), ('안', 'VerbPrefix'), ('하다', 'Verb'), ('되다', 'Verb'), ('?!', 'Punctuation')]
# [('하다', 'Verb'), ('바닥', 'Noun'), ('에', 'Josa'), ('넘어지다', 'Verb'), ('구형', 'Noun'), ('사의', 'Noun'), ('모습', 'Noun'), ('뒤', 'Noun'), ('로', 'Josa'), ('최', 'Noun'), ('형사', 'Noun'), ('와', 'Josa'), ('이', 'Determiner'), ('형사', 'Noun'), ('가', 'Josa'), ('절묘', 'Noun'), ('하다', 'Verb'), ('하다', 'Verb'), ('프레임', 'Noun'), ('안', 'Noun'), ('에', 'Josa'), ('걸리다', 'Verb'), ('속', 'Noun'), ('에', 'Josa'), ('스틸', 'Noun'), ('되다', 'Verb'), ('화면', 'Noun'), ('위로', 'Noun'), ('엔딩', 'Noun'), ('타이틀', 'Noun'), ('이', 'Josa'), ('올라가다', 'Verb'), ('.', 'Punctuation')]
# []

# %%
words_all
# Out:
# ['씬',
#  '달리다',
#  '버스',
#  '안',
#  '타이틀',
#  '끝나다',
#  '되다',
#  '경쾌',
#  '하다',
#  '달려오다',
#  '서다',
#  '시내버스',
#  '치익',
#  '소리',
#  '문',
#  '열리다',
#  '기다리다',
#  '있다',
#  '사람',
#  '올라타다',
#  '버스',
#  '카드',
#  '현금',
#  '함',
#  '앞',
#  '오가다',
#  '손',
#  '바라보다',
#  '운전',
#  '수',
#  '그냥',
#  '지나치다',
#  '사람',
#  '발견',
#  '아저씨',
#  '차비',
#  '내다',
#  '하다',
#  '운전',
#  '수가',
#  '놓다',
#  '보다',
#  '가방',
#  '메다',
#  '지나치다',
#  '가다가',
#  '뒤',
#  '돌아보다',
#  '꼴통',
#  '특유',
#  '인상',
#  '긁다',
#  '들다',
#  '볼펜',
#  '울다',
#  '내미다',
#  '시선',
#  '피',
#  '하다',
#  '차',
#  '출발',
#  '시키다',
#  '운전',
#  '수',
#  '꼴통',
#  '버스',
#  '가운데',
#  '서서',
#  '가방',
#  '털썩',
#  '내려놓다',
#  '볼펜',
#  '자루',
#  '치켜',
#  '꼴통',
#  '뒤뚱뒤뚱',
#  '인사',
#  '하다',
#  '차',
#  '안',
#  '계시다',
#  '신사',
#  '숙녀',
#  '여러분',
#  '안녕하십니까',
#  '저',
#  '홧김',
#  '폭력',
#  '겁',
#  '유괴',
#  '불타다',
#  '가슴',
#  '강간',
#  '등',
#  '도합',
#  '전과',
#  '십이',
#  '범',
#  '얼마',
#  '전',
#  '추다',
#  '소한',
#  '대책',
#  '없다',
#  '어리다',
#  '양',
#  '이다',
#  '시선',
#  '피',
#  '하다',
#  '승객',
#  '볼펜',
#  '자루',
#  '올려놓다',
#  '아프다',
#  '과거',
#  '잊다',
#  '꼬',
#  '딱지',
#  '포장마차',
#  '장만',
#  '하다',
#  '하니',
#  '액땜',
#  '하다',
#  '생각',
#  '하다',
#  '가볍다',
#  '지갑',
#  '열다',
#  '바라다',
#  '여러분',
#  '가정',
#  '불행',
#  '없다',
#  '간절',
#  '소망',
#  '하다',
#  '볼펜',
#  '들다',
#  '보이',
#  '이',
#  '볼펜',
#  '단돈',
#  '삼천원',
#  '드리다',
#  '감사',
#  '하다',
#  '인사',
#  '돈',
#  '거두다',
#  '들이다',
#  '돌아다니다',
#  '꼴통',
#  '험악',
#  '인상',
#  '쓰다',
#  '보이',
#  '순순하다',
#  '돈',
#  '주다',
#  '아가씨',
#  '까다',
#  '까다',
#  '보이다',
#  '남자',
#  '볼펜',
#  '돌려주다',
#  '꼴통',
#  '난',
#  '열',
#  '받다',
#  '입',
#  '주먹',
#  '먼저',
#  '나가다',
#  '놓다',
#  '하다',
#  '사내',
#  '앞',
#  '주먹',
#  '내미다',
#  '얼른',
#  '지갑',
#  '돈',
#  '꺼내다',
#  '주다',
#  '사내',
#  '이번',
#  '꾸벅',
#  '꾸벅',
#  '졸다',
#  '있다',
#  '고등학생',
#  '다가가다',
#  '꼴통',
#  '툭툭',
#  '깨지다',
#  '않다',
#  '뒷통수',
#  '퍽퍽치',
#  '꼴통',
#  '임마',
#  '자다',
#  '척',
#  '하다',
#  '학생',
#  '왜',
#  '그렇다',
#  '꼴통',
#  '삼천원',
#  '내',
#  '학생',
#  '왜',
#  '꼴통',
#  '라면',
#  '내',
#  '안내',
#  '고등학생',
#  '돈',
#  '꺼내다',
#  '다음',
#  '넘어가다',
#  '꼴통',
#  '아이',
#  '안고',
#  '창밖',
#  '보다',
#  '척',
#  '하다',
#  '아줌마',
#  '보다',
#  '아이',
#  '머리',
#  '쓰다듬다',
#  '꼴통',
#  '귀엽다',
#  '아줌마',
#  '돌아보다',
#  '꼴통',
#  '저',
#  '겁',
#  '유괴',
#  '를',
#  '두',
#  '번',
#  '하다',
#  '죽이다',
#  '놓다',
#  '하다',
#  '이번',
#  '겁',
#  '먹다',
#  '아이',
#  '볼',
#  '살짝',
#  '꼬집는',
#  '아줌마',
#  '얼른',
#  '손',
#  '쥐',
#  '있다',
#  '돈',
#  '주다',
#  '아이',
#  '끌어안다',
#  '꼴통',
#  '몇몇',
#  '사람',
#  '순순하다',
#  '돈',
#  '받다',
#  '뒷',
#  '향',
#  '하다',
#  '버스',
#  '안',
#  '일어나다',
#  '사태',
#  '전혀',
#  '의식',
#  '하다',
#  '못',
#  '채',
#  '귀',
#  '이어폰',
#  '끼',
#  '창',
#  '밖',
#  '보다',
#  '뭔가',
#  '메모',
#  '있다',
#  '하다',
#  '여자',
#  '앞',
#  '다가서다',
#  '꼴통',
#  '다짜고짜',
#  '그녀',
#  '어깨',
#  '손',
#  '올려놓다',
#  '특유',
#  '인상',
#  '긁다',
#  '깜짝',
#  '놀라다',
#  '돌아보다',
#  '기다',
#  '생머리',
#  '시원',
#  '얼굴',
#  '여자',
#  '바로',
#  '이',
#  '영화',
#  '신임',
#  '여',
#  '사인',
#  '최',
#  '형사',
#  '꼴통',
#  '나',
#  '강간',
#  '도',
#  '하다',
#  '여자',
#  '머리카락',
#  '배배',
#  '꼬',
#  '세',
#  '번',
#  '하다',
#  '어이',
#  '없다',
#  '쳐다보다',
#  '최',
#  '형사',
#  '겁',
#  '먹다',
#  '줄',
#  '알',
#  '핸드백',
#  '자기',
#  '손',
#  '열다',
#  '돈',
#  '꺼내다',
#  '수갑',
#  '권총',
#  '발견',
#  '굳어지다',
#  '꼴통',
#  '상대',
#  '이다',
#  '지라',
#  '표정',
#  '다시',
#  '정리',
#  '하다',
#  '꼴통',
#  '너',
#  '경찰',
#  '자다',
#  '만나다',
#  '난',
#  '경찰',
#  '라면',
#  '이',
#  '갈리',
#  '놈',
#  '순간',
#  '턱',
#  '쪼인트',
#  '맞다',
#  '꼴통',
#  '신음',
#  '고개',
#  '치켜',
#  '꼴통',
#  '어쭈',
#  '치다',
#  '이',
#  '내',
#  '알',
#  '말',
#  '끝나다',
#  '전',
#  '곧장',
#  '날아오다',
#  '최',
#  '사의',
#  '주먹',
#  '퍽',
#  '뒤',
#  '나다',
#  '빠지다',
#  '꼴통',
#  '코피',
#  '쓰윽',
#  '닦다',
#  '질겁',
#  '일어나며',
#  '피다',
#  '이',
#  '씨',
#  '웃통',
#  '벗다',
#  '끼어들다',
#  '놈',
#  '있다',
#  '죽이다',
#  '버리다',
#  '겁',
#  '지다',
#  '피',
#  '하다',
#  '사람',
#  '꼴통',
#  '버스',
#  '머리',
#  '받다',
#  '씨발',
#  '사고',
#  '치기',
#  '싫다',
#  '내',
#  '인생',
#  '왜',
#  '꼬이다',
#  '휙',
#  '손가락',
#  '가리키다',
#  '것',
#  '니',
#  '잘못',
#  '하다',
#  '최',
#  '형사',
#  '향',
#  '하다',
#  '저돌',
#  '돌다',
#  '꼴통',
#  '달려오다',
#  '꼴통',
#  '멋지다',
#  '업다',
#  '받다',
#  '넘기다',
#  '최',
#  '형사',
#  '버스',
#  '바닥',
#  '찌',
#  '그렇다',
#  '정도',
#  '떨어지다',
#  '꼴통',
#  '꼴통',
#  '자신',
#  '패',
#  '인정',
#  '최',
#  '형사',
#  '향',
#  '하다',
#  '손',
#  '모으다',
#  '빌다',
#  '꼴통',
#  '제',
#  '흥분',
#  '하다',
#  '최',
#  '형사',
#  '표정',
#  '변하다',
#  '않다',
#  '채',
#  '뚜둑',
#  '뚜둑',
#  '몸',
#  '풀다',
#  '다가서다',
#  '꼴통',
#  '휘둥그레지',
#  '아니다',
#  '왜',
#  '이르다',
#  '잘못',
#  '하다',
#  '최',
#  '형사',
#  '멱살',
#  '잡다',
#  '일으키다',
#  '세우다',
#  '아직',
#  '안',
#  '끝나다',
#  '씬',
#  '거리',
#  '달리다',
#  '버스',
#  '과장',
#  '들려오다',
#  '꼴통',
#  '비명',
#  '소리',
#  '퍽',
#  '퍽',
#  '우두둑',
#  '맞다',
#  '소리',
#  '좌우',
#  '요동',
#  '치다',
#  '버스',
#  '우지끈',
#  '어딘가',
#  '부러지다',
#  '듯',
#  '소리',
#  '끼',
#  '이익',
#  '멈추다',
#  '서다',
#  '버스',
#  '위로',
#  '덥다',
#  '타이틀',
#  '투캅스',
#  '씬',
#  '집',
#  '거실',
#  '자막',
#  '사라지다',
#  '선행',
#  '하다',
#  '초인종',
#  '소리',
#  '속',
#  '화면',
#  '가득',
#  '현관문',
#  '반투명',
#  '유리',
#  '남자',
#  '형체',
#  '보이다',
#  '속',
#  '끼',
#  '리릭',
#  '끼',
#  '리릭',
#  '소리',
#  '문고',
#  '리가',
#  '탁',
#  '하다',
#  '위로',
#  '젖다',
#  '스르르',
#  '열리다',
#  '문',
#  '들어오다',
#  '구두',
#  '카메라',
#  '틸업하',
#  '손',
#  '목',
#  '장갑',
#  '끼다',
#  '사내',
#  '열다',
#  '있다',
#  '문',
#  '장갑',
#  '끼다',
#  '사내',
#  '쌕',
#  '맨',
#  '채',
#  '들어오다',
#  '장갑',
#  '날카롭다',
#  '눈매',
#  '고개',
#  '휙',
#  '저으',
#  '빠르다',
#  '움직이다',
#  '목',
#  '장갑',
#  '방문',
#  '열다',
#  '가다',
#  '방',
#  '앞',
#  '장갑',
#  '보다',
#  '고개',
#  '끄덕이다',
#  '곳',
#  '걸어가다',
#  '장갑',
#  '씬',
#  '동',
#  '방안',
#  '금고',
#  '청진기',
#  '대다',
#  '채',
#  '번호판',
#  '돌리다',
#  '있다',
#  '장갑',
#  '뒤',
#  '각종',
#  '그림',
#  '도자기',
#  '등',
#  '널린',
#  '방',
#  '서랍',
#  '따위',
#  '뒤지다',
#  '있다',
#  '목',
#  '장갑',
#  '천원',
#  '짜다',
#  '몇',
#  '장',
#  '은장도',
#  '씨거',
#  '엽전',
#  '등',
#  '쌕',
#  '넣다',
#  '장갑',
#  '눈치',
#  '보다',
#  '몰래',
#  '천원',
#  '짜다',
#  '리',
#  '주머니',
#  '챙기다',
#  '기도',
#  '하다',
#  '목',
#  '장갑',
#  '장갑',
#  '청진기',
#  '대다',
#  '채',
#  '하다',
#  '껀',
#  '하다',
#  '돈',
#  '함부로',
#  '쓰다',
#  '마르다',
#  '상법',
#  '왜',
#  '잡히다',
#  '아',
#  '돈',
#  '생기다',
#  '친구',
#  '데리',
#  '룸싸롱',
#  '쭉쭉',
#  '빵빵',
#  '죽이다',
#  '년',
#  '끼',
#  '술',
#  '졸다',
#  '퍼마셨',
#  '이',
#  '친구',
#  '란',
#  '새끼',
#  '아침',
#  '해장국',
#  '먹다',
#  '갑자기',
#  '이렇다',
#  '생각',
#  '들다',
#  '자기',
#  '어제',
#  '하다',
#  '번',
#  '얻어먹다',
#  '저',
#  '새',
#  '끼다',
#  '그렇다',
#  '데',
#  '처',
#  '먹다',
#  '끄다',
#  '생각',
#  '하다',
#  '열',
#  '받다',
#  '씨발',
#  '경찰',
#  '수상한',
#  '놈',
#  '있다',
#  '찌다',
#  '잡히다',
#  '절대',
#  '친하다',
#  '놈',
#  '돈',
#  '쓰다',
#  '마르다',
#  '알다',
#  '목',
#  '장갑',
#  '예',
#  '장갑',
#  '보다',
#  '꼬불칠',
#  '생각',
#  '하다',
#  '마르다',
#  '나중',
#  '죽다',
#  '목',
#  '장갑',
#  '주머니',
#  '돈',
#  '꺼내다',
#  '예',
#  '하다',
#  '다시',
#  '천원',
#  '지폐',
#  '꺼내다',
#  '쌕',
#  '안',
#  '밀다',
#  '놓다',
#  '딸칵',
#  '소리',
#  '미소',
#  '지다',
#  '금고',
#  '손잡이',
#  '잡다',
#  '여',
#  '장갑',
#  '목',
#  '장갑',
#  '뒤',
#  '다가오다',
#  '장갑',
#  '미소',
#  '지은',
#  '채',
#  '금고',
#  '열다',
#  '잉',
#  '표정',
#  '확',
#  '변하다',
#  '뒤',
#  '어어',
#  '고개',
#  '들이다',
#  '밉다',
#  '목',
#  '장갑',
#  '표정',
#  '확',
#  '굳다',
#  '보다',
#  '열리다',
#  '문',
#  '안',
#  '금고',
#  '하나',
#  '더',
#  '보이다',
#  '목',
#  '장갑',
#  '씨발',
#  '이',
#  '새끼',
#  '금고',
#  '사하나',
#  '장갑',
#  '아니다',
#  '도굴',
#  '목',
#  '장갑',
#  '예',
#  '그게',
#  '뭡',
#  '장갑',
#  '몰래',
#  '남',
#  '무덤',
#  '졸다',
#  '파서',
#  '골동품',
#  '챙기다',
#  '팔',
#  '먹다',
#  '놓다',
#  '목',
#  '장갑',
#  '한마디',
#  '벼락',
#  '맞다',
#  '새끼',
#  '들이다',
#  '장갑',
#  '자',
#  '방출',
#  '간걸',
#  '보다',
#  '또',
#  '어떻다',
#  '놈',
#  '무덤',
#  '졸다',
#  '파고',
#  '있다',
#  '씬',
#  '동',
#  '밖',
#  '끼',
#  '이익',
#  '멈추다',
#  '봉고',
#  '박스',
#  '등',
#  '들다',
#  '내리다',
#  '도굴',
#  '꾼',
#  '제법',
#  '크다',
#  '집의',
#  '대문',
#  '열다',
#  '짐',
#  '들다',
#  '조심',
#  '스레',
#  '안',
#  '들어가다',
#  '속',
#  '그',
#  '뒤',
#  '멈추다',
#  '서다',
#  '차',
#  '열리다',
#  '차문',
#  '내리다',
#  '누군가',
#  '발',
#  '틸업하',
#  '바로',
#  '우리',
#  '형사',
#  '도굴',
#  '꾼',
#  '보다',
#  '빠르다',
#  '다가가다',
#  '씬',
#  '동',
#  '안',
#  '다시',
#  '청진기',
#  '대고',
#  '있다',
#  '장갑',
#  '뒤',
#  '시계',
#  '보고',
#  '있다',
#  '목',
#  '장갑',
#  '목',
#  '장갑',
#  '형님',
#  '안',
#  '금고',
#  '하나',
#  '더',
#  '있다',
#  '어떻다',
#  '하다',
#  '하자',
#  '휙',
#  '보다',
#  '장갑',
#  '목',
#  '장갑',
#  '머리',
#  '배',
#  '따위',
#  '마구',
#  '팬',
#  '장갑',
#  '재수',
#  '없다',
#  '소리',
#  '하다',
#  '임마',
#  '안',
#  '금고',
#  '또',
#  '있다',
#  '너',
#  '죽다',
#  '알',
#  '금고',
#  '문',
#  '여',
#  '순간',
#  '또',
#  '다른',
#  '금고',
#  '있다',
#  '장갑',
#  '목',
#  '장갑',
#  '팰',
#  '듯이',
#  '가다',
#  '리',
#  '새꺄',
#  '하다',
#  '순간',
#  '현관문',
#  '열리다',
#  '소리',
#  '들리다',
#  '표정',
#  '굳다',
#  '장갑',
#  '목',
#  '장갑',
#  '문쪽',
#  '바라보다',
#  '씬',
#  '동',
#  '거실',
#  '문',
#  '열다',
#  '들어오다',
#  '도굴',
#  '뒤',
#  '돌아보다',
#  '도굴',
#  '조심',
#  '하다',
#  '얼마',
#  '짜다',
#  '린',
#  '줄',
#  '알',
#  '무겁다',
#  '듯',
#  '박스',
#  '등',
#  '들다',
#  '들어오다',
#  '도굴',
#  '의',
#  '모습',
#  '속',
#  '들리다',
#  '소리',
#  '이형',
#  '사의',
#  '꼼작마',
#  '경찰',
#  '휙',
#  '뒤',
#  '돌아보다',
#  '도굴',
#  '꾼',
#  '인상',
#  '확',
#  '변하다',
#  '어느새다',
#  ...]
